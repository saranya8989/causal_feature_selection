# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
path='/media/sshudhees/DAEA17D6EA17ADAF/Data/Research_2022/2022/amphan/nio/2020/full_time/'
ds1=xr.open_dataset(path+'mslp_amphan.nc')
ds2=xr.open_dataset(path+'wind10_amphan.nc')
ds3=xr.open_dataset(path+'vor1000_amphan.nc')
ds4=xr.open_dataset(path+'vor925_amphan.nc')
ds5=xr.open_dataset(path+'vor850_amphan.nc')
ds6=xr.open_dataset(path+'vor700_amphan.nc')
ds7=xr.open_dataset(path+'vor600_amphan.nc')
ds8=xr.open_dataset(path+'vor500_amphan.nc')
ds9=xr.open_dataset(path+'vor400_amphan.nc')
ds10=xr.open_dataset(path+'vor300_amphan.nc')
# Out:
# /home/sshudhees/anaconda3/lib/python3.9/site-packages/xarray/coding/times.py:123: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
ds1.time[16:69]
# Out:
# <xarray.DataArray 'time' (time: 53)>
# array(['2020-05-14T00:00:00.000000000', '2020-05-14T03:00:00.000000000',
#        '2020-05-14T06:00:00.000000000', '2020-05-14T09:00:00.000000000',
#        '2020-05-14T12:00:00.000000000', '2020-05-14T15:00:00.000000000',
#        '2020-05-14T18:00:00.000000000', '2020-05-14T21:00:00.000000000',
#        '2020-05-15T00:00:00.000000000', '2020-05-15T03:00:00.000000000',
#        '2020-05-15T06:00:00.000000000', '2020-05-15T09:00:00.000000000',
#        '2020-05-15T12:00:00.000000000', '2020-05-15T15:00:00.000000000',
#        '2020-05-15T18:00:00.000000000', '2020-05-15T21:00:00.000000000',
#        '2020-05-16T00:00:00.000000000', '2020-05-16T03:00:00.000000000',
#        '2020-05-16T06:00:00.000000000', '2020-05-16T09:00:00.000000000',
#        '2020-05-16T12:00:00.000000000', '2020-05-16T15:00:00.000000000',
#        '2020-05-16T18:00:00.000000000', '2020-05-16T21:00:00.000000000',
# ...

# %%
slp=ds1.var151[16:69,:,:]
w10=ds2.ws[16:69,:,:]
vor1000=ds3.var138[16:69,:,:]
vor925=ds4.var138[16:69,:,:]
vor850=ds5.var138[16:69,:,:]
vor700=ds6.var138[16:69,:,:]
vor600=ds7.var138[16:69,:,:]
vor500=ds8.var138[16:69,:,:]
vor400=ds9.var138[16:69,:,:]
vor300=ds10.var138[16:69,:,:]

# %%
ds11=xr.open_dataset(path+'2mdewt_amphan.nc')
ds12=xr.open_dataset(path+'2mtemp_amphan.nc')
ds13=xr.open_dataset(path+'cape_amphan.nc')
ds14=xr.open_dataset(path+'convppt_amphan.nc')
ds15=xr.open_dataset(path+'conv_rrate_amphan.nc')
ds16=xr.open_dataset(path+'div200_amphan.nc')
ds17=xr.open_dataset(path+'div300_amphan.nc')
ds18=xr.open_dataset(path+'div400_amphan.nc')
ds19=xr.open_dataset(path+'div500_amphan.nc')
ds20=xr.open_dataset(path+'dwnwrdmean_swr_flux_amphan.nc')
# Out:
# /home/sshudhees/anaconda3/lib/python3.9/site-packages/xarray/coding/times.py:123: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
dewt2m=ds11.var168[16:69,:,:]
t2m=ds12.var167[16:69,:,:]
cape=ds13.var59[16:69,:,:]
convppt=ds14.var143[16:69,:,:]
convrr=ds15.var218[16:69,:,:]
d200=ds16.ws[16:69,:,:]
d300=ds17.ws[16:69,:,:]
d400=ds18.ws[16:69,:,:]
d500=ds19.ws[16:69,:,:]
dwnswr=ds20.var53[16:69,:,:]

# %%
ds21=xr.open_dataset(path+'eqpot200_amphan.nc')
ds22=xr.open_dataset(path+'eqpot300_amphan.nc')
ds23=xr.open_dataset(path+'eqpot400_amphan.nc')
ds24=xr.open_dataset(path+'eqpot500_amphan.nc')
ds25=xr.open_dataset(path+'eqpot600_amphan.nc')
ds26=xr.open_dataset(path+'eqpot700_amphan.nc')
ds27=xr.open_dataset(path+'eqpot850_amphan.nc')
ds28=xr.open_dataset(path+'eqpot925_amphan.nc')
ds29=xr.open_dataset(path+'eqpot1000_amphan.nc')
ds30=xr.open_dataset(path+'ls_rrate_amphan.nc')
# Out:
# /home/sshudhees/anaconda3/lib/python3.9/site-packages/xarray/coding/times.py:123: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
te200=ds21.eqt[16:69,:,:]
te300=ds22.eqt[16:69,:,:]
te400=ds23.eqt[16:69,:,:]
te500=ds24.eqt[16:69,:,:]
te600=ds25.eqt[16:69,:,:]
te700=ds26.eqt[16:69,:,:]
te850=ds27.eqt[16:69,:,:]
te925=ds28.eqt[16:69,:,:]
te1000=ds29.eqt[16:69,:,:]
lsrr=ds30.var219[16:69,:,:]

# %%
ds31=xr.open_dataset(path+'inst_10m_wnd_gst_amphan.nc')
ds32=xr.open_dataset(path+'inst_moisture_flux_amphan.nc')
ds33=xr.open_dataset(path+'inst_ssh_flux_amphan.nc')
ds34=xr.open_dataset(path+'mn_conv_prate_amphan.nc')
ds35=xr.open_dataset(path+'mn_ls_prate_amphan.nc')
ds36=xr.open_dataset(path+'mn_tot_prate_amphan.nc')
ds37=xr.open_dataset(path+'shear850_250amphan.nc')
ds38=xr.open_dataset(path+'shear850_amphan.nc')
ds39=xr.open_dataset(path+'shear925_200amphan.nc')
ds40=xr.open_dataset(path+'shear925_amphan.nc')
# Out:
# /home/sshudhees/anaconda3/lib/python3.9/site-packages/xarray/coding/times.py:123: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
inst10mwnd=ds31.var29[16:69,:,:]
instmst=ds32.var232[16:69,:,:]
instssh=ds33.var231[16:69,:,:]
mnconvrr=ds34.var30[16:69,:,:]
mnlsrr=ds35.var29[16:69,:,:]
mnttrr=ds36.var55[16:69,:,:]
sh825=ds37.sh[16:69,:,:]
sh820=ds38.sh[16:69,:,:]
sh920=ds39.sh[16:69,:,:]
sh925=ds40.sh[16:69,:,:]

# %%
ds41=xr.open_dataset(path+'pv200_amphan.nc')
ds42=xr.open_dataset(path+'pv300_amphan.nc')
ds43=xr.open_dataset(path+'pv400_amphan.nc')
ds44=xr.open_dataset(path+'pv500_amphan.nc')
ds45=xr.open_dataset(path+'pv600_amphan.nc')
ds46=xr.open_dataset(path+'pv700_amphan.nc')
ds47=xr.open_dataset(path+'pv850_amphan.nc')
ds48=xr.open_dataset(path+'pv925_amphan.nc')
ds49=xr.open_dataset(path+'pv1000_amphan.nc')
ds50=xr.open_dataset(path+'sst_amphan.nc')

# %%
pvor200=ds41.var60[16:69,:,:]
pvor300=ds42.var60[16:69,:,:]
pvor400=ds43.var60[16:69,:,:]
pvor500=ds44.var60[16:69,:,:]
pvor600=ds45.var60[16:69,:,:]
pvor700=ds46.var60[16:69,:,:]
pvor850=ds47.var60[16:69,:,:]
pvor925=ds48.var60[16:69,:,:]
pvor1000=ds49.var60[16:69,:,:]
sst=ds50.var34[16:69,:,:]

# %%
ds51=xr.open_dataset(path+'rh200_amphan.nc')
ds52=xr.open_dataset(path+'rh300_amphan.nc')
ds53=xr.open_dataset(path+'rh400_amphan.nc')
ds54=xr.open_dataset(path+'rh500_amphan.nc')
ds55=xr.open_dataset(path+'rh600_amphan.nc')
ds56=xr.open_dataset(path+'rh700_amphan.nc')
ds57=xr.open_dataset(path+'rh850_amphan.nc')
ds58=xr.open_dataset(path+'rh925_amphan.nc')
ds59=xr.open_dataset(path+'rh1000_amphan.nc')
ds60=xr.open_dataset(path+'stress10m_amphan.nc')
# Out:
# /home/sshudhees/anaconda3/lib/python3.9/site-packages/xarray/coding/times.py:123: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
r200=ds51.var157[16:69,:,:]
r300=ds52.var157[16:69,:,:]
r400=ds53.var157[16:69,:,:]
r500=ds54.var157[16:69,:,:]
r600=ds55.var157[16:69,:,:]
r700=ds56.var157[16:69,:,:]
r850=ds57.var157[16:69,:,:]
r925=ds58.var157[16:69,:,:]
r1000=ds59.var157[16:69,:,:]
strss=ds60.ws[16:69,:,:]

# %%
ds61=xr.open_dataset(path+'t200_amphan.nc')
ds62=xr.open_dataset(path+'t300_amphan.nc')
ds63=xr.open_dataset(path+'t400_amphan.nc')
ds64=xr.open_dataset(path+'t500_amphan.nc')
ds65=xr.open_dataset(path+'t600_amphan.nc')
ds66=xr.open_dataset(path+'t700_amphan.nc')
ds67=xr.open_dataset(path+'t850_amphan.nc')
ds68=xr.open_dataset(path+'t925_amphan.nc')
ds69=xr.open_dataset(path+'t1000_amphan.nc')
ds70=xr.open_dataset(path+'tot_wtr_vpr_amphan.nc')

# %%
t200=ds61.var130[16:69,:,:]
t300=ds62.var130[16:69,:,:]
t400=ds63.var130[16:69,:,:]
t500=ds64.var130[16:69,:,:]
t600=ds65.var130[16:69,:,:]
t700=ds66.var130[16:69,:,:]
t850=ds67.var130[16:69,:,:]
t925=ds68.var130[16:69,:,:]
t1000=ds69.var130[16:69,:,:]
wtrvpr=ds70.var137[16:69,:,:]

# %%
ds71=xr.open_dataset(path+'z200_amphan.nc')
ds72=xr.open_dataset(path+'z300_amphan.nc')
ds73=xr.open_dataset(path+'z400_amphan.nc')
ds74=xr.open_dataset(path+'z500_amphan.nc')
ds75=xr.open_dataset(path+'z600_amphan.nc')
ds76=xr.open_dataset(path+'z700_amphan.nc')
ds77=xr.open_dataset(path+'z850_amphan.nc')
ds78=xr.open_dataset(path+'z925_amphan.nc')
ds79=xr.open_dataset(path+'z1000_amphan.nc')
ds80=xr.open_dataset(path+'surf_lhf_amphan.nc')

# %%
z200=ds71.var129[16:69,:,:]
z300=ds72.var129[16:69,:,:]
z400=ds73.var129[16:69,:,:]
z500=ds74.var129[16:69,:,:]
z600=ds75.var129[16:69,:,:]
z700=ds76.var129[16:69,:,:]
z850=ds77.var129[16:69,:,:]
z925=ds78.var129[16:69,:,:]
z1000=ds79.var129[16:69,:,:]
srflhf=ds80.var147[16:69,:,:]

# %%
ds81=xr.open_dataset(path+'surfmean_lhf_amphan.nc')
ds82=xr.open_dataset(path+'surfmean_shf_amphan.nc')
ds83=xr.open_dataset(path+'surfmean_lwr_flux_amphan.nc')
ds84=xr.open_dataset(path+'surfmean_swr_flux_amphan.nc')
ds85=xr.open_dataset(path+'surf_shf_amphan.nc')
ds86=xr.open_dataset(path+'topmean_lwr_flux_amphan.nc')
ds87=xr.open_dataset(path+'topmean_swr_flux_amphan.nc')
ds88=xr.open_dataset(path+'tot_cld_ice_amphan.nc')
ds89=xr.open_dataset(path+'tot_cld_rain_amphan.nc')
ds90=xr.open_dataset(path+'tot_cldwtr_amphan.nc')

# %%
srfmnlhf=ds81.var34[16:69,:,:]
srfmnshf=ds82.var33[16:69,:,:]
srfmnlwr=ds83.var38[16:69,:,:]
srfmnswr=ds84.var58[16:69,:,:]
srfshf=ds85.var146[16:69,:,:]
tpmnlwr=ds86.var40[16:69,:,:]
tpmnswr=ds87.var39[16:69,:,:]
ttcldice=ds88.var79[16:69,:,:]
ttcldrn=ds89.var89[16:69,:,:]
ttcldwtr=ds90.var78[16:69,:,:]

# %%
ds91=xr.open_dataset(path+'tot_suprcool_liqwtr_amphan.nc')
ds92=xr.open_dataset(path+'vi_div_cld_froz_wtr_amphan.nc')
ds93=xr.open_dataset(path+'vi_div_cld_liq_wtr_amphan.nc')
ds94=xr.open_dataset(path+'vi_div_gpot_flux_amphan.nc')
ds95=xr.open_dataset(path+'vi_div_ke_flux_amphan.nc')
ds96=xr.open_dataset(path+'vi_div_mass_flux_amphan.nc')
ds97=xr.open_dataset(path+'vi_div_moisture_flux_amphan.nc')
ds98=xr.open_dataset(path+'vi_div_olr_flux_amphan.nc')
ds99=xr.open_dataset(path+'vi_div_tot_enrgy_flux_amphan.nc')
ds100=xr.open_dataset(path+'vi_ke_amphan.nc')
ds101=xr.open_dataset(path+'vimean_moisture_div_amphan.nc')
ds102=xr.open_dataset(path+'vi_moisture_div_amphan.nc')
ds103=xr.open_dataset(path+'vi_olr_amphan.nc')
ds104=xr.open_dataset(path+'vi_pe_ie_latentenrgy_amphan.nc')
ds105=xr.open_dataset(path+'vi_pe__inte_amphan.nc')
ds106=xr.open_dataset(path+'vi_temp_amphan.nc')
ds107=xr.open_dataset(path+'vi_tot_enrgy_amphan.nc')

# %%
ds105
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 79, lon: 280, lat: 120)
# Coordinates:
#   * time     (time) datetime64[ns] 2020-05-12 ... 2020-05-21T18:00:00
#   * lon      (lon) float64 40.0 40.25 40.5 40.75 ... 109.0 109.2 109.5 109.8
#   * lat      (lat) float64 30.0 29.75 29.5 29.25 29.0 ... 1.25 1.0 0.75 0.5 0.25
#     lev      float64 0.0
# Data variables:
#     var61    (time, lat, lon) float32 ...

# %%
ttsprwtr=ds91.var88[16:69,:,:]
vicldfrzwtr=ds92.var80[16:69,:,:]
vicldliqwtr=ds93.var79_2[16:69,:,:]
vigpot=ds94.var85[16:69,:,:]
vikefl=ds95.var82[16:69,:,:]
vimss=ds96.var81[16:69,:,:]
vimst=ds97.var84[16:69,:,:]
violrfl=ds98.var83[16:69,:,:]
vitotenrgyfl=ds99.var86[16:69,:,:]
vike=ds100.var59[16:69,:,:]
vimnmstdiv=ds101.var54[16:69,:,:]
vimstdiv=ds102.var213[16:69,:,:]
violr=ds103.var60[16:69,:,:]
vipeiele=ds104.var62[16:69,:,:]
vipeie=ds105.var61[16:69,:,:]
vitmp=ds106.var54[16:69,:,:]
vitotenrgy=ds107.var63[16:69,:,:]

# %%
# Out:
# <xarray.DataArray 'var63' (time: 53, lat: 120, lon: 280)>
# [1780800 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-05-14 ... 2020-05-20T12:00:00
#   * lon      (lon) float64 40.0 40.25 40.5 40.75 ... 109.0 109.2 109.5 109.8
#   * lat      (lat) float64 30.0 29.75 29.5 29.25 29.0 ... 1.25 1.0 0.75 0.5 0.25
#     lev      float64 0.0
# Attributes:
#     table:    162

# %%
track=pd.read_csv('nio_bb_20200514.csv',delimiter=r",")

# %%
track
# Out:
#                    time  latitude  longitude
# 0   2020-05-14:00.00.00  10.03180    86.4177
# 1   2020-05-14:03.00.00  10.69140    86.1814
# 2   2020-05-14:06.00.00  10.65010    86.6277
# 3   2020-05-14:09.00.00  10.97990    86.7327
# 4   2020-05-14:12.00.00  10.36150    85.5776
# 5   2020-05-14:15.00.00   9.53704    85.9451
# 6   2020-05-14:18.00.00  10.15540    85.7876
# 7   2020-05-14:21.00.00  10.60890    85.9189
# 8   2020-05-15:00.00.00  10.11420    85.6826
# 9   2020-05-15:03.00.00  10.23790    85.4988
# 10  2020-05-15:06.00.00  10.11420    86.7589
# 11  2020-05-15:09.00.00  10.03180    86.3914
# 12  2020-05-15:12.00.00   9.45457    85.8138
# 13  2020-05-15:15.00.00  10.15540    86.1026
# 14  2020-05-15:18.00.00  10.44400    86.3914
# 15  2020-05-15:21.00.00  10.23150    85.8606
# 16  2020-05-16:00.00.00   9.84000    86.4400
# 17  2020-05-16:03.00.00  10.09000    86.2134
# 18  2020-05-16:06.00.00  10.32860    86.0714
# 19  2020-05-16:09.00.00  10.49250    86.1062
# ...

# %%
lon1=track['longitude'].to_numpy()
lat1=track['latitude'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)

# %%
pos.shape[0]
# Out:
# 53

# %%
pos
# Out:
# array([[10.0318 , 86.4177 ],
#        [10.6914 , 86.1814 ],
#        [10.6501 , 86.6277 ],
#        [10.9799 , 86.7327 ],
#        [10.3615 , 85.5776 ],
#        [ 9.53704, 85.9451 ],
#        [10.1554 , 85.7876 ],
#        [10.6089 , 85.9189 ],
#        [10.1142 , 85.6826 ],
#        [10.2379 , 85.4988 ],
#        [10.1142 , 86.7589 ],
#        [10.0318 , 86.3914 ],
#        [ 9.45457, 85.8138 ],
#        [10.1554 , 86.1026 ],
#        [10.444  , 86.3914 ],
#        [10.2315 , 85.8606 ],
#        [ 9.84   , 86.44   ],
#        [10.09   , 86.2134 ],
#        [10.3286 , 86.0714 ],
#        [10.4925 , 86.1062 ],
#        [10.6    , 86.15   ],
#        [10.7537 , 86.125  ],
#        [10.9    , 86.1    ],
#        [11.075  , 86.125  ],
#        [11.2    , 86.1    ],
#        [11.2962 , 86.125  ],
#        [11.45   , 86.15   ],
#        [11.6387 , 86.1713 ],
#        [11.9    , 86.2    ],
#        [12.4675 , 86.3612 ],
#        [12.5    , 86.35   ],
#        [12.865  , 86.4651 ],
# ...

# %%
tc_irad=np.empty((53,4))
tc_irad[:,0] = pos[:,0]+2
tc_irad[:,1] = pos[:,0]-2
tc_irad[:,2] = pos[:,1]-2
tc_irad[:,3] = pos[:,1]+2

# %%
tc_irad
# Out:
# array([[12.0318 ,  8.0318 , 84.4177 , 88.4177 ],
#        [12.6914 ,  8.6914 , 84.1814 , 88.1814 ],
#        [12.6501 ,  8.6501 , 84.6277 , 88.6277 ],
#        [12.9799 ,  8.9799 , 84.7327 , 88.7327 ],
#        [12.3615 ,  8.3615 , 83.5776 , 87.5776 ],
#        [11.53704,  7.53704, 83.9451 , 87.9451 ],
#        [12.1554 ,  8.1554 , 83.7876 , 87.7876 ],
#        [12.6089 ,  8.6089 , 83.9189 , 87.9189 ],
#        [12.1142 ,  8.1142 , 83.6826 , 87.6826 ],
#        [12.2379 ,  8.2379 , 83.4988 , 87.4988 ],
#        [12.1142 ,  8.1142 , 84.7589 , 88.7589 ],
#        [12.0318 ,  8.0318 , 84.3914 , 88.3914 ],
#        [11.45457,  7.45457, 83.8138 , 87.8138 ],
#        [12.1554 ,  8.1554 , 84.1026 , 88.1026 ],
#        [12.444  ,  8.444  , 84.3914 , 88.3914 ],
#        [12.2315 ,  8.2315 , 83.8606 , 87.8606 ],
#        [11.84   ,  7.84   , 84.44   , 88.44   ],
#        [12.09   ,  8.09   , 84.2134 , 88.2134 ],
#        [12.3286 ,  8.3286 , 84.0714 , 88.0714 ],
# ...

# %%
df1=np.zeros((tc_irad.shape[0],))
df2=np.zeros((tc_irad.shape[0],))
df3=np.zeros((tc_irad.shape[0],))
df4=np.zeros((tc_irad.shape[0],))
df5=np.zeros((tc_irad.shape[0],))
df6=np.zeros((tc_irad.shape[0],))
df7=np.zeros((tc_irad.shape[0],))
df8=np.zeros((tc_irad.shape[0],))
df9=np.zeros((tc_irad.shape[0],))
df10=np.zeros((tc_irad.shape[0],))
df11=np.zeros((tc_irad.shape[0],))
df12=np.zeros((tc_irad.shape[0],))
df13=np.zeros((tc_irad.shape[0],))
df14=np.zeros((tc_irad.shape[0],))
df15=np.zeros((tc_irad.shape[0],))
df16=np.zeros((tc_irad.shape[0],))
df17=np.zeros((tc_irad.shape[0],))
df18=np.zeros((tc_irad.shape[0],))
df19=np.zeros((tc_irad.shape[0],))
df20=np.zeros((tc_irad.shape[0],))
df21=np.zeros((tc_irad.shape[0],))
df22=np.zeros((tc_irad.shape[0],))
df23=np.zeros((tc_irad.shape[0],))
df24=np.zeros((tc_irad.shape[0],))
df25=np.zeros((tc_irad.shape[0],))
df26=np.zeros((tc_irad.shape[0],))
df27=np.zeros((tc_irad.shape[0],))
df28=np.zeros((tc_irad.shape[0],))
df29=np.zeros((tc_irad.shape[0],))
df30=np.zeros((tc_irad.shape[0],))
df31=np.zeros((tc_irad.shape[0],))
df32=np.zeros((tc_irad.shape[0],))
df33=np.zeros((tc_irad.shape[0],))
df34=np.zeros((tc_irad.shape[0],))
df35=np.zeros((tc_irad.shape[0],))
df36=np.zeros((tc_irad.shape[0],))
df37=np.zeros((tc_irad.shape[0],))
df38=np.zeros((tc_irad.shape[0],))
df39=np.zeros((tc_irad.shape[0],))
df40=np.zeros((tc_irad.shape[0],))
df41=np.zeros((tc_irad.shape[0],))
df42=np.zeros((tc_irad.shape[0],))
df43=np.zeros((tc_irad.shape[0],))
df44=np.zeros((tc_irad.shape[0],))
df45=np.zeros((tc_irad.shape[0],))
df46=np.zeros((tc_irad.shape[0],))
df47=np.zeros((tc_irad.shape[0],))
df48=np.zeros((tc_irad.shape[0],))
df49=np.zeros((tc_irad.shape[0],))
df50=np.zeros((tc_irad.shape[0],))

# %%
df51=np.zeros((tc_irad.shape[0],))
df52=np.zeros((tc_irad.shape[0],))
df53=np.zeros((tc_irad.shape[0],))
df54=np.zeros((tc_irad.shape[0],))
df55=np.zeros((tc_irad.shape[0],))
df56=np.zeros((tc_irad.shape[0],))
df57=np.zeros((tc_irad.shape[0],))
df58=np.zeros((tc_irad.shape[0],))
df59=np.zeros((tc_irad.shape[0],))
df60=np.zeros((tc_irad.shape[0],))
df61=np.zeros((tc_irad.shape[0],))
df62=np.zeros((tc_irad.shape[0],))
df63=np.zeros((tc_irad.shape[0],))
df64=np.zeros((tc_irad.shape[0],))
df65=np.zeros((tc_irad.shape[0],))
df66=np.zeros((tc_irad.shape[0],))
df67=np.zeros((tc_irad.shape[0],))
df68=np.zeros((tc_irad.shape[0],))
df69=np.zeros((tc_irad.shape[0],))
df70=np.zeros((tc_irad.shape[0],))
df71=np.zeros((tc_irad.shape[0],))
df72=np.zeros((tc_irad.shape[0],))
df73=np.zeros((tc_irad.shape[0],))
df74=np.zeros((tc_irad.shape[0],))
df75=np.zeros((tc_irad.shape[0],))
df76=np.zeros((tc_irad.shape[0],))
df77=np.zeros((tc_irad.shape[0],))
df78=np.zeros((tc_irad.shape[0],))
df79=np.zeros((tc_irad.shape[0],))
df80=np.zeros((tc_irad.shape[0],))
df81=np.zeros((tc_irad.shape[0],))
df82=np.zeros((tc_irad.shape[0],))
df83=np.zeros((tc_irad.shape[0],))
df84=np.zeros((tc_irad.shape[0],))
df85=np.zeros((tc_irad.shape[0],))
df86=np.zeros((tc_irad.shape[0],))
df87=np.zeros((tc_irad.shape[0],))
df88=np.zeros((tc_irad.shape[0],))
df89=np.zeros((tc_irad.shape[0],))
df90=np.zeros((tc_irad.shape[0],))
df91=np.zeros((tc_irad.shape[0],))
df92=np.zeros((tc_irad.shape[0],))
df93=np.zeros((tc_irad.shape[0],))
df94=np.zeros((tc_irad.shape[0],))
df95=np.zeros((tc_irad.shape[0],))
df96=np.zeros((tc_irad.shape[0],))
df97=np.zeros((tc_irad.shape[0],))
df98=np.zeros((tc_irad.shape[0],))
df99=np.zeros((tc_irad.shape[0],))
df100=np.zeros((tc_irad.shape[0],))
df101=np.zeros((tc_irad.shape[0],))
df102=np.zeros((tc_irad.shape[0],))
df103=np.zeros((tc_irad.shape[0],))
df104=np.zeros((tc_irad.shape[0],))
df105=np.zeros((tc_irad.shape[0],))
df106=np.zeros((tc_irad.shape[0],))
df107=np.zeros((tc_irad.shape[0],))

# %%
for it in range(tc_irad.shape[0]):
    latn, lats, lone, lonw = tc_irad[it,:]
    print(it)
    print(latn, lats, lone, lonw)
    df1[it]=slp[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df2[it]=vor1000[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df3[it]=w10[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df4[it]=vor925[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df5[it]=vor850[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df6[it]=vor700[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df7[it]=vor600[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df8[it]=vor500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df9[it]=vor400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df10[it]=vor300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df11[it]=dewt2m[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df12[it]=t2m[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df13[it]=cape[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df14[it]=convppt[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df15[it]=convrr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df16[it]=d200[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df17[it]=d300[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df18[it]=d400[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df19[it]=d500[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df20[it]=dwnswr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df21[it]=te200[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df22[it]=te300[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df23[it]=te400[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df24[it]=te500[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df25[it]=te600[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df26[it]=te700[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df27[it]=te850[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df28[it]=te925[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df29[it]=te1000[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df30[it]=vitmp[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df31[it]=vitotenrgy[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df32[it]=lsrr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df33[it]=inst10mwnd[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df34[it]=instmst[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df35[it]=instssh[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df36[it]=mnconvrr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df37[it]=mnlsrr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df38[it]=mnttrr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df39[it]=sh825[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df40[it]=sh820[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df41[it]=sh920[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df42[it]=sh925[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df43[it]=pvor200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df44[it]=pvor300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df45[it]=pvor400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df46[it]=pvor500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df47[it]=pvor600[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df48[it]=pvor700[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df49[it]=pvor850[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df50[it]=pvor925[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df51[it]=pvor1000[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df52[it]=sst[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df53[it]=r200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df54[it]=r300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df55[it]=r400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df56[it]=r500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df57[it]=r600[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df58[it]=r700[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df59[it]=r850[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df60[it]=r925[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df61[it]=r1000[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df62[it]=strss[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df63[it]=t200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df64[it]=t300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df65[it]=t400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df66[it]=t500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df67[it]=t600[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df68[it]=t700[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df69[it]=t850[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df70[it]=t925[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df71[it]=t1000[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df72[it]=wtrvpr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df73[it]=z200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df74[it]=z300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df75[it]=z400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df76[it]=z500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df77[it]=z600[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df78[it]=z700[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df79[it]=z850[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df80[it]=z925[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df81[it]=z1000[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df82[it]=srflhf[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df83[it]=srfmnlhf[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df84[it]=srfmnshf[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df85[it]=srfmnlwr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df86[it]=srfmnswr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df87[it]=srfshf[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df88[it]=tpmnlwr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df89[it]=tpmnswr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df90[it]=ttcldice[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df91[it]=ttcldrn[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df92[it]=ttcldwtr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df93[it]=ttsprwtr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df94[it]=vicldfrzwtr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df95[it]=vicldliqwtr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df96[it]=vigpot[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df97[it]=vikefl[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df98[it]=vimss[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df99[it]=vimst[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df100[it]=violrfl[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df101[it]=vitotenrgyfl[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df102[it]=vike[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df103[it]=vimnmstdiv[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df104[it]=vimstdiv[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df105[it]=violr[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df106[it]=vipeiele[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
    df107[it]=vipeie[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)).mean(dim=['lat','lon'])
# Out:
# 0
# 12.0318 8.0318 84.4177 88.4177
# 1
# 12.6914 8.6914 84.1814 88.1814
# 2
# 12.6501 8.6501 84.6277 88.6277
# 3
# 12.9799 8.9799 84.7327 88.7327
# 4
# 12.3615 8.3615 83.5776 87.5776
# 5
# 11.53704 7.537039999999999 83.9451 87.9451
# 6
# 12.1554 8.1554 83.7876 87.7876
# 7
# 12.6089 8.6089 83.9189 87.9189
# 8
# 12.1142 8.1142 83.6826 87.6826
# 9
# 12.2379 8.2379 83.4988 87.4988
# 10
# 12.1142 8.1142 84.7589 88.7589
# 11
# 12.0318 8.0318 84.3914 88.3914
# 12
# 11.45457 7.45457 83.8138 87.8138
# 13
# 12.1554 8.1554 84.1026 88.1026
# 14
# 12.444 8.444 84.3914 88.3914
# 15
# 12.2315 8.2315 83.8606 87.8606
# 16
# 11.84 7.84 84.44 88.44
# 17
# 12.09 8.09 84.2134 88.2134
# 18
# 12.3286 8.3286 84.0714 88.0714
# 19
# 12.4925 8.4925 84.1062 88.1062
# 20
# 12.6 8.6 84.15 88.15
# 21
# 12.7537 8.7537 84.125 88.125
# 22
# 12.9 8.9 84.1 88.1
# 23
# 13.075 9.075 84.125 88.125
# 24
# 13.2 9.2 84.1 88.1
# 25
# 13.2962 9.2962 84.125 88.125
# 26
# 13.45 9.45 84.15 88.15
# 27
# ...

# %%
#Creating empty data frame for output timeseries for the storm
start_date='2020-05-14 00:00:00'
end_date='2020-05-20 12:00:00'
date_range=pd.date_range(start=start_date, end=end_date,freq="3h00min")
dset=pd.DataFrame(0,columns=['SLP'], index=date_range)
dset = dset.astype({'SLP':'float32'})

# %%
dset['SLP']=df1/100

# %%
dset['Vort1000']=df2
dset['wind10mn']=df3
dset['Vort925']=df4
dset['Vort850']=df5
dset['Vort700']=df6
dset['Vort600']=df7
dset['Vort500']=df8
dset['Vort400']=df9
dset['Vort300']=df10
dset['Dewtemp2m']=df11

# %%
dset['Temp2m']=df12
dset['Cape']=df13
dset['Convectppt']=df14
dset['Convectrrate']=df15
dset['Div200']=df16
dset['Div300']=df17
dset['Div400']=df18
dset['Div500']=df19
dset['DwnwardSWR']=df20
dset['Te200']=df21
dset['Te300']=df22
dset['Te400']=df23
dset['Te500']=df24
dset['Te600']=df25
dset['Te700']=df26
dset['Te850']=df27
dset['Te925']=df28
dset['Te1000']=df29

# %%
dset['VItemp']=df30
dset['VItotenrgy']=df31
dset['LSrrate']=df32
dset['Inst10mwind']=df33
dset['Instmoist']=df34
dset['InstSSH']=df35
dset['MnconvRrate']=df36
dset['MnLSrrate']=df37
dset['Mntotprate']=df38
dset['Shear850250']=df39
dset['Shear850200']=df40
dset['Shear925200']=df41
dset['Shear925250']=df42
dset['Pvor200']=df43
dset['Pvor300']=df44
dset['Pvor400']=df45
dset['Pvor500']=df46
dset['Pvor600']=df47
dset['Pvor700']=df48
dset['Pvor850']=df49
dset['Pvor925']=df50
dset['Pvor1000']=df51
dset['SST']=df52

# %%
dset['Rh200']=df53
dset['Rh300']=df54
dset['Rh400']=df55
dset['Rh500']=df56
dset['Rh600']=df57
dset['Rh700']=df58
dset['Rh850']=df59
dset['Rh925']=df60
dset['Rh1000']=df61
dset['Wstress']=df62
dset['T200']=df63
dset['T300']=df64
dset['T400']=df65
dset['T500']=df66
dset['T600']=df67
dset['T700']=df68
dset['T850']=df69
dset['T925']=df70
dset['T1000']=df71
dset['Totwtrvpr']=df72

# %%
dset['Gpot200']=df73
dset['Gpot300']=df74
dset['Gpot400']=df75
dset['Gpot500']=df76
dset['Gpot600']=df77
dset['Gpot700']=df78
dset['Gpot850']=df79
dset['Gpot925']=df80
dset['Gpot1000']=df81
dset['Surflhf']=df82
dset['Surflhfmn']=df83
dset['Surfshfmn']=df84
dset['Surflwrmn']=df85
dset['Surfswrmn']=df86
dset['Surfshf']=df87
dset['Toplwrmn']=df88
dset['Topswrmn']=df89
dset['Totcloudice']=df90
dset['Totcloudrain']=df91
dset['Totcloudwater']=df92
dset['Totsupercoolwtr']=df93

# %%
dset['VIcloudfrzwtr']=df94
dset['VIcloudliqwtr']=df95
dset['VIgpot']=df96
dset['VIKEflux']=df97
dset['VImassflux']=df98
dset['VImoistflux']=df99
dset['VIOLRflux']=df100
dset['VItotenergyflux']=df101
dset['VIKenergy']=df102
dset['VImeanMoistDiv']=df103
dset['VIMoistDiv']=df104
dset['VIOlr']=df105
dset['VIpot_int_latentenrgy']=df106
dset['VIpot_intenrgy']=df107

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53 entries, 2020-05-14 00:00:00 to 2020-05-20 12:00:00
# Freq: 3H
# Columns: 107 entries, SLP to VIpot_intenrgy
# dtypes: float64(107)
# memory usage: 44.7 KB

# %%
dset
# Out:
#                              SLP  Vort1000   wind10mn   Vort925   Vort850  \
# 2020-05-14 00:00:00  1005.116016  0.000037   4.449358  0.000042  0.000052
# 2020-05-14 03:00:00  1007.277969  0.000042   5.710608  0.000044  0.000050
# 2020-05-14 06:00:00  1006.614219  0.000050   5.727270  0.000053  0.000054
# 2020-05-14 09:00:00  1004.384063  0.000049   5.743377  0.000056  0.000056
# 2020-05-14 12:00:00  1004.290000  0.000041   4.461676  0.000048  0.000048
# 2020-05-14 15:00:00  1006.302500  0.000043   4.887439  0.000050  0.000050
# 2020-05-14 18:00:00  1005.298516  0.000046   4.609368  0.000053  0.000051
# 2020-05-14 21:00:00  1003.183750  0.000049   4.652966  0.000057  0.000054
# 2020-05-15 00:00:00  1003.482891  0.000048   4.882286  0.000056  0.000059
# 2020-05-15 03:00:00  1005.431719  0.000051   5.480096  0.000061  0.000061
# 2020-05-15 06:00:00  1004.432109  0.000056   6.715981  0.000071  0.000072
# 2020-05-15 09:00:00  1002.187969  0.000061   6.449786  0.000082  0.000079
# ...

# %%
dset['Toplwrmn'].plot()
# Out:
# <AxesSubplot:>

# %%
dset.to_csv('200km_107vars_amphan.csv')
