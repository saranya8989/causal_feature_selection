# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
p1='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/tracks_nio/'
path='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/tsready_data/nisarga/'

# %%
dm2=xr.open_mfdataset([path+'mslp_nisarga.nc',path+'sst_nisarga.nc',path+'vor1000_nisarga.nc',path+'vor925_nisarga.nc',
                     path+'vor850_nisarga.nc',path+'vor700_nisarga.nc',path+'vor600_nisarga.nc',path+'vor500_nisarga.nc',
                     path+'vor400_nisarga.nc',path+'vor300_nisarga.nc', path+'gpot200_nisarga.nc',
                     path+'gpot250_nisarga.nc',path+'gpot300_nisarga.nc',path+'gpot400_nisarga.nc',
                     path+'gpot500_nisarga.nc',path+'gpot600_nisarga.nc',path+'gpot700_nisarga.nc',
                     path+'gpot850_nisarga.nc',path+'gpot925_nisarga.nc',path+'gpot1000_nisarga.nc',path+'pvor200_nisarga.nc',
                     ])

# %%
dm2
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 1440, lat: 721, time: 44)
# Coordinates:
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 -90.0 -89.75 -89.5 -89.25 ... 89.25 89.5 89.75 90.0
#   * time     (time) datetime64[ns] 2020-01-07T18:00:00 ... 2020-06-03T09:00:00
# Data variables: (12/21)
#     pv200    (time, lat, lon) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#     slp      (time, lat, lon) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#     sst      (time, lat, lon) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#     vor1000  (time, lat, lon) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#     vor300   (time, lat, lon) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#     vor400   (time, lat, lon) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#     ...       ...
# ...

# %%
dm1=xr.open_mfdataset([path+'pvor250_nisarga.nc',path+'pvor300_nisarga.nc',path+'pvor400_nisarga.nc',
                     path+'pvor500_nisarga.nc',path+'pvor600_nisarga.nc',path+'pvor700_nisarga.nc',
                     path+'pvor850_nisarga.nc',path+'pvor925_nisarga.nc'])

# %%
dm2=xr.open_mfdataset([path+'rhum250_nisarga.nc',path+'rhum300_nisarga.nc',path+'rhum400_nisarga.nc',
                     path+'rhum500_nisarga.nc',path+'rhum600_nisarga.nc',path+'rhum700_nisarga.nc',
                     path+'rhum850_nisarga.nc',path+'rhum925_nisarga.nc',
                     path+'rhum1000_nisarga.nc'])

# %%
dm3=xr.open_mfdataset([path+'temp250_nisarga.nc',path+'temp300_nisarga.nc',path+'temp400_nisarga.nc',
                     path+'temp500_nisarga.nc',path+'temp600_nisarga.nc',path+'temp700_nisarga.nc',
                     path+'temp850_nisarga.nc',path+'temp925_nisarga.nc',
                     path+'temp1000_nisarga.nc',path+'temp200_nisarga.nc'])

# %%
test=xr.open_dataset(path+'gpot250_nisarga.nc')

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 280, lat: 120, time: 22)
# Coordinates:
#   * lon      (lon) float64 40.0 40.25 40.5 40.75 ... 109.0 109.2 109.5 109.8
#   * lat      (lat) float64 30.0 29.75 29.5 29.25 29.0 ... 1.25 1.0 0.75 0.5 0.25
#   * time     (time) datetime64[ns] 2020-05-31T18:00:00 ... 2020-06-03T09:00:00
# Data variables:
#     z250     (time, lat, lon) float32 ...
