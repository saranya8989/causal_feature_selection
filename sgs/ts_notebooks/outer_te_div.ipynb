# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
p1='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/'
path='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/new_ready/'
xtra='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/data/storms2017/'

# %%
dm1=xr.open_mfdataset([path+'te200_wp2016haima.nc',path+'te250_wp2016haima.nc',path+'te300_wp2016haima.nc',path+'te400_wp2016haima.nc',
                       path+'te500_wp2016haima.nc',path+'te600_wp2016haima.nc',path+'te700_wp2016haima.nc',path+'te850_wp2016haima.nc',
                       path+'te925_wp2016haima.nc',path+'te1000_wp2016haima.nc',path+'div100_wp2016haima.nc',path+'div200_wp2016haima.nc',path+'div250_wp2016haima.nc',path+'div300_wp2016haima.nc',path+'div400_wp2016haima.nc',
                       path+'div500_wp2016haima.nc',path+'wstress10_wp2016haima.nc',path+'w10_wp2016haima.nc',path+'sh850_200_wp2016haima.nc',path+'sh850_250_wp2016haima.nc',
                       path+'sh925_200_wp2016haima.nc',path+'sh925_250_wp2016haima.nc'
                     ])

# %%
dm1
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 320, lon: 600, time: 69)
# Coordinates:
#   * time       (time) datetime64[ns] 2016-10-14T06:00:00 ... 2016-10-22T18:00:00
#   * lon        (lon) float64 30.0 30.25 30.5 30.75 ... 179.0 179.2 179.5 179.8
#   * lat        (lat) float64 -19.75 -19.5 -19.25 -19.0 ... 59.25 59.5 59.75 60.0
# Data variables:
#     div100     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     div200     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     div250     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     div300     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     div400     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     div500     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt1000    (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt200     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt250     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt300     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt400     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt500     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt600     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt700     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt850     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     eqt925     (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     sh850_200  (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     sh850_250  (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     sh925_200  (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     sh925_250  (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     ws10       (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     wstrss10   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>

# %% [markdown]
# #

# %% [markdown]
# #

# %%
vname0=["div100","div200","div250","div300","div400","div500","eqt1000","eqt200","eqt250","eqt300",
        "eqt400","eqt500","eqt600","eqt700","eqt850","eqt925","sh850_200","sh850_250","sh925_200","sh925_250","ws10","wstrss10"]

# %%
vname=["out_div100","out_div200","out_div250","out_div300","out_div400","out_div500","out_eqt1000","out_eqt200","out_eqt250","out_eqt300",
        "out_eqt400","out_eqt500","out_eqt600","out_eqt700","out_eqt850","out_eqt925","out_sh850_200","out_sh850_250","out_sh925_200","out_sh925_250","out_ws10","out_wstrss10"]

# %%
dm0=xr.open_mfdataset([path+'vor1000_wp2016haima.nc',path+'vor925_wp2016haima.nc',
                     path+'vor850_wp2016haima.nc',path+'vor700_wp2016haima.nc',path+'vor600_wp2016haima.nc',path+'vor500_wp2016haima.nc',
                     path+'vor400_wp2016haima.nc',path+'vor300_wp2016haima.nc'                     
                     ])

# %%
dm0
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 600, time: 69)
# Coordinates:
#   * time     (time) datetime64[ns] 2016-10-14T06:00:00 ... 2016-10-22T18:00:00
#   * lon      (lon) float64 30.0 30.25 30.5 30.75 ... 179.0 179.2 179.5 179.8
#   * lat      (lat) float64 60.0 59.75 59.5 59.25 ... -19.0 -19.25 -19.5 -19.75
#     plev     float64 ...
# Data variables:
#     vor1000  (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor300   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor400   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor500   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor600   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor700   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor850   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>
#     vor925   (time, lat, lon) float32 dask.array<chunksize=(69, 320, 600), meta=np.ndarray>

# %%
track=pd.read_csv(p1+'wp/nwp_20161014.csv',delimiter=r",")
lon1=track['lon'].to_numpy()
lat1=track['lat'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)
pos.shape
# Out:
# (69, 2)

# %%
tc_irad=np.empty((pos.shape[0],4))
tc_irad[:,0] = pos[:,0]-2
tc_irad[:,1] = pos[:,0]+2
tc_irad[:,2] = pos[:,1]-2
tc_irad[:,3] = pos[:,1]+2

tc_orad=np.empty((pos.shape[0],4))
tc_orad[:,0] = pos[:,0]-8
tc_orad[:,1] = pos[:,0]+8
tc_orad[:,2] = pos[:,1]-8
tc_orad[:,3] = pos[:,1]+8

# %%
dsh=np.zeros((pos.shape[0],64,64))
dvor00=np.zeros((pos.shape[0],64,64))
dd200=np.zeros((pos.shape[0],64,64))
dd250=np.zeros((pos.shape[0],64,64))
dd300=np.zeros((pos.shape[0],64,64))
dd400=np.zeros((pos.shape[0],64,64))
dd500=np.zeros((pos.shape[0],64,64))
de1000=np.zeros((pos.shape[0],64,64))
de200=np.zeros((pos.shape[0],64,64))
de250=np.zeros((pos.shape[0],64,64))
de300=np.zeros((pos.shape[0],64,64))
de400=np.zeros((pos.shape[0],64,64))
de500=np.zeros((pos.shape[0],64,64))
de600=np.zeros((pos.shape[0],64,64))
de700=np.zeros((pos.shape[0],64,64))
de850=np.zeros((pos.shape[0],64,64))
de925=np.zeros((pos.shape[0],64,64))
ds850_200=np.zeros((pos.shape[0],64,64))
ds850_250=np.zeros((pos.shape[0],64,64))
ds925_200=np.zeros((pos.shape[0],64,64))
ds925_250=np.zeros((pos.shape[0],64,64))
dw10m=np.zeros((pos.shape[0],64,64))
dstrss10m=np.zeros((pos.shape[0],64,64))

# %%
tc_orad
# Out:
# array([[-8.000000e-01,  1.520000e+01,  1.372000e+02,  1.532000e+02],
#        [-8.275100e-01,  1.517249e+01,  1.370280e+02,  1.530280e+02],
#        [-7.600000e-01,  1.524000e+01,  1.366600e+02,  1.526600e+02],
#        [-4.899500e-01,  1.551005e+01,  1.362840e+02,  1.522840e+02],
#        [-9.091000e-02,  1.590909e+01,  1.359360e+02,  1.519360e+02],
#        [ 2.806600e-01,  1.628066e+01,  1.355920e+02,  1.515920e+02],
#        [ 6.000000e-01,  1.660000e+01,  1.352330e+02,  1.512330e+02],
#        [ 8.842800e-01,  1.688428e+01,  1.348190e+02,  1.508190e+02],
#        [ 1.150000e+00,  1.715000e+01,  1.343250e+02,  1.503250e+02],
#        [ 1.415670e+00,  1.741567e+01,  1.337450e+02,  1.497450e+02],
#        [ 1.625000e+00,  1.762500e+01,  1.331500e+02,  1.491500e+02],
#        [ 1.729390e+00,  1.772939e+01,  1.325900e+02,  1.485900e+02],
#        [ 1.800000e+00,  1.780000e+01,  1.321250e+02,  1.481250e+02],
#        [ 1.908010e+00,  1.790801e+01,  1.318010e+02,  1.478010e+02],
#        [ 2.050000e+00,  1.805000e+01,  1.315750e+02,  1.475750e+02],
#        [ 2.206800e+00,  1.820680e+01,  1.313860e+02,  1.473860e+02],
#        [ 2.450000e+00,  1.845000e+01,  1.312000e+02,  1.472000e+02],
#        [ 2.821200e+00,  1.882120e+01,  1.309750e+02,  1.469750e+02],
#        [ 3.275000e+00,  1.927500e+01,  1.306750e+02,  1.466750e+02],
#        [ 3.761200e+00,  1.976120e+01,  1.302860e+02,  1.462860e+02],
#        [ 4.225000e+00,  2.022500e+01,  1.298000e+02,  1.458000e+02],
#        [ 4.601900e+00,  2.060190e+01,  1.292270e+02,  1.452270e+02],
#        [ 4.900000e+00,  2.090000e+01,  1.286250e+02,  1.446250e+02],
#        [ 5.127400e+00,  2.112740e+01,  1.280780e+02,  1.440780e+02],
#        [ 5.325000e+00,  2.132500e+01,  1.275500e+02,  1.435500e+02],
#        [ 5.549200e+00,  2.154920e+01,  1.270300e+02,  1.430300e+02],
#        [ 5.800000e+00,  2.180000e+01,  1.265000e+02,  1.425000e+02],
#        [ 6.099900e+00,  2.209990e+01,  1.259380e+02,  1.419380e+02],
#        [ 6.400000e+00,  2.240000e+01,  1.253500e+02,  1.413500e+02],
#        [ 6.644800e+00,  2.264480e+01,  1.247560e+02,  1.407560e+02],
#        [ 6.875000e+00,  2.287500e+01,  1.241250e+02,  1.401250e+02],
#        [ 7.143500e+00,  2.314350e+01,  1.234570e+02,  1.394570e+02],
#        [ 7.375000e+00,  2.337500e+01,  1.227250e+02,  1.387250e+02],
#        [ 7.495000e+00,  2.349500e+01,  1.219090e+02,  1.379090e+02],
#        [ 7.600000e+00,  2.360000e+01,  1.210750e+02,  1.370750e+02],
#        [ 7.812700e+00,  2.381270e+01,  1.203050e+02,  1.363050e+02],
#        [ 8.000000e+00,  2.400000e+01,  1.195500e+02,  1.355500e+02],
#        [ 8.006200e+00,  2.400620e+01,  1.187570e+02,  1.347570e+02],
#        [ 8.050000e+00,  2.405000e+01,  1.180000e+02,  1.340000e+02],
#        [ 8.333200e+00,  2.433320e+01,  1.173480e+02,  1.333480e+02],
#        [ 8.700000e+00,  2.470000e+01,  1.167000e+02,  1.327000e+02],
#        [ 9.012900e+00,  2.501290e+01,  1.159620e+02,  1.319620e+02],
#        [ 9.300000e+00,  2.530000e+01,  1.151750e+02,  1.311750e+02],
#        [ 9.535600e+00,  2.553560e+01,  1.143510e+02,  1.303510e+02],
#        [ 9.775000e+00,  2.577500e+01,  1.135500e+02,  1.295500e+02],
#        [ 1.008150e+01,  2.608150e+01,  1.128400e+02,  1.288400e+02],
#        [ 1.040000e+01,  2.640000e+01,  1.121750e+02,  1.281750e+02],
#        [ 1.065970e+01,  2.665970e+01,  1.115140e+02,  1.275140e+02],
#        [ 1.095000e+01,  2.695000e+01,  1.108500e+02,  1.268500e+02],
#        [ 1.133830e+01,  2.733830e+01,  1.101150e+02,  1.261150e+02],
#        [ 1.177500e+01,  2.777500e+01,  1.094500e+02,  1.254500e+02],
#        [ 1.218020e+01,  2.818020e+01,  1.089850e+02,  1.249850e+02],
#        [ 1.265000e+01,  2.865000e+01,  1.086000e+02,  1.246000e+02],
#        [ 1.324500e+01,  2.924500e+01,  1.081480e+02,  1.241480e+02],
#        [ 1.390000e+01,  2.990000e+01,  1.077250e+02,  1.237250e+02],
#        [ 1.453930e+01,  3.053930e+01,  1.073530e+02,  1.233530e+02],
#        [ 1.517500e+01,  3.117500e+01,  1.070750e+02,  1.230750e+02],
#        [ 1.577800e+01,  3.177800e+01,  1.068600e+02,  1.228600e+02],
#        [ 1.640670e+01,  3.240670e+01,  1.068200e+02,  1.228200e+02],
#        [ 1.709800e+01,  3.309800e+01,  1.070030e+02,  1.230030e+02],
#        [ 1.782500e+01,  3.382500e+01,  1.074080e+02,  1.234080e+02],
#        [ 1.862280e+01,  3.462280e+01,  1.078730e+02,  1.238730e+02],
#        [ 1.941110e+01,  3.541110e+01,  1.085330e+02,  1.245330e+02],
#        [ 2.012160e+01,  3.612160e+01,  1.097030e+02,  1.257030e+02],
#        [ 2.080000e+01,  3.680000e+01,  1.111000e+02,  1.271000e+02],
#        [ 2.158040e+01,  3.758040e+01,  1.121490e+02,  1.281490e+02],
#        [ 2.220000e+01,  3.820000e+01,  1.131430e+02,  1.291430e+02],
#        [ 2.248530e+01,  3.848530e+01,  1.140880e+02,  1.300880e+02],
#        [ 2.250000e+01,  3.850000e+01,  1.151000e+02,  1.311000e+02]])

# %%
lonselect = dm0.lon.sel(lon=slice(tc_orad[0,:][2],tc_orad[0,:][3])).data
latselect = np.flipud(dm0.lat.sel(lat=slice(tc_orad[0,:][1],tc_orad[0,:][0])).data)
lon2d,lat2d = np.meshgrid(lonselect,latselect)

# %%
def createmask(irad=None):
    mask = []
    for ti in range(len(tc_irad)):
        lonselect = dm0.lon.sel(lon=slice(tc_orad[ti,:][2],tc_orad[ti,:][3])).data
        latselect = np.flipud(dm0.lat.sel(lat=slice(tc_orad[ti,:][1],tc_orad[ti,:][0])).data)
        if (lonselect.shape != 64) or (latselect.shape != 64):
            lon2d,lat2d = np.meshgrid(lonselect[0:64],latselect[0:64])
        else:
            lon2d,lat2d = np.meshgrid(lonselect,latselect)
        #############################################################################################
        latcriteria = np.logical_and(lat2d>irad[ti][0],lat2d<irad[ti][1])
        loncriteria = np.logical_and(lon2d>irad[ti][2],lon2d<irad[ti][3])
        allcriteria = np.logical_and(loncriteria,latcriteria)
        mask.append(allcriteria)

    return mask
mymask = createmask(irad=tc_irad)

# %%
import matplotlib.pyplot as plt
plt.pcolormesh(mymask[0])

# %%
for it in range(tc_orad.shape[0]):
    latn, lats, lone, lonw = tc_orad[it,:]
    #test.append(dm.slp[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)))
    dd100[it,:,:]=dm1.div100[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dd200[it,:,:]=dm1.div200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dd250[it,:,:]=dm1.div250[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dd300[it,:,:]=dm1.div300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dd400[it,:,:]=dm1.div400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dd500[it,:,:]=dm1.div500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de1000[it,:,:]=dm1.eqt1000[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de200[it,:,:]=dm1.eqt200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de250[it,:,:]=dm1.eqt250[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de300[it,:,:]=dm1.eqt300[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de400[it,:,:]=dm1.eqt400[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de500[it,:,:]=dm1.eqt500[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de600[it,:,:]=dm1.eqt600[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de700[it,:,:]=dm1.eqt700[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de850[it,:,:]=dm1.eqt850[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    de925[it,:,:]=dm1.eqt925[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    ds850_200[it,:,:]=dm1.sh850_200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]   
    ds850_250[it,:,:]=dm1.sh850_250[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    ds925_200[it,:,:]=dm1.sh925_200[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    ds925_250[it,:,:]=dm1.sh925_250[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dw10m[it,:,:]=dm1.ws10[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]
    dstrss10m[it,:,:]=dm1.wstrss10[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:64,0:64]

# %%
#To loop over the variables to get the annular values before averaging them
varlist = [dd100,dd200,dd250,dd300,dd400,dd500,de1000,de200,de250,de300,de400,de500,
           de600,de700,de850,de925,ds850_200,ds850_250,ds925_200,ds925_250,dw10m,dstrss10m]
tempdict = {}
for ind,obj in enumerate(varlist):
    templist = [obj[i,...][~mymask[i]] for i in range(len(mymask))]
    tempdict[vname[ind]] = templist

# %%
out_timeseries_dict = {}
for ind,obj in enumerate(vname):
    out_timeseries_dict[obj] = [np.nanmean(obj) for obj in tempdict[obj]]

# %%
out_ts=pd.DataFrame.from_dict(out_timeseries_dict)

# %%
out_ts
# Out:
#       out_div100  out_div200  out_div250    out_div300    out_div400  \
# 0   8.946957e-06    0.000011    0.000007  1.156859e-06 -1.332785e-06
# 1   1.336151e-05    0.000012    0.000005 -6.294133e-09 -2.432066e-06
# 2   1.457065e-05    0.000016    0.000008  2.973615e-07 -2.683609e-06
# 3   1.159503e-05    0.000015    0.000008  1.609930e-07 -1.773632e-06
# 4   1.028928e-05    0.000013    0.000006 -6.244606e-07 -1.427634e-07
# ..           ...         ...         ...           ...           ...
# 64  2.755902e-06    0.000002    0.000003  4.047246e-06 -3.256438e-07
# 65  1.903494e-06    0.000003    0.000003  4.201310e-06 -8.061623e-07
# 66 -7.163049e-07    0.000004    0.000003  3.131668e-06 -1.075570e-06
# 67  5.150529e-07    0.000003    0.000004  2.406542e-06 -2.474511e-06
# 68  8.618405e-07    0.000003    0.000004  3.278186e-06 -2.035574e-06
#
#       out_div500  out_eqt1000  out_eqt200  out_eqt250  out_eqt300  ...  \
# 0  -1.129752e-06   332.085799  352.541479  350.154173  348.277512  ...
# 1  -2.397869e-06   332.124613  352.227042  350.130235  348.252895  ...
# 2  -2.931298e-06   334.039459  351.623381  350.081720  348.494149  ...
# 3  -2.004407e-06   334.447430  351.148019  349.778797  348.297046  ...
# 4  -9.481931e-07   334.531559  350.775560  349.574607  348.192367  ...
# ..           ...          ...         ...         ...         ...  ...
# 64 -1.732153e-07   309.109647  354.552865  351.127880  347.677244  ...
# 65 -1.592724e-06   305.730833  354.368424  350.877583  347.251886  ...
# 66 -2.264163e-06   303.406519  354.247072  350.459382  346.226147  ...
# 67 -3.131807e-06   301.624989  353.972408  349.871987  345.622150  ...
# 68 -2.926370e-06   300.223955  353.685145  349.320324  345.143027  ...
#
#     out_eqt600  out_eqt700  out_eqt850  out_eqt925  out_sh850_200  \
# 0   336.373102  296.178087  287.260086  309.797125      12.384300
# 1   336.346778  315.252009  322.855557  325.466730      11.992113
# 2   336.859133  326.835059  325.976859  290.710328      13.382218
# 3   336.583025  332.095387  300.216188  317.134182      13.977929
# 4   336.366540  333.211303  305.814607  324.762660      14.417921
# ..         ...         ...         ...         ...            ...
# 64  333.614151  297.947766  326.668790  327.004817      21.747621
# 65  332.822551  300.863649  290.873818  300.453326      24.325791
# 66  331.973872  318.107283  312.399360  310.420097      25.633423
# 67  331.319833  327.185161  327.977330  326.490552      27.138010
# 68  330.884923  333.281032  317.501151  289.040728      28.012658
#
#     out_sh850_250  out_sh925_200  out_sh925_250  out_ws10  out_wstrss10
# 0       10.036982      12.459119      10.057690  5.582252      0.870831
# 1        9.593049      12.048200       9.610240  5.561117      0.867534
# 2       10.123175      13.356751      10.150284  5.387242      0.840410
# 3       10.821115      13.897672      10.804197  5.590555      0.872127
# 4       11.282069      14.313917      11.211405  5.695466      0.888493
# ..            ...            ...            ...       ...           ...
# 64      20.391470      23.027145      21.724356  5.333671      0.832053
# 65      22.881971      26.012766      24.597039  5.482505      0.855271
# 66      24.498881      27.270075      26.191902  5.193518      0.810189
# 67      26.072775      29.067620      28.076956  5.719486      0.892240
# 68      27.070634      30.026894      29.121163  6.184979      0.964857
#
# [69 rows x 22 columns]

# %%
out_ts.to_csv(p1+'time_series/outder_2016_nwp_haima.csv')
