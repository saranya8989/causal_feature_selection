# %%
from tqdm.auto import tqdm 
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline
import glob
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
output="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/"
final="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/tigramite_timeseries/"
target="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/targets/"
fall='/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/timeseries_csv/ts_wp'
path="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/besttracks/"

# %%
# !ls /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/besttracks/*2009*
# Out:
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/besttracks/2009_wp_storms.csv

# %%
track = sorted(glob.glob(path+'*2003*.csv'))

# %%
#tapah nuri hagupit

# %%
tracksDF = pd.read_csv(track[0])
tracksDF['name'].unique()
stormnames = list(tracksDF['name'].unique())

# %%
stormnames
# Out:
# ['YANYAN',
#  'KUJIRA',
#  'CHAN-HOM',
#  'LINFA',
#  'NANGKA',
#  'SOUDELOR',
#  'IMBUDO',
#  'KONI',
#  'ETAU',
#  'KROVANH',
#  'DUJUAN',
#  'MAEMI',
#  'CHOI-WAN',
#  'KOPPU',
#  'KETSANA',
#  'PARMA',
#  'MELOR',
#  'NEPARTAK',
#  'LUPIT']

# %%
path="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/besttracks/"

# %%
# !ls /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/*2003_*KUJIRA*
# Out:
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_eqtlevs_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_innerlevs_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_outerdiv_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_outereqt_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_outerlevs_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_outerradvar_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_outerslvars_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_outpresstvar_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_pmin_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_presstvar_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_radvar_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_slvars_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2003_wmax_wpac_KUJIRA.csv
# /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/shears_wpouter_2003_KUJIRA.csv

# %%
maincs=pd.read_csv(output+'2003_outerlevs_wpac_KUJIRA.csv',delimiter=r",")
maincs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
maincs=maincs.drop('a', axis=1)

idiv_cs=pd.read_csv(output+'2003_innerlevs_wpac_KUJIRA.csv',delimiter=r",")
idiv_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
idiv_cs=idiv_cs.drop('a', axis=1)

sh_cs=pd.read_csv(output+'shears_wpouter_2003_KUJIRA.csv',delimiter=r",")
sh_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
sh_cs=sh_cs.drop('a', axis=1)

eq_cs=pd.read_csv(output+'2003_eqtlevs_wpac_KUJIRA.csv',delimiter=r",")
eq_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
eq_cs=eq_cs.drop('a', axis=1)

oeq_cs=pd.read_csv(output+'2003_outereqt_wpac_KUJIRA.csv',delimiter=r",")
oeq_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
oeq_cs=oeq_cs.drop('a', axis=1)

sl_cs=pd.read_csv(output+'2003_slvars_wpac_KUJIRA.csv',delimiter=r",")
sl_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
sl_cs=sl_cs.drop('a', axis=1)

osl_cs=pd.read_csv(output+'2003_outerslvars_wpac_KUJIRA.csv',delimiter=r",")
osl_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
osl_cs=osl_cs.drop('a', axis=1)

rl_cs=pd.read_csv(output+'2003_radvar_wpac_KUJIRA.csv',delimiter=r",")
rl_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
rl_cs=rl_cs.drop('a', axis=1)


orl_cs=pd.read_csv(output+'2003_outerradvar_wpac_KUJIRA.csv',delimiter=r",")
orl_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
orl_cs=orl_cs.drop('a', axis=1)

psst_cs=pd.read_csv(output+'2003_presstvar_wpac_KUJIRA.csv',delimiter=r",")
psst_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
psst_cs=psst_cs.drop('a', axis=1)

opsst_cs=pd.read_csv(output+'2003_outpresstvar_wpac_KUJIRA.csv',delimiter=r",")
opsst_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
opsst_cs=opsst_cs.drop('a', axis=1)

div_cs=pd.read_csv(output+'2003_outerdiv_wpac_KUJIRA.csv',delimiter=r",")
div_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
div_cs=div_cs.drop('a', axis=1)

pmin_cs=pd.read_csv(output+'2003_pmin_wpac_KUJIRA.csv',delimiter=r",")
pmin_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
pmin_cs=pmin_cs.drop('a', axis=1)

wmax_cs=pd.read_csv(output+'2003_wmax_wpac_KUJIRA.csv',delimiter=r",")
wmax_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
wmax_cs=wmax_cs.drop('a', axis=1)

# %%
sh_cs
# Out:
#     shear_1000_200  shear_1000_300  shear_1000_500  shear_1000_700  \
# 0        15.414655       11.089908        8.575887        7.767155
# 1        15.355224       10.720122        8.655046        8.016512
# 2        14.108584        9.645685        8.031597        7.760870
# 3        13.611683        9.464828        8.778673        8.153804
# 4        13.308998        9.466405        9.517409        8.494192
# ..             ...             ...             ...             ...
# 78       24.676618       17.973763       13.342415        8.616546
# 79       25.606857       19.158084       14.226659        8.966529
# 80       26.419152       20.266147       15.230406        9.053819
# 81       26.027533       20.244624       15.542248        8.542821
# 82       25.606239       20.025493       15.562257        8.042738
#
#     shear_1000_850  shear_850_200  shear_850_250  shear_850_300  \
# 0         5.615848      17.167315      15.626753      12.626780
# 1         5.483966      16.823509      15.289608      12.164767
# 2         4.617136      15.262343      13.652603      10.511506
# 3         4.349713      14.621154      12.926131      10.188369
# 4         4.220209      13.910971      12.194225       9.929046
# ..             ...            ...            ...            ...
# 78        4.271203      22.242578      18.285348      15.845129
# 79        4.455704      22.778148      18.753843      16.401979
# 80        4.464279      23.491039      19.275096      17.272465
# 81        4.384658      23.152867      19.190270      17.297240
# 82        3.917284      23.373243      19.641609      17.494807
#
#     shear_850_500  shear_925_200  shear_925_250
# 0        7.745542      16.753165      15.290136
# 1        7.664875      16.497790      14.940152
# 2        6.845461      15.023236      13.408222
# 3        7.042551      14.531260      12.862745
# 4        7.485897      14.183126      12.446725
# ..            ...            ...            ...
# 78      10.789497      24.319890      20.213691
# 79      11.225001      25.215962      21.216371
# 80      11.882530      26.038709      22.009965
# 81      12.248056      25.597919      21.820157
# 82      12.534523      25.274428      21.897124
#
# [83 rows x 11 columns]

# %%
pmin_cs=pmin_cs/100

# %%
p=pmin_cs.rename(columns={"mslp": "pmin"})

# %%
div=idiv_cs.iloc[:,:13]
innerlevs=idiv_cs.iloc[:,13:]

# %%
innerlevs.drop(['vor_10', 'vor_20','vor_30','vor_50','vor_70',\
              'rh_10', 'rh_20','rh_30','rh_50','rh_70',\
              'gpot_10', 'gpot_20','gpot_30','gpot_50','gpot_70',\
              'vvel_10', 'vvel_20','vvel_30','vvel_50','vvel_70',\
                'temp_10', 'temp_20','temp_30','temp_50','temp_70',\
                'temp_100', 'temp_150','temp_200','temp_250','temp_300',\
                'temp_400', 'temp_500','temp_600','temp_700','temp_800',\
                'temp_850', 'temp_900','temp_925','temp_950','temp_975','temp_1000'],axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_2893694/3139884359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   innerlevs.drop(['vor_10', 'vor_20','vor_30','vor_50','vor_70',\

# %%
innerlevs=innerlevs.rename(columns={"vor_100": "vort_100","vor_150": "vort_150","vor_200": "vort_200","vor_250": "vort_250",\
                         "vor_300": "vort_300","vor_400": "vort_400","vor_500": "vort_500","vor_600": "vort_600",\
                         "vor_700": "vort_700","vor_850": "vort_850","vor_800": "vort_800","vor_900": "vort_900",\
                         "vor_925": "vort_925","vor_950": "vort_950","vor_975": "vort_975","vor_1000": "vort_1000",\
                          "rh_100": "rhum_100","rh_150": "rhum_150","rh_200": "rhum_200","rh_250": "rhum_250",\
                         "rh_300": "rhum_300","rh_400": "rhum_400","rh_500": "rhum_500","rh_600": "rhum_600",\
                         "rh_700": "rhum_700","rh_850": "rhum_850","rh_800": "rhum_800","rh_900": "rhum_900",\
                         "rh_925": "rhum_925","rh_950": "rhum_950","rh_975": "rhum_975","rh_1000": "rhum_1000"
                         })

# %%
maincs.drop(['outvort_10', 'outvort_20','outvort_30','outvort_50','outvort_70',\
              'outrhum_10', 'outrhum_20','outrhum_30','outrhum_50','outrhum_70',\
              'outgpot_10', 'outgpot_20','outgpot_30','outgpot_50','outgpot_70',\
              'outvvel_10', 'outvvel_20','outvvel_30','outvvel_50','outvvel_70',\
                'outtemp_10', 'outtemp_20','outtemp_30','outtemp_50','outtemp_70',\
                'outtemp_100', 'outtemp_150','outtemp_200','outtemp_250','outtemp_300',\
                'outtemp_400', 'outtemp_500','outtemp_600','outtemp_700','outtemp_800',\
                'outtemp_850', 'outtemp_900','outtemp_925','outtemp_950','outtemp_975','outtemp_1000'],axis = 1, inplace = True)

# %%
maincs
# Out:
#     outvort_100   outvort_150   outvort_200   outvort_250  outvort_300  \
# 0     -0.000005 -3.399335e-06  7.073201e-07  1.009018e-06     0.000002
# 1     -0.000007 -3.128347e-06  2.123831e-06  2.567501e-07     0.000001
# 2     -0.000007 -8.629771e-07  3.551890e-06  2.760211e-06     0.000004
# 3     -0.000005 -4.275896e-07  3.188041e-06  3.107261e-06     0.000004
# 4     -0.000003  7.632701e-07  3.309914e-06  3.399924e-06     0.000005
# ..          ...           ...           ...           ...          ...
# 78    -0.000032 -3.896539e-05 -3.866192e-05 -3.632749e-05    -0.000030
# 79    -0.000034 -3.864175e-05 -3.914242e-05 -3.751492e-05    -0.000033
# 80    -0.000034 -3.912093e-05 -3.811864e-05 -3.876437e-05    -0.000035
# 81    -0.000032 -3.940777e-05 -3.758156e-05 -3.682127e-05    -0.000034
# 82    -0.000031 -3.897969e-05 -3.681539e-05 -3.522327e-05    -0.000034
#
#     outvort_400  outvort_500  outvort_600  outvort_700  outvort_800  ...  \
# 0      0.000004     0.000007     0.000008     0.000008     0.000010  ...
# 1      0.000005     0.000008     0.000008     0.000010     0.000010  ...
# 2      0.000008     0.000008     0.000007     0.000010     0.000009  ...
# 3      0.000008     0.000008     0.000008     0.000010     0.000009  ...
# 4      0.000009     0.000010     0.000009     0.000010     0.000010  ...
# ..          ...          ...          ...          ...          ...  ...
# 78    -0.000031    -0.000021    -0.000014    -0.000009    -0.000005  ...
# 79    -0.000035    -0.000022    -0.000015    -0.000011    -0.000007  ...
# 80    -0.000036    -0.000024    -0.000017    -0.000012    -0.000009  ...
# 81    -0.000036    -0.000024    -0.000020    -0.000013    -0.000010  ...
# 82    -0.000038    -0.000025    -0.000020    -0.000013    -0.000010  ...
#
#     outvvel_250  outvvel_300  outvvel_400  outvvel_500  outvvel_600  \
# 0     -0.208709    -0.241519    -0.220832    -0.161443    -0.097979
# 1     -0.187291    -0.212757    -0.175046    -0.120804    -0.055332
# 2     -0.139770    -0.167310    -0.154599    -0.106105    -0.040040
# 3     -0.116320    -0.143047    -0.126737    -0.074571    -0.012507
# 4     -0.099439    -0.123610    -0.103201    -0.053806    -0.006793
# ..          ...          ...          ...          ...          ...
# 78     0.010564     0.015983    -0.005819    -0.007536    -0.014849
# 79     0.011344     0.024478     0.014955     0.021683     0.014733
# 80     0.007852     0.017294     0.010923     0.029959     0.033638
# 81     0.011128     0.018056     0.003691     0.017243     0.026781
# 82     0.002514     0.013072    -0.008456    -0.000689     0.012400
#
#     outvvel_700  outvvel_850  outvvel_925  outvvel_975  outvvel_1000
# 0     -0.040143     0.010744     0.017661     0.018052      0.018292
# 1     -0.006126     0.006973     0.004567     0.003643      0.004165
# 2     -0.010793    -0.013269    -0.015897    -0.019411     -0.020592
# 3      0.009974     0.002740    -0.005848    -0.008548     -0.008020
# 4      0.015602     0.025240     0.018433     0.015825      0.017228
# ..          ...          ...          ...          ...           ...
# 78    -0.028541    -0.038530    -0.027033    -0.019091     -0.014726
# 79    -0.000429    -0.015066    -0.015904    -0.015940     -0.015140
# 80     0.033890     0.032444     0.025813     0.017563      0.014507
# 81     0.037709     0.037194     0.030804     0.023377      0.020178
# 82     0.023643     0.024271     0.015564     0.006258      0.001889
#
# [83 rows x 61 columns]

# %%
sl_cs.drop(['u10', 'v10','vi_div_gpot_flux','vi_div_ke_flux','vi_div_olr_flux',\
              'vi_ke', 'vi_temp'],axis = 1, inplace = True)
rl_cs.drop(['inst_10m_wnd_gst', 'surfmean_swr_flux','surfmean_lwr_flux','topmean_lwr_flux','topmean_swr_flux',\
              'dwnwrdmean_swr_flux'],axis = 1, inplace = True)

# %%
osl_cs.drop(['outu10', 'outv10','outvi_div_gpot_flux','outvi_div_ke_flux','outvi_div_olr_flux',\
              'outvi_ke', 'outvi_temp'],axis = 1, inplace = True)
orl_cs.drop(['outinst_10m_wnd_gst', 'outsurfmean_swr_flux','outsurfmean_lwr_flux','outtopmean_lwr_flux','outtopmean_swr_flux',\
              'outdwnwrdmean_swr_flux'],axis = 1, inplace = True)

# %%
psst_cs.drop(['mn_mslp'],axis = 1, inplace = True)

# %%
eq_cs.drop(['eqt800'],axis = 1, inplace = True)
oeq_cs.drop(['outeqt800'],axis = 1, inplace = True)

# %%
opsst_cs.drop(['outmslp'],axis = 1, inplace = True)

# %%
stormnames
# Out:
# ['YANYAN',
#  'KUJIRA',
#  'CHAN-HOM',
#  'LINFA',
#  'NANGKA',
#  'SOUDELOR',
#  'IMBUDO',
#  'KONI',
#  'ETAU',
#  'KROVANH',
#  'DUJUAN',
#  'MAEMI',
#  'CHOI-WAN',
#  'KOPPU',
#  'KETSANA',
#  'PARMA',
#  'MELOR',
#  'NEPARTAK',
#  'LUPIT']

# %%
product=pd.concat([p,wmax_cs,div,eq_cs,sl_cs,rl_cs,psst_cs,innerlevs,div_cs,oeq_cs,osl_cs,orl_cs,opsst_cs,maincs,sh_cs], axis=1, join='inner')

# %%
product
# Out:
#            pmin     wind10        div_50       div_100       div_200  \
# 0   1005.613750  14.499000  5.619106e-06  4.581682e-05  1.488777e-05
# 1   1006.878125  14.869414  1.299991e-05  3.051775e-05  2.475979e-05
# 2   1005.135000  14.577867  7.477618e-06  3.564480e-05  1.696590e-05
# 3   1001.985625  15.136902 -2.505258e-07  3.672950e-05  2.435781e-05
# 4   1002.987500  16.976795 -8.317875e-06  3.533129e-05  2.310309e-05
# ..          ...        ...           ...           ...           ...
# 78  1009.700625  11.574636 -1.063925e-05 -5.924376e-06 -4.508765e-07
# 79  1007.660625  12.066852 -6.068090e-06 -4.590838e-07  3.474706e-06
# 80  1007.905000  11.789174  3.444555e-06  4.924892e-06  5.075766e-06
# 81  1009.788125  10.881208  3.885187e-06  8.652278e-06 -2.542627e-06
# 82  1010.849375  10.034472  7.970491e-06  3.584079e-06  2.224755e-06
#
#          div_250   div_300       div_400   div_500   div_600  ...  \
# 0   1.583155e-05  0.000014 -9.464449e-06 -0.000017 -0.000006  ...
# 1   2.070982e-05  0.000012 -6.133865e-06 -0.000013 -0.000001  ...
# 2   2.031622e-05  0.000015 -6.752554e-06 -0.000012 -0.000001  ...
# 3   3.122014e-05  0.000019 -2.064346e-05 -0.000020 -0.000003  ...
# 4   1.888489e-05  0.000003 -4.124665e-05 -0.000029 -0.000001  ...
# ..           ...       ...           ...       ...       ...  ...
# 78 -3.577443e-07 -0.000015 -3.681052e-07  0.000004  0.000001  ...
# 79  8.773059e-07 -0.000009 -1.577602e-06  0.000003 -0.000002  ...
# 80  1.370499e-06  0.000003  2.891524e-06 -0.000002 -0.000004  ...
# 81  6.903894e-06  0.000010 -1.419103e-07 -0.000003 -0.000003  ...
# 82  1.655472e-05  0.000006 -8.894422e-06 -0.000003  0.000004  ...
#
#     shear_1000_300  shear_1000_500  shear_1000_700  shear_1000_850  \
# 0        11.089908        8.575887        7.767155        5.615848
# 1        10.720122        8.655046        8.016512        5.483966
# 2         9.645685        8.031597        7.760870        4.617136
# 3         9.464828        8.778673        8.153804        4.349713
# 4         9.466405        9.517409        8.494192        4.220209
# ..             ...             ...             ...             ...
# 78       17.973763       13.342415        8.616546        4.271203
# 79       19.158084       14.226659        8.966529        4.455704
# 80       20.266147       15.230406        9.053819        4.464279
# 81       20.244624       15.542248        8.542821        4.384658
# 82       20.025493       15.562257        8.042738        3.917284
#
#     shear_850_200  shear_850_250  shear_850_300  shear_850_500  shear_925_200  \
# 0       17.167315      15.626753      12.626780       7.745542      16.753165
# 1       16.823509      15.289608      12.164767       7.664875      16.497790
# 2       15.262343      13.652603      10.511506       6.845461      15.023236
# 3       14.621154      12.926131      10.188369       7.042551      14.531260
# 4       13.910971      12.194225       9.929046       7.485897      14.183126
# ..            ...            ...            ...            ...            ...
# 78      22.242578      18.285348      15.845129      10.789497      24.319890
# 79      22.778148      18.753843      16.401979      11.225001      25.215962
# 80      23.491039      19.275096      17.272465      11.882530      26.038709
# 81      23.152867      19.190270      17.297240      12.248056      25.597919
# 82      23.373243      19.641609      17.494807      12.534523      25.274428
#
#     shear_925_250
# 0       15.290136
# 1       14.940152
# 2       13.408222
# 3       12.862745
# 4       12.446725
# ..            ...
# 78      20.213691
# 79      21.216371
# 80      22.009965
# 81      21.820157
# 82      21.897124
#
# [83 rows x 245 columns]

# %%
product.to_csv(output+'timeseries_nwp_newall_2003YANYAN.csv')

# %%
var_names=product.columns.values.tolist()
var_names
# Out:
# ['pmin',
#  'wind10',
#  'div_50',
#  'div_100',
#  'div_200',
#  'div_250',
#  'div_300',
#  'div_400',
#  'div_500',
#  'div_600',
#  'div_700',
#  'div_800',
#  'div_850',
#  'div_925',
#  'div_1000',
#  'eqt1000',
#  'eqt200',
#  'eqt250',
#  'eqt300',
#  'eqt400',
#  'eqt500',
#  'eqt600',
#  'eqt700',
#  'eqt800',
#  'eqt850',
#  'eqt925',
#  '2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'conv_rrate',
#  'ls_rrate',
#  'mn_conv_prate',
#  'mn_ls_prate',
#  'mn_tot_prate',
#  'sst',
#  'vort_100',
#  'vort_150',
#  'vort_200',
#  'vort_250',
#  'vort_300',
#  'vort_400',
#  'vort_500',
#  'vort_600',
#  'vort_700',
#  'vort_800',
#  'vort_850',
#  'vort_900',
#  'vort_925',
#  'vort_950',
#  'vort_975',
#  'vort_1000',
#  'rhum_100',
#  'rhum_150',
#  'rhum_200',
#  'rhum_250',
#  'rhum_300',
#  'rhum_400',
#  'rhum_500',
#  'rhum_600',
#  'rhum_700',
#  'rhum_800',
#  'rhum_850',
#  'rhum_900',
#  'rhum_925',
#  'rhum_950',
#  'rhum_975',
#  'rhum_1000',
#  'gpot_100',
#  'gpot_150',
#  'gpot_200',
#  'gpot_250',
#  'gpot_300',
#  'gpot_400',
#  'gpot_500',
#  'gpot_600',
#  'gpot_700',
#  'gpot_800',
#  'gpot_850',
#  'gpot_900',
#  'gpot_925',
#  'gpot_950',
#  'gpot_975',
#  'gpot_1000',
#  'vvel_100',
#  'vvel_150',
#  'vvel_200',
#  'vvel_250',
#  'vvel_300',
#  'vvel_400',
#  'vvel_500',
#  'vvel_600',
#  'vvel_700',
#  'vvel_850',
#  'vvel_925',
#  'vvel_975',
#  'vvel_1000',
#  'outdiv_50',
#  'outdiv_100',
#  'outdiv_200',
#  'outdiv_250',
#  'outdiv_300',
#  'outdiv_400',
#  'outdiv_500',
#  'outdiv_600',
#  'outdiv_700',
#  'outdiv_800',
#  'outdiv_850',
#  'outdiv_925',
#  'outdiv_1000',
#  'outeqt1000',
#  'outeqt200',
#  'outeqt250',
#  'outeqt300',
#  'outeqt400',
#  'outeqt500',
#  'outeqt600',
#  'outeqt700',
#  'outeqt800',
#  'outeqt850',
#  'outeqt925',
#  'out2mdewtmp',
#  'out2mtmp',
#  'outconv_ppt',
#  'outtot_cld_ice',
#  'outtot_cldwtr',
#  'outtot_cld_rain',
#  'outvi_div_cld_froz_wtr',
#  'outvi_div_cld_liq_wtr',
#  'outvi_div_mass_flux',
#  'outvi_div_moisture_flux',
#  'outvi_div_tot_enrgy_flux',
#  'outvi_pe_inte',
#  'outvi_pe_ie_latentenrgy',
#  'outvi_olr',
#  'outvi_tot_enrgy',
#  'outvi_moisture_div',
#  'outcape',
#  'outinst_moisture_flux',
#  'outinst_ssh_flux',
#  'outsurfmean_lhf',
#  'outsurfmean_shf',
#  'outvimean_moisture_div',
#  'outsurf_lhf',
#  'outsurf_shf',
#  'outtot_suprcool_liqwtr',
#  'outtot_wtr_vpr',
#  'outconv_rrate',
#  'outls_rrate',
#  'outmn_conv_prate',
#  'outmn_ls_prate',
#  'outmn_tot_prate',
#  'outsst',
#  'outvort_100',
#  'outvort_150',
#  'outvort_200',
#  'outvort_250',
#  'outvort_300',
#  'outvort_400',
#  'outvort_500',
#  'outvort_600',
#  'outvort_700',
#  'outvort_800',
#  'outvort_850',
#  'outvort_900',
#  'outvort_925',
#  'outvort_950',
#  'outvort_975',
#  'outvort_1000',
#  'outrhum_100',
#  'outrhum_150',
#  'outrhum_200',
#  'outrhum_250',
#  'outrhum_300',
#  'outrhum_400',
#  'outrhum_500',
#  'outrhum_600',
#  'outrhum_700',
#  'outrhum_800',
#  'outrhum_850',
#  'outrhum_900',
#  'outrhum_925',
#  'outrhum_950',
#  'outrhum_975',
#  'outrhum_1000',
#  'outgpot_100',
#  'outgpot_150',
#  'outgpot_200',
#  'outgpot_250',
#  'outgpot_300',
#  'outgpot_400',
#  'outgpot_500',
#  'outgpot_600',
#  'outgpot_700',
#  'outgpot_800',
#  'outgpot_850',
#  'outgpot_900',
#  'outgpot_925',
#  'outgpot_950',
#  'outgpot_975',
#  'outgpot_1000',
#  'outvvel_100',
#  'outvvel_150',
#  'outvvel_200',
#  'outvvel_250',
#  'outvvel_300',
#  'outvvel_400',
#  'outvvel_500',
#  'outvvel_600',
#  'outvvel_700',
#  'outvvel_850',
#  'outvvel_925',
#  'outvvel_975',
#  'outvvel_1000',
#  'shear_1000_200',
#  'shear_1000_300',
#  'shear_1000_500',
#  'shear_1000_700',
#  'shear_1000_850',
#  'shear_850_200',
#  'shear_850_250',
#  'shear_850_300',
#  'shear_850_500',
#  'shear_925_200',
#  'shear_925_250']

# %%
order:pmin,win10, div, eqt, slevs, rlevs, precsst, vor, rh, gpot, vvel

# %%
target=maincs.iloc[:,:2]
tar=target.rename(columns={"Pmin": "pmin","w10max": "wind10"})

# %%
maincs.drop([ 'Pmin','w10max','div100','div200','div250','div300','div400','div500',\
             'out_div100', 'out_div200','out_div250','out_div300','out_div400','out_div500',\
               'sh850_200', 'sh850_250','sh925_200','sh925_250','wstrss10','out_sh850_200',\
              'out_sh850_250','out_sh925_200','out_sh925_250','out_wstrss10',\
               'vort_10', 'vort_20','vort_30','vort_50','vort_70',\
              'rhum_10', 'rhum_20','rhum_30','rhum_50','rhum_70',\
              'gpot_10', 'gpot_20','gpot_30','gpot_50','gpot_70',\
              'vvel_10', 'vvel_20','vvel_30','vvel_50','vvel_70',\
              'outvort_10', 'outvort_20','outvort_30','outvort_50','outvort_70',\
              'outrhum_10', 'outrhum_20','outrhum_30','outrhum_50','outrhum_70',\
              'outgpot_10', 'outgpot_20','outgpot_30','outgpot_50','outgpot_70',\
              'outvvel_10', 'outvvel_20','outvvel_30','outvvel_50','outvvel_70'], axis = 1, inplace = True)

# %%
newtest=maincs.iloc[:,:103]
rest=maincs.iloc[:,103:]

# %%
x=pd.concat([tar,idiv_cs,newtest,div_cs,rest,sh_cs], axis=1, join='inner')

# %%
x
# Out:
#            pmin     wind10        div_50   div_100   div_200       div_250  \
# 0   1007.069375  11.374318  1.583406e-05  0.000008  0.000026  1.256482e-05
# 1   1008.814375  12.570400  9.069103e-06  0.000019  0.000007  5.473848e-06
# 2   1009.147500  12.993572 -6.857270e-06  0.000016  0.000028  1.212163e-05
# 3   1007.325625  12.251040 -2.714572e-06  0.000001  0.000023  4.518079e-06
# 4   1006.491875  12.024080  1.091976e-07 -0.000015  0.000021  9.086216e-07
# ..          ...        ...           ...       ...       ...           ...
# 56  1004.050000  18.803926  8.937204e-07 -0.000014  0.000018  4.284084e-07
# 57  1003.718750  18.780231  1.117005e-05  0.000003  0.000020  8.091913e-06
# 58  1006.248125  18.004267  2.145229e-06 -0.000017  0.000014  3.024470e-06
# 59  1006.571250  16.774679  8.326606e-07 -0.000005  0.000013  3.045832e-06
# 60  1004.445000  16.020393  5.591544e-06  0.000005  0.000010 -4.476751e-06
#
#          div_300   div_400       div_500       div_600  ...  shear_1000_300  \
# 0   1.083768e-06  0.000005 -1.374865e-06 -9.303796e-06  ...        5.347239
# 1   6.899820e-06  0.000009 -1.763692e-08 -1.336425e-05  ...        4.751918
# 2   1.135585e-05 -0.000005 -3.172958e-06 -1.207273e-05  ...        4.839080
# 3   5.652080e-06 -0.000009 -7.342547e-06 -7.183291e-06  ...        5.360641
# 4   1.305563e-05 -0.000012 -6.325950e-06 -7.371593e-06  ...        5.913981
# ..           ...       ...           ...           ...  ...             ...
# 56 -1.006946e-05 -0.000003  5.621812e-06  1.825229e-05  ...       12.743617
# 57  5.912734e-07  0.000004  6.449118e-06  1.531653e-05  ...       11.810412
# 58 -3.282446e-06  0.000009  3.439607e-06  6.003887e-06  ...       11.522425
# 59 -5.238573e-06  0.000015 -2.731744e-06 -9.478536e-07  ...       11.199899
# 60 -3.317604e-06  0.000019 -1.086958e-05 -7.284048e-06  ...       10.830235
#
#     shear_1000_500  shear_1000_700  shear_1000_850  shear_850_200  \
# 0         3.435577        4.303391        3.144401       8.441775
# 1         3.457505        4.090746        2.964232       7.236525
# 2         3.985580        4.621602        2.731271       7.390084
# 3         4.363336        4.329391        2.609039       7.328903
# 4         4.692687        4.083926        2.504798       8.003003
# ..             ...             ...             ...            ...
# 56        8.760723        8.741952        6.554503      16.346885
# 57        8.822399        8.389943        6.253206      15.622228
# 58       10.347160        7.843174        5.957745      15.656976
# 59       10.896514        7.876389        5.713390      15.086102
# 60       10.845948        7.754690        5.412803      14.447177
#
#     shear_850_250  shear_850_300  shear_850_500  shear_925_200  shear_925_250
# 0        8.029752       6.705156       3.934923       8.030680       7.401614
# 1        7.171575       5.705904       4.048550       7.006484       6.713887
# 2        6.513946       5.245422       4.189249       7.147122       6.158033
# 3        6.386677       5.230111       4.445349       7.354466       6.403368
# 4        6.554572       5.551200       4.828130       8.036178       6.770875
# ..            ...            ...            ...            ...            ...
# 56      14.579489      13.262244       8.640472      18.059965      15.848929
# 57      13.819235      12.362388       8.743737      17.276386      15.077284
# 58      13.599952      11.349780       9.211614      17.416550      15.126349
# 59      13.323083      10.833859       9.606781      17.000200      14.937549
# 60      12.663430      10.174022       9.699289      16.248904      14.337755
#
# [61 rows x 245 columns]

# %%
cs=pd.read_csv(fall+'/timeseries_nwp_newall_2011haima.csv')

# %%
var_names=cs.columns.values.tolist()
var_names
# Out:
# ['Unnamed: 0',
#  'pmin',
#  'wind10',
#  'div_50',
#  'div_100',
#  'div_200',
#  'div_250',
#  'div_300',
#  'div_400',
#  'div_500',
#  'div_600',
#  'div_700',
#  'div_800',
#  'div_850',
#  'div_925',
#  'div_1000',
#  'eqt1000',
#  'eqt200',
#  'eqt250',
#  'eqt300',
#  'eqt400',
#  'eqt500',
#  'eqt600',
#  'eqt700',
#  'eqt850',
#  'eqt925',
#  '2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'conv_rrate',
#  'ls_rrate',
#  'mn_conv_prate',
#  'mn_ls_prate',
#  'mn_tot_prate',
#  'sst',
#  'vort_100',
#  'vort_150',
#  'vort_200',
#  'vort_250',
#  'vort_300',
#  'vort_400',
#  'vort_500',
#  'vort_600',
#  'vort_700',
#  'vort_800',
#  'vort_850',
#  'vort_900',
#  'vort_925',
#  'vort_950',
#  'vort_975',
#  'vort_1000',
#  'rhum_100',
#  'rhum_150',
#  'rhum_200',
#  'rhum_250',
#  'rhum_300',
#  'rhum_400',
#  'rhum_500',
#  'rhum_600',
#  'rhum_700',
#  'rhum_800',
#  'rhum_850',
#  'rhum_900',
#  'rhum_925',
#  'rhum_950',
#  'rhum_975',
#  'rhum_1000',
#  'gpot_100',
#  'gpot_150',
#  'gpot_200',
#  'gpot_250',
#  'gpot_300',
#  'gpot_400',
#  'gpot_500',
#  'gpot_600',
#  'gpot_700',
#  'gpot_800',
#  'gpot_850',
#  'gpot_900',
#  'gpot_925',
#  'gpot_950',
#  'gpot_975',
#  'gpot_1000',
#  'vvel_100',
#  'vvel_150',
#  'vvel_200',
#  'vvel_250',
#  'vvel_300',
#  'vvel_400',
#  'vvel_500',
#  'vvel_600',
#  'vvel_700',
#  'vvel_850',
#  'vvel_925',
#  'vvel_975',
#  'vvel_1000',
#  'outdiv_50',
#  'outdiv_100',
#  'outdiv_200',
#  'outdiv_250',
#  'outdiv_300',
#  'outdiv_400',
#  'outdiv_500',
#  'outdiv_600',
#  'outdiv_700',
#  'outdiv_800',
#  'outdiv_850',
#  'outdiv_925',
#  'outdiv_1000',
#  'out_eqt1000',
#  'out_eqt200',
#  'out_eqt250',
#  'out_eqt300',
#  'out_eqt400',
#  'out_eqt500',
#  'out_eqt600',
#  'out_eqt700',
#  'out_eqt850',
#  'out_eqt925',
#  'out2mdewtmp',
#  'out2mtmp',
#  'outconv_ppt',
#  'outtot_cld_ice',
#  'outtot_cldwtr',
#  'outtot_cld_rain',
#  'outvi_div_cld_froz_wtr',
#  'outvi_div_cld_liq_wtr',
#  'outvi_div_mass_flux',
#  'outvi_div_moisture_flux',
#  'outvi_div_tot_enrgy_flux',
#  'outvi_pe_inte',
#  'outvi_pe_ie_latentenrgy',
#  'outvi_olr',
#  'outvi_tot_enrgy',
#  'outvi_moisture_div',
#  'outcape',
#  'outinst_moisture_flux',
#  'outinst_ssh_flux',
#  'outsurfmean_lhf',
#  'outsurfmean_shf',
#  'outvimean_moisture_div',
#  'outsurf_lhf',
#  'outsurf_shf',
#  'outtot_suprcool_liqwtr',
#  'outtot_wtr_vpr',
#  'outconv_rrate',
#  'outls_rrate',
#  'outmn_conv_prate',
#  'outmn_ls_prate',
#  'outmn_tot_prate',
#  'outsst',
#  'outvort_100',
#  'outvort_150',
#  'outvort_200',
#  'outvort_250',
#  'outvort_300',
#  'outvort_400',
#  'outvort_500',
#  'outvort_600',
#  'outvort_700',
#  'outvort_800',
#  'outvort_850',
#  'outvort_900',
#  'outvort_925',
#  'outvort_950',
#  'outvort_975',
#  'outvort_1000',
#  'outrhum_100',
#  'outrhum_150',
#  'outrhum_200',
#  'outrhum_250',
#  'outrhum_300',
#  'outrhum_400',
#  'outrhum_500',
#  'outrhum_600',
#  'outrhum_700',
#  'outrhum_800',
#  'outrhum_850',
#  'outrhum_900',
#  'outrhum_925',
#  'outrhum_950',
#  'outrhum_975',
#  'outrhum_1000',
#  'outgpot_100',
#  'outgpot_150',
#  'outgpot_200',
#  'outgpot_250',
#  'outgpot_300',
#  'outgpot_400',
#  'outgpot_500',
#  'outgpot_600',
#  'outgpot_700',
#  'outgpot_800',
#  'outgpot_850',
#  'outgpot_900',
#  'outgpot_925',
#  'outgpot_950',
#  'outgpot_975',
#  'outgpot_1000',
#  'outvvel_100',
#  'outvvel_150',
#  'outvvel_200',
#  'outvvel_250',
#  'outvvel_300',
#  'outvvel_400',
#  'outvvel_500',
#  'outvvel_600',
#  'outvvel_700',
#  'outvvel_850',
#  'outvvel_925',
#  'outvvel_975',
#  'outvvel_1000',
#  'shear_1000_200',
#  'shear_1000_300',
#  'shear_1000_500',
#  'shear_1000_700',
#  'shear_1000_850',
#  'shear_850_200',
#  'shear_850_250',
#  'shear_850_300',
#  'shear_850_500',
#  'shear_925_200',
#  'shear_925_250']

# %%
product
# Out:
#            pmin     wind10        div_50       div_100   div_200  \
# 0   1004.566875  12.842197  2.928718e-07  4.444722e-06  0.000008
# 1   1002.108125  11.755289 -2.793327e-06  9.172712e-06  0.000010
# 2   1001.766250  10.468782 -5.007547e-06  5.647307e-06  0.000008
# 3   1003.603125  11.919233 -8.492774e-06  1.284503e-05  0.000007
# 4   1003.393750  12.092264 -2.994435e-06  1.313118e-05  0.000004
# ..          ...        ...           ...           ...       ...
# 76  1001.421875  16.466103  7.694907e-07  9.197975e-06  0.000001
# 77  1001.163750  18.302256  3.914698e-06  7.838826e-06  0.000004
# 78  1003.364375  14.402316  6.457616e-06  1.127482e-07  0.000007
# 79  1004.177500  16.515623 -2.109766e-06 -7.072173e-06  0.000007
# 80  1004.611250  14.314419 -1.361639e-05 -1.054414e-05  0.000005
#
#          div_250       div_300   div_400       div_500       div_600  ...  \
# 0   1.003320e-05  1.316657e-06 -0.000002 -4.299334e-06 -6.858667e-06  ...
# 1   9.161071e-06 -6.658142e-06 -0.000008 -5.795213e-06 -3.829075e-06  ...
# 2  -1.572073e-06 -1.277891e-06 -0.000001 -5.267211e-07  7.495400e-07  ...
# 3   9.180963e-06 -1.526379e-06  0.000003 -1.774228e-06 -2.355315e-06  ...
# 4   1.060107e-07 -7.520139e-06  0.000007  3.528141e-06 -4.366739e-07  ...
# ..           ...           ...       ...           ...           ...  ...
# 76 -4.207017e-06 -3.174122e-06 -0.000003  3.854511e-07  4.890608e-06  ...
# 77 -8.574047e-06 -1.474866e-06 -0.000002  1.129811e-06 -4.074536e-07  ...
# 78 -8.452334e-07 -2.153101e-06 -0.000004  2.219807e-06 -2.643210e-06  ...
# 79  6.096554e-06 -4.780013e-07 -0.000003 -2.869230e-06 -3.790716e-06  ...
# 80  3.867026e-06  6.697956e-07 -0.000002  7.791677e-07 -2.988614e-06  ...
#
#     shear_1000_300  shear_1000_500  shear_1000_700  shear_1000_850  \
# 0         8.289832        4.797206        3.510498        2.672602
# 1         8.325814        4.900672        3.421545        2.692647
# 2         8.599300        5.151618        3.855670        3.271839
# 3         8.900774        5.597399        4.413044        3.338029
# 4         8.864699        6.093020        4.604232        3.112423
# ..             ...             ...             ...             ...
# 76        9.634441        7.334599        7.053450        4.481249
# 77        9.647971        7.224732        7.077604        4.681494
# 78       10.202889        7.257409        7.102418        4.840439
# 79       10.276280        7.358329        7.113590        4.992940
# 80       10.313441        7.178368        6.853954        4.415159
#
#     shear_850_200  shear_850_250  shear_850_300  shear_850_500  shear_925_200  \
# 0       14.524215      11.987963       9.131244       4.584256      13.707550
# 1       14.420391      12.244939       9.333990       4.866227      13.680104
# 2       14.755454      11.680785       9.401399       5.073623      13.940087
# 3       14.697094      11.674498       9.408061       4.994554      14.214002
# 4       14.744348      11.455299       9.243106       5.088908      14.555629
# ..            ...            ...            ...            ...            ...
# 76      13.038873      11.240506      10.042604       7.063267      12.904484
# 77      13.510660      11.103289       9.831734       6.903579      13.374956
# 78      13.635069      11.475229      10.406727       6.888741      13.347173
# 79      13.775389      11.739309      10.426280       6.797202      13.449455
# 80      13.733949      11.684553      10.144809       6.636963      13.738326
#
#     shear_925_250
# 0       11.303284
# 1       11.607116
# 2       10.986586
# 3       11.166028
# 4       11.193675
# ..            ...
# 76      11.175275
# 77      11.233563
# 78      11.527258
# 79      12.034792
# 80      12.479759
#
# [81 rows x 246 columns]

# %%
x=pd.read_csv(fall+'/timeseries_nwp_newall_2011haima.csv')

# %%
x
# Out:
#     Unnamed: 0         pmin     wind10    div_50   div_100   div_200  \
# 0            0  1005.852500  12.920896  0.000006 -0.000011  0.000028
# 1            1  1005.700625  11.155981 -0.000001 -0.000013  0.000034
# 2            2  1007.673125  11.616890 -0.000011 -0.000020  0.000020
# 3            3  1007.952500  10.947051  0.000003 -0.000017  0.000002
# 4            4  1005.093125  12.182612  0.000005 -0.000019 -0.000008
# ..         ...          ...        ...       ...       ...       ...
# 72          72   995.521875  11.428171 -0.000006  0.000028  0.000025
# 73          73   995.124375  11.366698 -0.000004  0.000023  0.000024
# 74          74   997.292500   9.420424 -0.000007  0.000028  0.000030
# 75          75   999.440000   9.506091  0.000005  0.000021  0.000033
# 76          76   999.065625   9.484329  0.000004  0.000025  0.000033
#
#      div_250       div_300   div_400       div_500  ...  shear_1000_300  \
# 0   0.000011  4.831760e-06  0.000004 -2.087385e-06  ...        9.288847
# 1   0.000012  3.217778e-06  0.000003 -8.684001e-06  ...        8.700054
# 2   0.000017  6.464776e-06 -0.000007 -9.825453e-07  ...        9.073136
# 3   0.000011  4.619302e-06 -0.000007  3.009685e-06  ...        9.462588
# 4  -0.000003  8.550123e-07 -0.000003 -2.914458e-07  ...        9.826395
# ..       ...           ...       ...           ...  ...             ...
# 72  0.000015  1.109060e-05  0.000009 -6.488990e-07  ...        8.738535
# 73  0.000019  9.652285e-06  0.000004 -2.048269e-06  ...        8.504591
# 74  0.000008  5.392532e-06  0.000014  3.974594e-06  ...        8.012774
# 75  0.000015  1.656997e-05  0.000011 -1.586333e-06  ...        7.741951
# 76  0.000014  1.495017e-05  0.000005 -1.181033e-06  ...        7.254272
#
#     shear_1000_500  shear_1000_700  shear_1000_850  shear_850_200  \
# 0         5.871145        4.736082        3.406758      14.931618
# 1         5.385077        4.520162        3.336483      14.827590
# 2         5.892637        5.704425        3.741751      15.283868
# 3         6.186801        5.754110        3.635580      14.685981
# 4         5.928213        5.455534        3.502933      14.666815
# ..             ...             ...             ...            ...
# 72        6.860533        7.521901        6.670208      19.794617
# 73        7.052809        7.995008        7.034058      19.685256
# 74        6.942427        8.991190        7.672977      20.466674
# 75        6.551404        8.844377        7.976849      21.272873
# 76        6.604081        8.703580        7.865621      20.592265
#
#     shear_850_250  shear_850_300  shear_850_500  shear_925_200  shear_925_250
# 0       12.469911      11.115579       6.003537      14.345275      11.818965
# 1       11.693236      10.618858       5.535554      14.245346      10.990258
# 2       12.933236      10.895873       5.663210      14.507734      12.132557
# 3       12.947256      11.166186       5.768856      13.959444      12.233133
# 4       12.753317      11.493865       5.703244      13.930808      12.111174
# ..            ...            ...            ...            ...            ...
# 72      16.897413      13.501043       5.679230      17.397866      14.485837
# 73      16.606829      13.460967       5.662564      17.266843      14.177017
# 74      16.773010      13.678349       5.920827      17.696984      14.155689
# 75      17.342171      14.103914       6.247682      18.304505      14.437636
# 76      16.707881      13.576756       5.967883      17.829280      13.926331
#
# [77 rows x 246 columns]

# %%
var_names=x.columns.values.tolist()
var_names
# Out:
# ['Unnamed: 0',
#  'pmin',
#  'wind10',
#  'div_50',
#  'div_100',
#  'div_200',
#  'div_250',
#  'div_300',
#  'div_400',
#  'div_500',
#  'div_600',
#  'div_700',
#  'div_800',
#  'div_850',
#  'div_925',
#  'div_1000',
#  'eqt1000',
#  'eqt200',
#  'eqt250',
#  'eqt300',
#  'eqt400',
#  'eqt500',
#  'eqt600',
#  'eqt700',
#  'eqt850',
#  'eqt925',
#  '2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'conv_rrate',
#  'ls_rrate',
#  'mn_conv_prate',
#  'mn_ls_prate',
#  'mn_tot_prate',
#  'sst',
#  'vort_100',
#  'vort_150',
#  'vort_200',
#  'vort_250',
#  'vort_300',
#  'vort_400',
#  'vort_500',
#  'vort_600',
#  'vort_700',
#  'vort_800',
#  'vort_850',
#  'vort_900',
#  'vort_925',
#  'vort_950',
#  'vort_975',
#  'vort_1000',
#  'rhum_100',
#  'rhum_150',
#  'rhum_200',
#  'rhum_250',
#  'rhum_300',
#  'rhum_400',
#  'rhum_500',
#  'rhum_600',
#  'rhum_700',
#  'rhum_800',
#  'rhum_850',
#  'rhum_900',
#  'rhum_925',
#  'rhum_950',
#  'rhum_975',
#  'rhum_1000',
#  'gpot_100',
#  'gpot_150',
#  'gpot_200',
#  'gpot_250',
#  'gpot_300',
#  'gpot_400',
#  'gpot_500',
#  'gpot_600',
#  'gpot_700',
#  'gpot_800',
#  'gpot_850',
#  'gpot_900',
#  'gpot_925',
#  'gpot_950',
#  'gpot_975',
#  'gpot_1000',
#  'vvel_100',
#  'vvel_150',
#  'vvel_200',
#  'vvel_250',
#  'vvel_300',
#  'vvel_400',
#  'vvel_500',
#  'vvel_600',
#  'vvel_700',
#  'vvel_850',
#  'vvel_925',
#  'vvel_975',
#  'vvel_1000',
#  'outdiv_50',
#  'outdiv_100',
#  'outdiv_200',
#  'outdiv_250',
#  'outdiv_300',
#  'outdiv_400',
#  'outdiv_500',
#  'outdiv_600',
#  'outdiv_700',
#  'outdiv_800',
#  'outdiv_850',
#  'outdiv_925',
#  'outdiv_1000',
#  'out_eqt1000',
#  'out_eqt200',
#  'out_eqt250',
#  'out_eqt300',
#  'out_eqt400',
#  'out_eqt500',
#  'out_eqt600',
#  'out_eqt700',
#  'out_eqt850',
#  'out_eqt925',
#  'out2mdewtmp',
#  'out2mtmp',
#  'outconv_ppt',
#  'outtot_cld_ice',
#  'outtot_cldwtr',
#  'outtot_cld_rain',
#  'outvi_div_cld_froz_wtr',
#  'outvi_div_cld_liq_wtr',
#  'outvi_div_mass_flux',
#  'outvi_div_moisture_flux',
#  'outvi_div_tot_enrgy_flux',
#  'outvi_pe_inte',
#  'outvi_pe_ie_latentenrgy',
#  'outvi_olr',
#  'outvi_tot_enrgy',
#  'outvi_moisture_div',
#  'outcape',
#  'outinst_moisture_flux',
#  'outinst_ssh_flux',
#  'outsurfmean_lhf',
#  'outsurfmean_shf',
#  'outvimean_moisture_div',
#  'outsurf_lhf',
#  'outsurf_shf',
#  'outtot_suprcool_liqwtr',
#  'outtot_wtr_vpr',
#  'outconv_rrate',
#  'outls_rrate',
#  'outmn_conv_prate',
#  'outmn_ls_prate',
#  'outmn_tot_prate',
#  'outsst',
#  'outvort_100',
#  'outvort_150',
#  'outvort_200',
#  'outvort_250',
#  'outvort_300',
#  'outvort_400',
#  'outvort_500',
#  'outvort_600',
#  'outvort_700',
#  'outvort_800',
#  'outvort_850',
#  'outvort_900',
#  'outvort_925',
#  'outvort_950',
#  'outvort_975',
#  'outvort_1000',
#  'outrhum_100',
#  'outrhum_150',
#  'outrhum_200',
#  'outrhum_250',
#  'outrhum_300',
#  'outrhum_400',
#  'outrhum_500',
#  'outrhum_600',
#  'outrhum_700',
#  'outrhum_800',
#  'outrhum_850',
#  'outrhum_900',
#  'outrhum_925',
#  'outrhum_950',
#  'outrhum_975',
#  'outrhum_1000',
#  'outgpot_100',
#  'outgpot_150',
#  'outgpot_200',
#  'outgpot_250',
#  'outgpot_300',
#  'outgpot_400',
#  'outgpot_500',
#  'outgpot_600',
#  'outgpot_700',
#  'outgpot_800',
#  'outgpot_850',
#  'outgpot_900',
#  'outgpot_925',
#  'outgpot_950',
#  'outgpot_975',
#  'outgpot_1000',
#  'outvvel_100',
#  'outvvel_150',
#  'outvvel_200',
#  'outvvel_250',
#  'outvvel_300',
#  'outvvel_400',
#  'outvvel_500',
#  'outvvel_600',
#  'outvvel_700',
#  'outvvel_850',
#  'outvvel_925',
#  'outvvel_975',
#  'outvvel_1000',
#  'shear_1000_200',
#  'shear_1000_300',
#  'shear_1000_500',
#  'shear_1000_700',
#  'shear_1000_850',
#  'shear_850_200',
#  'shear_850_250',
#  'shear_850_300',
#  'shear_850_500',
#  'shear_925_200',
#  'shear_925_250']

# %% [markdown]
# Say your current order of column is [b,c,d,a] and you want to order it into [a,b,c,d], you could do it this way:
#
# new_df = old_df[['a', 'b', 'c', 'd']]

# %%
maincs=pd.read_csv(output+'timeseries_outer_nio_2021.csv',delimiter=r",")
maincs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
maincs=maincs.drop('a', axis=1)

pdf_cs=pd.read_csv(output+'2021/target_2021shah.csv',delimiter=r",")
pdf_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
pdf_cs=pdf_cs.drop('a', axis=1)

in_cs=pd.read_csv(output+'2021/inner_nio_20210924.csv',delimiter=r",")
in_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
in_cs=in_cs.drop('a', axis=1)

sh_cs=pd.read_csv(output+'2021/shears_outer_20210924.csv',delimiter=r",")
sh_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
sh_cs=sh_cs.drop('a', axis=1)

eq_cs=pd.read_csv(output+'2021/eqt_outer_20210924.csv',delimiter=r",")
eq_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
eq_cs=eq_cs.drop('a', axis=1)

div_cs=pd.read_csv(output+'2021/div_outer_20210924.csv',delimiter=r",")
div_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
div_cs=div_cs.drop('a', axis=1)

# %%
#innereqt_nio_20210924.csv
ieq_cs=pd.read_csv(output+'inner/innereqt_nio_20210924.csv',delimiter=r",")
ieq_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
ieq_cs=ieq_cs.drop('a', axis=1)
id_cs=pd.read_csv(output+'inner/innerdiv_nio_20210924.csv',delimiter=r",")
id_cs.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
id_cs=id_cs.drop('a', axis=1)

# %%
ieq_cs
# Out:
#        eqt1000      eqt200      eqt250      eqt300      eqt400      eqt500  \
# 0   347.465510  353.612995  352.615771  351.885030  349.794871  345.930374
# 1   348.032755  353.901343  353.290178  352.379025  350.267347  346.014148
# 2   348.136506  354.550363  353.770979  352.717997  349.740759  346.176270
# 3   349.024466  353.804380  353.036090  352.184105  349.293982  346.201871
# 4   349.183840  353.478839  352.447847  351.570752  349.024746  346.258267
# ..         ...         ...         ...         ...         ...         ...
# 76  348.058863  354.708487  353.396028  351.339416  346.817756  344.356065
# 77  346.036352  354.979061  353.627199  351.048416  345.912341  343.477470
# 78  346.199288  354.693309  353.020268  350.607740  346.181340  343.845247
# 79  345.417474  354.148402  352.606752  350.140655  345.739419  343.014634
# 80  346.577767  354.025700  352.442505  350.414938  345.942443  342.405590
#
#         eqt600      eqt700      eqt800      eqt850      eqt925
# 0   341.606979  341.429963  342.398958  342.343998  343.325633
# 1   341.451700  341.119879  342.895915  342.643210  344.383870
# 2   341.167901  340.779176  343.131411  343.263164  344.796794
# 3   341.311854  341.193903  343.332500  343.815773  345.019775
# 4   341.318893  341.459933  343.778754  344.046753  345.605279
# ..         ...         ...         ...         ...         ...
# 76  342.125011  338.951577  337.613086  339.079971  341.898986
# 77  341.276634  337.919911  337.713780  339.445153  341.137160
# 78  341.155738  337.884333  337.608753  339.035710  342.632651
# 79  338.227574  335.233031  335.824224  338.153663  341.766845
# 80  336.432995  333.944431  333.761630  336.939563  342.179316
#
# [81 rows x 11 columns]

# %%
maincs.drop([ 'outvort_10', 'outvort_20','outvort_30','outvort_50','outvort_70',\
              'outrhum_10', 'outrhum_20','outrhum_30','outrhum_50','outrhum_70',\
              'outgpot_10', 'outgpot_20','outgpot_30','outgpot_50','outgpot_70',\
              'outvvel_10', 'outvvel_20','outvvel_30','outvvel_50','outvvel_70','outu10','outv10'], axis = 1, inplace = True)

# %%
in_cs.drop(['eqt100','u10','v10','pvor_10','pvor_20','pvor_30','pvor_100','pvor_150',\
            'pvor_50','pvor_70','pvor_200','pvor_250','pvor_300','pvor_400',\
            'pvor_500','pvor_600','pvor_700','pvor_850','pvor_925','pvor_975','pvor_1000',\
            'temp_10','temp_20','temp_30','temp_100','temp_50','temp_150','temp_200','temp_250',\
            'temp_70','temp_300','temp_400','temp_500','temp_600','temp_700','temp_800',\
            'temp_850','temp_900','temp_925','temp_950','temp_975','temp_1000',\
            'vort_10', 'vort_20','vort_30','vort_50','vort_70',\
              'rhum_10', 'rhum_20','rhum_30','rhum_50','rhum_70',\
              'gpot_10', 'gpot_20','gpot_30','gpot_50','gpot_70',\
              'vvel_10', 'vvel_20','vvel_30','vvel_50','vvel_70'], axis = 1, inplace = True)

# %%
in_cs
# Out:
#           div_50       div_100   div_200       div_250       div_300  \
# 0  -1.470139e-05 -2.004806e-05  0.000018  1.717859e-05  1.207291e-05
# 1  -2.488989e-05 -5.881069e-06  0.000022  1.001521e-05  7.239578e-06
# 2  -5.774957e-06 -1.693203e-06  0.000016  3.927038e-06 -8.301693e-06
# 3  -4.540430e-06  5.546259e-06  0.000010  9.460666e-06 -8.159375e-06
# 4   1.277926e-05  2.870103e-06  0.000009  5.408539e-06 -6.243528e-06
# ..           ...           ...       ...           ...           ...
# 76 -3.872090e-06 -4.878500e-06  0.000037  4.795962e-06  8.417992e-07
# 77  1.046498e-05 -6.112386e-07  0.000041  8.770730e-07 -3.539375e-06
# 78 -3.096648e-07 -5.463196e-06  0.000052  1.734338e-05 -3.813999e-06
# 79  3.144261e-06 -1.742784e-05  0.000044  1.299020e-05 -1.123449e-05
# 80 -3.384193e-07 -8.378294e-06  0.000032  6.530317e-06 -8.087722e-06
#
#          div_400       div_500       div_600       div_700       div_800  ...  \
# 0   8.906121e-06 -1.034816e-06  7.125200e-07 -3.069406e-06 -4.832400e-06  ...
# 1  -2.546585e-06  2.435117e-06 -5.611917e-06 -5.518668e-07 -1.899782e-06  ...
# 2  -1.514552e-05 -1.117820e-06  2.739776e-06 -5.193695e-06  6.410002e-06  ...
# 3  -6.259594e-06 -4.779082e-06  1.751061e-06 -1.289300e-07  5.345559e-06  ...
# 4   6.831135e-06  1.678709e-07  1.325330e-06  7.220078e-07  1.140637e-06  ...
# ..           ...           ...           ...           ...           ...  ...
# 76  4.533329e-06 -4.068715e-07 -1.222652e-05 -2.529082e-05 -1.379685e-05  ...
# 77  3.801601e-06 -2.524524e-06 -1.678348e-05 -3.209530e-05 -1.239870e-05  ...
# 78  3.948808e-06 -9.298674e-06 -3.250362e-05 -2.863479e-05 -9.745010e-06  ...
# 79 -4.185305e-06 -1.553120e-05 -2.349971e-05 -1.744000e-05  4.005851e-07  ...
# 80  7.246272e-07 -1.445104e-05 -2.099917e-05 -1.772260e-05  5.969312e-06  ...
#
#     vvel_250  vvel_300  vvel_400  vvel_500  vvel_600  vvel_700  vvel_850  \
# 0  -0.179325 -0.259124 -0.360181 -0.382818 -0.385455 -0.363965 -0.295342
# 1  -0.201773 -0.238356 -0.244928 -0.229633 -0.239007 -0.181803 -0.169252
# 2  -0.151920 -0.137368 -0.016568  0.070683  0.044295  0.076153  0.026839
# 3  -0.156391 -0.158884 -0.086677 -0.047792 -0.028524 -0.031328 -0.089968
# 4  -0.165562 -0.165935 -0.179049 -0.213646 -0.220336 -0.232739 -0.245793
# ..       ...       ...       ...       ...       ...       ...       ...
# 76 -0.332974 -0.345632 -0.376871 -0.417450 -0.363439 -0.170226  0.073287
# 77 -0.463555 -0.455450 -0.437432 -0.476495 -0.402014 -0.120978  0.123721
# 78 -0.633262 -0.663047 -0.619403 -0.636304 -0.430235 -0.075319  0.126537
# 79 -0.388316 -0.391463 -0.256868 -0.165840  0.070560  0.315451  0.356788
# 80 -0.188751 -0.189928 -0.124838 -0.054407  0.154492  0.347481  0.344084
#
#     vvel_925  vvel_975  vvel_1000
# 0  -0.182406 -0.074252  -0.017509
# 1  -0.119534 -0.056306  -0.018626
# 2  -0.005580  0.007360   0.018210
# 3  -0.073317 -0.020160   0.013664
# 4  -0.176871 -0.078091  -0.024020
# ..       ...       ...        ...
# 76  0.059968  0.022831   0.031646
# 77  0.091201  0.027067   0.026226
# 78  0.079193  0.016556   0.001574
# 79  0.221411  0.084055   0.041359
# 80  0.203439  0.065261   0.019004
#
# [81 rows x 128 columns]

# %%
tar=pdf_cs.rename(columns={"mslp_2020": "pmin"})

# %%
tar
# Out:
#            pmin     wind10
# 0   1004.566875  12.842197
# 1   1002.108125  11.755289
# 2   1001.766250  10.468782
# 3   1003.603125  11.919233
# 4   1003.393750  12.092264
# ..          ...        ...
# 76  1001.421875  16.466103
# 77  1001.163750  18.302256
# 78  1003.364375  14.402316
# 79  1004.177500  16.515623
# 80  1004.611250  14.314419
#
# [81 rows x 2 columns]

# %%
product=pd.concat([tar,id_cs,ieq_cs,inrest,div_cs,eq_cs,newdf,sh_cs], axis=1, join='inner')

# %%
product
# Out:
#            pmin     wind10        div_50       div_100   div_200  \
# 0   1004.566875  12.842197  2.928718e-07  4.444722e-06  0.000008
# 1   1002.108125  11.755289 -2.793327e-06  9.172712e-06  0.000010
# 2   1001.766250  10.468782 -5.007547e-06  5.647307e-06  0.000008
# 3   1003.603125  11.919233 -8.492774e-06  1.284503e-05  0.000007
# 4   1003.393750  12.092264 -2.994435e-06  1.313118e-05  0.000004
# ..          ...        ...           ...           ...       ...
# 76  1001.421875  16.466103  7.694907e-07  9.197975e-06  0.000001
# 77  1001.163750  18.302256  3.914698e-06  7.838826e-06  0.000004
# 78  1003.364375  14.402316  6.457616e-06  1.127482e-07  0.000007
# 79  1004.177500  16.515623 -2.109766e-06 -7.072173e-06  0.000007
# 80  1004.611250  14.314419 -1.361639e-05 -1.054414e-05  0.000005
#
#          div_250       div_300   div_400       div_500       div_600  ...  \
# 0   1.003320e-05  1.316657e-06 -0.000002 -4.299334e-06 -6.858667e-06  ...
# 1   9.161071e-06 -6.658142e-06 -0.000008 -5.795213e-06 -3.829075e-06  ...
# 2  -1.572073e-06 -1.277891e-06 -0.000001 -5.267211e-07  7.495400e-07  ...
# 3   9.180963e-06 -1.526379e-06  0.000003 -1.774228e-06 -2.355315e-06  ...
# 4   1.060107e-07 -7.520139e-06  0.000007  3.528141e-06 -4.366739e-07  ...
# ..           ...           ...       ...           ...           ...  ...
# 76 -4.207017e-06 -3.174122e-06 -0.000003  3.854511e-07  4.890608e-06  ...
# 77 -8.574047e-06 -1.474866e-06 -0.000002  1.129811e-06 -4.074536e-07  ...
# 78 -8.452334e-07 -2.153101e-06 -0.000004  2.219807e-06 -2.643210e-06  ...
# 79  6.096554e-06 -4.780013e-07 -0.000003 -2.869230e-06 -3.790716e-06  ...
# 80  3.867026e-06  6.697956e-07 -0.000002  7.791677e-07 -2.988614e-06  ...
#
#     shear_1000_300  shear_1000_500  shear_1000_700  shear_1000_850  \
# 0         8.289832        4.797206        3.510498        2.672602
# 1         8.325814        4.900672        3.421545        2.692647
# 2         8.599300        5.151618        3.855670        3.271839
# 3         8.900774        5.597399        4.413044        3.338029
# 4         8.864699        6.093020        4.604232        3.112423
# ..             ...             ...             ...             ...
# 76        9.634441        7.334599        7.053450        4.481249
# 77        9.647971        7.224732        7.077604        4.681494
# 78       10.202889        7.257409        7.102418        4.840439
# 79       10.276280        7.358329        7.113590        4.992940
# 80       10.313441        7.178368        6.853954        4.415159
#
#     shear_850_200  shear_850_250  shear_850_300  shear_850_500  shear_925_200  \
# 0       14.524215      11.987963       9.131244       4.584256      13.707550
# 1       14.420391      12.244939       9.333990       4.866227      13.680104
# 2       14.755454      11.680785       9.401399       5.073623      13.940087
# 3       14.697094      11.674498       9.408061       4.994554      14.214002
# 4       14.744348      11.455299       9.243106       5.088908      14.555629
# ..            ...            ...            ...            ...            ...
# 76      13.038873      11.240506      10.042604       7.063267      12.904484
# 77      13.510660      11.103289       9.831734       6.903579      13.374956
# 78      13.635069      11.475229      10.406727       6.888741      13.347173
# 79      13.775389      11.739309      10.426280       6.797202      13.449455
# 80      13.733949      11.684553      10.144809       6.636963      13.738326
#
#     shear_925_250
# 0       11.303284
# 1       11.607116
# 2       10.986586
# 3       11.166028
# 4       11.193675
# ..            ...
# 76      11.175275
# 77      11.233563
# 78      11.527258
# 79      12.034792
# 80      12.479759
#
# [81 rows x 269 columns]

# %%
product.to_csv(output+'timeseries_nio_newall_20210924.csv')

# %%
product

# %%
inrest=in_cs.iloc[:,24:]

# %%
inrest
# Out:
#       2mdewtmp       2mtmp  conv_ppt  tot_cld_ice  tot_cldwtr  tot_cld_rain  \
# 0   297.831451  300.927116  0.000670     0.171029    0.194011      0.495889
# 1   297.993210  301.024956  0.000393     0.175396    0.149730      0.300468
# 2   297.638100  300.568596  0.000374     0.112899    0.070724      0.085901
# 3   297.803566  300.834404  0.000279     0.088313    0.072903      0.036659
# 4   297.874138  300.781960  0.000431     0.102021    0.136815      0.094988
# ..         ...         ...       ...          ...         ...           ...
# 76  295.738846  301.151794  0.000707     0.199975    0.213264      0.519048
# 77  294.979492  300.440697  0.000342     0.247307    0.211577      0.506780
# 78  295.339912  300.260643  0.000360     0.331206    0.289762      0.478316
# 79  294.221283  300.048172  0.000389     0.258266    0.189384      0.375591
# 80  294.223198  301.889519  0.000247     0.127806    0.141320      0.142889
#
#     vi_div_cld_froz_wtr  vi_div_cld_liq_wtr  vi_div_gpot_flux  vi_div_ke_flux  \
# 0          3.766443e-06       -9.422656e-07       3744.273438       -1.700073
# 1         -3.183377e-07       -2.060668e-06       2683.535156        0.436279
# 2         -6.177579e-07        1.218868e-07        315.332031       -0.926758
# 3         -5.122274e-08       -2.599554e-07       1193.757812       -0.257568
# 4          5.981419e-07        3.083842e-07       2616.390625        1.111328
# ..                  ...                 ...               ...             ...
# 76         6.776652e-06        5.335314e-07       3505.062500        0.180176
# 77         1.651485e-05        1.373002e-06       4277.406250        3.747070
# 78         1.727387e-05       -4.008063e-06       5591.570312       13.151855
# 79         1.050316e-05       -2.196990e-06       1076.355469       15.547119
# 80         2.712593e-06       -6.734626e-07       -278.355469       16.494873
#
#     ...  vvel_250  vvel_300  vvel_400  vvel_500  vvel_600  vvel_700  vvel_850  \
# 0   ... -0.179325 -0.259124 -0.360181 -0.382818 -0.385455 -0.363965 -0.295342
# 1   ... -0.201773 -0.238356 -0.244928 -0.229633 -0.239007 -0.181803 -0.169252
# 2   ... -0.151920 -0.137368 -0.016568  0.070683  0.044295  0.076153  0.026839
# 3   ... -0.156391 -0.158884 -0.086677 -0.047792 -0.028524 -0.031328 -0.089968
# 4   ... -0.165562 -0.165935 -0.179049 -0.213646 -0.220336 -0.232739 -0.245793
# ..  ...       ...       ...       ...       ...       ...       ...       ...
# 76  ... -0.332974 -0.345632 -0.376871 -0.417450 -0.363439 -0.170226  0.073287
# 77  ... -0.463555 -0.455450 -0.437432 -0.476495 -0.402014 -0.120978  0.123721
# 78  ... -0.633262 -0.663047 -0.619403 -0.636304 -0.430235 -0.075319  0.126537
# 79  ... -0.388316 -0.391463 -0.256868 -0.165840  0.070560  0.315451  0.356788
# 80  ... -0.188751 -0.189928 -0.124838 -0.054407  0.154492  0.347481  0.344084
#
#     vvel_925  vvel_975  vvel_1000
# 0  -0.182406 -0.074252  -0.017509
# 1  -0.119534 -0.056306  -0.018626
# 2  -0.005580  0.007360   0.018210
# 3  -0.073317 -0.020160   0.013664
# 4  -0.176871 -0.078091  -0.024020
# ..       ...       ...        ...
# 76  0.059968  0.022831   0.031646
# 77  0.091201  0.027067   0.026226
# 78  0.079193  0.016556   0.001574
# 79  0.221411  0.084055   0.041359
# 80  0.203439  0.065261   0.019004
#
# [81 rows x 104 columns]

# %%
#Final order = target pmin,ws, indiv, ineqt, inlevs, invlev, outdiv, outeqt, outlev, outvlevs, outshears

# %%
newtest=maincs.iloc[:,:60]
rest=maincs.iloc[:,60:]

# %%
rest
# Out:
#     out2mdewtmp    out2mtmp  outconv_ppt  outtot_cld_ice  outtot_cldwtr  \
# 0    297.413957  301.842893     0.000301        0.064621       0.102471
# 1    297.755244  302.359274     0.000250        0.057749       0.101190
# 2    297.973723  301.243634     0.000129        0.030840       0.088187
# 3    297.807355  300.345169     0.000100        0.021827       0.062551
# 4    297.724121  300.038449     0.000133        0.022091       0.063922
# ..          ...         ...          ...             ...            ...
# 76   288.540940  301.204832     0.000002        0.006853       0.008936
# 77   289.280687  299.701232     0.000004        0.009970       0.010539
# 78   289.124394  298.340587     0.000006        0.008881       0.010073
# 79   288.704858  297.923796     0.000006        0.008099       0.010406
# 80   288.424280  302.304570     0.000003        0.004795       0.005917
#
#     outtot_cld_rain  outvi_div_cld_froz_wtr  outvi_div_cld_liq_wtr  \
# 0          0.043154           -2.156865e-07          -4.600734e-08
# 1          0.036265           -7.576309e-08           1.643474e-07
# 2          0.018082           -4.105580e-09           4.925920e-08
# 3          0.018070           -1.571607e-07          -4.389634e-08
# 4          0.013454           -1.292132e-07          -1.516504e-08
# ..              ...                     ...                    ...
# 76         0.000401           -4.728402e-07           3.096648e-08
# 77         0.000595           -1.132923e-06          -5.254212e-08
# 78         0.000202           -1.138164e-06           1.596908e-07
# 79         0.000184           -6.978090e-07           1.162679e-07
# 80         0.000093           -1.925897e-07           1.104937e-07
#
#     outvi_div_gpot_flux  outvi_div_ke_flux  ...    outsurf_shf  \
# 0            713.635417           2.077637  ... -199661.416667
# 1            444.811719           1.874772  ...  -78138.916667
# 2            -12.766927           1.618896  ...   -8880.383333
# 3             49.582813           1.753564  ...   -6168.800000
# 4            493.333333           1.729736  ...   -8927.616667
# ..                  ...                ...  ...            ...
# 76          -184.946875          -0.246680  ...   21496.816667
# 77           -73.536458          -0.338704  ...   18061.583333
# 78          -324.855208          -1.501595  ...   18737.016667
# 79          -268.691406          -1.869743  ...   10756.916667
# 80          -172.193490          -1.571891  ... -258620.516667
#
#     outtot_suprcool_liqwtr  outtot_wtr_vpr      outmslp  outconv_rrate  \
# 0                 0.050517       56.292139  1009.195629   1.121959e-04
# 1                 0.043549       56.497572  1006.490612   6.989970e-05
# 2                 0.037530       56.420094  1006.097475   3.446986e-05
# 3                 0.029600       56.349209  1007.823859   2.807571e-05
# 4                 0.028116       56.841968  1007.708139   3.854219e-05
# ..                     ...             ...          ...            ...
# 76                0.004420       30.299450  1008.916994   7.229236e-07
# 77                0.004124       30.371192  1008.305332   1.214258e-06
# 78                0.005358       29.339513  1008.040143   1.778454e-06
# 79                0.004095       28.863249  1009.092350   1.622364e-06
# 80                0.001504       27.934332  1009.916441   8.177944e-07
#
#      outls_rrate  outmn_conv_prate  outmn_ls_prate  outmn_tot_prate  \
# 0   3.656587e-05      8.370019e-05    3.885394e-05     1.225576e-04
# 1   3.559136e-05      6.958020e-05    3.955193e-05     1.091378e-04
# 2   2.235503e-05      3.583099e-05    2.394101e-05     5.976968e-05
# 3   2.031783e-05      2.774615e-05    1.982677e-05     4.758021e-05
# 4   1.882855e-05      3.682574e-05    2.044520e-05     5.727131e-05
# ..           ...               ...             ...              ...
# 76  2.833704e-07      6.560236e-07    2.926526e-07     9.474034e-07
# 77  8.211782e-07      1.200599e-06    9.144967e-07     2.107831e-06
# 78  8.129204e-07      1.701464e-06    8.250897e-07     2.526181e-06
# 79  5.956118e-07      1.614587e-06    7.673788e-07     2.373507e-06
# 80  3.567897e-07      9.251758e-07    3.968986e-07     1.319187e-06
#
#         outsst
# 0   302.105147
# 1   302.131579
# 2   302.146305
# 3   302.157020
# 4   302.184027
# ..         ...
# 76  301.943022
# 77  301.939233
# 78  302.010758
# 79  302.048350
# 80  302.096877
#
# [81 rows x 44 columns]

# %%
newdf=pd.concat([rest,newtest], axis=1, join='inner')

# %%
newdf
# Out:
#     out2mdewtmp    out2mtmp  outconv_ppt  outtot_cld_ice  outtot_cldwtr  \
# 0    297.413957  301.842893     0.000301        0.064621       0.102471
# 1    297.755244  302.359274     0.000250        0.057749       0.101190
# 2    297.973723  301.243634     0.000129        0.030840       0.088187
# 3    297.807355  300.345169     0.000100        0.021827       0.062551
# 4    297.724121  300.038449     0.000133        0.022091       0.063922
# ..          ...         ...          ...             ...            ...
# 76   288.540940  301.204832     0.000002        0.006853       0.008936
# 77   289.280687  299.701232     0.000004        0.009970       0.010539
# 78   289.124394  298.340587     0.000006        0.008881       0.010073
# 79   288.704858  297.923796     0.000006        0.008099       0.010406
# 80   288.424280  302.304570     0.000003        0.004795       0.005917
#
#     outtot_cld_rain  outvi_div_cld_froz_wtr  outvi_div_cld_liq_wtr  \
# 0          0.043154           -2.156865e-07          -4.600734e-08
# 1          0.036265           -7.576309e-08           1.643474e-07
# 2          0.018082           -4.105580e-09           4.925920e-08
# 3          0.018070           -1.571607e-07          -4.389634e-08
# 4          0.013454           -1.292132e-07          -1.516504e-08
# ..              ...                     ...                    ...
# 76         0.000401           -4.728402e-07           3.096648e-08
# 77         0.000595           -1.132923e-06          -5.254212e-08
# 78         0.000202           -1.138164e-06           1.596908e-07
# 79         0.000184           -6.978090e-07           1.162679e-07
# 80         0.000093           -1.925897e-07           1.104937e-07
#
#     outvi_div_gpot_flux  outvi_div_ke_flux  ...  outvvel_250  outvvel_300  \
# 0            713.635417           2.077637  ...    -0.048377    -0.055831
# 1            444.811719           1.874772  ...    -0.030989    -0.031646
# 2            -12.766927           1.618896  ...    -0.008211    -0.008018
# 3             49.582813           1.753564  ...    -0.011244    -0.003785
# 4            493.333333           1.729736  ...    -0.030656    -0.028129
# ..                  ...                ...  ...          ...          ...
# 76          -184.946875          -0.246680  ...     0.004315    -0.000680
# 77           -73.536458          -0.338704  ...     0.005583    -0.001821
# 78          -324.855208          -1.501595  ...     0.028003     0.026987
# 79          -268.691406          -1.869743  ...     0.020498     0.025566
# 80          -172.193490          -1.571891  ...     0.008746     0.015674
#
#     outvvel_400  outvvel_500  outvvel_600  outvvel_700  outvvel_850  \
# 0     -0.066773    -0.059936    -0.044920    -0.032454    -0.026028
# 1     -0.041984    -0.033261    -0.020508    -0.020403    -0.021941
# 2     -0.009882     0.005383     0.019843     0.020013     0.013971
# 3     -0.000681     0.004511     0.001317    -0.003807     0.008537
# 4     -0.024671    -0.032463    -0.052087    -0.060658    -0.030495
# ..          ...          ...          ...          ...          ...
# 76     0.020704     0.053308     0.051713     0.019009    -0.006515
# 77     0.009456     0.035198     0.037830     0.005044    -0.011094
# 78     0.029419     0.047530     0.043010     0.010902     0.003907
# 79     0.028357     0.038512     0.035311     0.008340     0.004733
# 80     0.032109     0.046844     0.042398     0.011661    -0.032117
#
#     outvvel_925  outvvel_975  outvvel_1000
# 0     -0.034016    -0.041054     -0.042336
# 1     -0.028094    -0.029991     -0.030221
# 2      0.006781     0.007023      0.009039
# 3      0.013327     0.022460      0.026680
# 4     -0.013738     0.003075      0.011227
# ..          ...          ...           ...
# 76     0.020013     0.024044      0.021556
# 77     0.023625     0.038691      0.039037
# 78     0.037490     0.054649      0.056324
# 79     0.042361     0.067897      0.072284
# 80    -0.033661    -0.029766     -0.030210
#
# [81 rows x 104 columns]
