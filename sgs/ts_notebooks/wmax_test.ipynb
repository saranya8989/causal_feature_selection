# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
p1='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/'
path='/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/new_ready/'

# %%
# !ls /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/new_ready/w10*haima*
# Out:
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/new_ready/w10_wp2011haima.nc
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/new_ready/w10_wp2016haima.nc

# %%
dm0=xr.open_dataset(path+'w10_niokeila.nc')

# %%
dm0
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 600, time: 57)
# Coordinates:
#   * time     (time) datetime64[ns] 2011-10-29T06:00:00 ... 2011-11-05T06:00:00
#   * lon      (lon) float64 30.0 30.25 30.5 30.75 ... 179.0 179.2 179.5 179.8
#   * lat      (lat) float64 -19.75 -19.5 -19.25 -19.0 ... 59.25 59.5 59.75 60.0
# Data variables:
#     ws10     (time, lat, lon) float32 ...

# %%
#dm0=dm0.ws10[0:55,:,:]#for it in range(tc_irad.shape[0]):
   # latn, lats, lone, lonw = tc_irad[it,:]
    
    #dw10m[it,:,:]=dm0[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:40,0:40]
    #ws[it]=np.max(dw10m[it,:,:])

# %%
dm0
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 600, time: 57)
# Coordinates:
#   * time     (time) datetime64[ns] 2011-10-29T06:00:00 ... 2011-11-05T06:00:00
#   * lon      (lon) float64 30.0 30.25 30.5 30.75 ... 179.0 179.2 179.5 179.8
#   * lat      (lat) float64 -19.75 -19.5 -19.25 -19.0 ... 59.25 59.5 59.75 60.0
# Data variables:
#     ws10     (time, lat, lon) float32 ...

# %%
#nio tracks use latitude longitude instead of lat lon
track=pd.read_csv(p1+'nio/nio_20111029.csv',delimiter=r",")
lon1=track['lon'].to_numpy()
lat1=track['lat'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)
pos.shape
# Out:
# (57, 2)

# %%
track
# Out:
#                    time      lat      lon
# 0   2011-10-29:06.00.00  13.0000  62.0000
# 1   2011-10-29:09.00.00  13.0005  61.3875
# 2   2011-10-29:12.00.00  13.0000  61.0000
# 3   2011-10-29:15.00.00  12.9998  60.9625
# 4   2011-10-29:18.00.00  13.0000  61.0000
# 5   2011-10-29:21.00.00  12.9999  60.8352
# 6   2011-10-30:00.00.00  13.0000  60.5000
# 7   2011-10-30:03.00.00  13.0000  60.0000
# 8   2011-10-30:06.00.00  13.0000  60.0000
# 9   2011-10-30:09.00.00  13.1989  59.8012
# 10  2011-10-30:12.00.00  13.5000  59.5000
# 11  2011-10-30:15.00.00  13.7500  59.2126
# 12  2011-10-30:18.00.00  14.0000  59.0000
# 13  2011-10-30:21.00.00  14.1987  59.0677
# 14  2011-10-31:00.00.00  14.5000  59.0000
# 15  2011-10-31:03.00.00  15.0000  58.5000
# 16  2011-10-31:06.00.00  16.0000  57.0000
# 17  2011-10-31:09.00.00  16.2037  56.9587
# 18  2011-10-31:12.00.00  16.0000  57.5000
# 19  2011-10-31:15.00.00  16.0000  57.3250
# 20  2011-10-31:18.00.00  16.0000  57.0000
# 21  2011-10-31:21.00.00  15.9998  56.8011
# 22  2011-11-01:00.00.00  15.9400  56.5600
# 23  2011-11-01:03.00.00  15.9167  56.1842
# 24  2011-11-01:06.00.00  15.9143  56.1286
# 25  2011-11-01:09.00.00  15.9251  55.9048
# 26  2011-11-01:12.00.00  15.9500  55.6500
# 27  2011-11-01:15.00.00  15.9712  55.5275
# 28  2011-11-01:18.00.00  16.0000  55.4500
# 29  2011-11-01:21.00.00  16.0425  55.3698
# 30  2011-11-02:00.00.00  16.1000  55.2500
# 31  2011-11-02:03.00.00  16.1675  55.0425
# 32  2011-11-02:06.00.00  16.2500  54.7500
# 33  2011-11-02:09.00.00  16.3612  54.7500
# 34  2011-11-02:12.00.00  16.7000  54.7500
# 35  2011-11-02:15.00.00  16.8688  54.5962
# 36  2011-11-02:18.00.00  17.0000  54.5000
# 37  2011-11-02:21.00.00  16.9919  54.5044
# 38  2011-11-03:00.00.00  16.9500  54.5500
# 39  2011-11-03:03.00.00  17.0175  54.5675
# 40  2011-11-03:06.00.00  17.1000  54.6000
# 41  2011-11-03:09.00.00  17.1167  54.7309
# 42  2011-11-03:12.00.00  17.1000  54.9000
# 43  2011-11-03:15.00.00  17.0937  55.0626
# 44  2011-11-03:18.00.00  17.0500  55.1500
# 45  2011-11-03:21.00.00  16.9667  55.1172
# 46  2011-11-04:00.00.00  16.7333  54.9333
# 47  2011-11-04:03.00.00  16.4480  54.6681
# 48  2011-11-04:06.00.00  16.3000  54.3000
# 49  2011-11-04:09.00.00  16.1349  54.0850
# 50  2011-11-04:12.00.00  16.0000  53.9000
# 51  2011-11-04:15.00.00  15.9200  53.7075
# 52  2011-11-04:18.00.00  15.9000  53.5000
# 53  2011-11-04:21.00.00  15.8975  53.2499
# 54  2011-11-05:00.00.00  16.0000  53.0000
# 55  2011-11-05:03.00.00  16.2550  52.7877
# 56  2011-11-05:06.00.00  16.6000  52.6000

# %%
tc_irad=np.empty((pos.shape[0],4))
tc_irad[:,0] = pos[:,0]-5
tc_irad[:,1] = pos[:,0]+5
tc_irad[:,2] = pos[:,1]-5
tc_irad[:,3] = pos[:,1]+5

# %%
dw10m=np.zeros((pos.shape[0],40,40))
ws=np.zeros((tc_irad.shape[0],))

# %%
tc_irad
# Out:
# array([[ 8.    , 18.    , 57.    , 67.    ],
#        [ 8.0005, 18.0005, 56.3875, 66.3875],
#        [ 8.    , 18.    , 56.    , 66.    ],
#        [ 7.9998, 17.9998, 55.9625, 65.9625],
#        [ 8.    , 18.    , 56.    , 66.    ],
#        [ 7.9999, 17.9999, 55.8352, 65.8352],
#        [ 8.    , 18.    , 55.5   , 65.5   ],
#        [ 8.    , 18.    , 55.    , 65.    ],
#        [ 8.    , 18.    , 55.    , 65.    ],
#        [ 8.1989, 18.1989, 54.8012, 64.8012],
#        [ 8.5   , 18.5   , 54.5   , 64.5   ],
#        [ 8.75  , 18.75  , 54.2126, 64.2126],
#        [ 9.    , 19.    , 54.    , 64.    ],
#        [ 9.1987, 19.1987, 54.0677, 64.0677],
#        [ 9.5   , 19.5   , 54.    , 64.    ],
#        [10.    , 20.    , 53.5   , 63.5   ],
#        [11.    , 21.    , 52.    , 62.    ],
#        [11.2037, 21.2037, 51.9587, 61.9587],
#        [11.    , 21.    , 52.5   , 62.5   ],
#        [11.    , 21.    , 52.325 , 62.325 ],
#        [11.    , 21.    , 52.    , 62.    ],
#        [10.9998, 20.9998, 51.8011, 61.8011],
#        [10.94  , 20.94  , 51.56  , 61.56  ],
#        [10.9167, 20.9167, 51.1842, 61.1842],
#        [10.9143, 20.9143, 51.1286, 61.1286],
#        [10.9251, 20.9251, 50.9048, 60.9048],
#        [10.95  , 20.95  , 50.65  , 60.65  ],
#        [10.9712, 20.9712, 50.5275, 60.5275],
#        [11.    , 21.    , 50.45  , 60.45  ],
#        [11.0425, 21.0425, 50.3698, 60.3698],
#        [11.1   , 21.1   , 50.25  , 60.25  ],
#        [11.1675, 21.1675, 50.0425, 60.0425],
#        [11.25  , 21.25  , 49.75  , 59.75  ],
#        [11.3612, 21.3612, 49.75  , 59.75  ],
#        [11.7   , 21.7   , 49.75  , 59.75  ],
#        [11.8688, 21.8688, 49.5962, 59.5962],
#        [12.    , 22.    , 49.5   , 59.5   ],
#        [11.9919, 21.9919, 49.5044, 59.5044],
#        [11.95  , 21.95  , 49.55  , 59.55  ],
#        [12.0175, 22.0175, 49.5675, 59.5675],
#        [12.1   , 22.1   , 49.6   , 59.6   ],
#        [12.1167, 22.1167, 49.7309, 59.7309],
#        [12.1   , 22.1   , 49.9   , 59.9   ],
#        [12.0937, 22.0937, 50.0626, 60.0626],
#        [12.05  , 22.05  , 50.15  , 60.15  ],
#        [11.9667, 21.9667, 50.1172, 60.1172],
#        [11.7333, 21.7333, 49.9333, 59.9333],
#        [11.448 , 21.448 , 49.6681, 59.6681],
#        [11.3   , 21.3   , 49.3   , 59.3   ],
#        [11.1349, 21.1349, 49.085 , 59.085 ],
#        [11.    , 21.    , 48.9   , 58.9   ],
#        [10.92  , 20.92  , 48.7075, 58.7075],
#        [10.9   , 20.9   , 48.5   , 58.5   ],
#        [10.8975, 20.8975, 48.2499, 58.2499],
#        [11.    , 21.    , 48.    , 58.    ],
#        [11.255 , 21.255 , 47.7877, 57.7877],
#        [11.6   , 21.6   , 47.6   , 57.6   ]])

# %%
ws.shape
# Out:
# (57,)

# %%
for it in range(tc_irad.shape[0]):
    latn, lats, lone, lonw = tc_irad[it,:]
    
    #dw10m[it,:,:]=dm0[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:40,0:40]
    dw10m[it,:,:]=dm0.ws10[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw))[0:40,0:40]
    ws[it]=np.max(dw10m[it,:,:])

# %%
ws
# Out:
# array([12.05509853, 11.66478825, 12.07604504, 11.88857841, 12.55070496,
#        12.08392239, 12.90496159, 12.65021706, 13.25035191, 13.00758076,
#        13.17536736, 14.1374321 , 13.27536297, 13.51172256, 13.52567101,
#        12.95095158, 13.65272713, 13.64632225, 14.53664303, 16.35745811,
#        16.06983185, 15.78394222, 15.19727612, 14.84628487, 15.88924885,
#        17.5984745 , 17.59850693, 19.33740234, 19.12825584, 18.45531464,
#        17.35936546, 15.83073139, 14.12554932, 14.23485565, 12.30214977,
#        13.59609509, 14.18544102, 13.29693699, 12.36727428, 11.38127613,
#        10.5955925 , 10.75936127, 11.47606468, 11.67092609, 11.5416317 ,
#         9.21051979,  8.80557537,  7.34166002,  7.70041037,  8.40463257,
#         8.8862772 ,  9.780406  ,  8.78766441,  7.37512922,  7.32679033,
#         7.26692009,  8.62913418])

# %%
plt.plot(ws)
plt.show()

# %%
df = pd.DataFrame(data=ws, columns=["w10max"])

# %%
df
# Out:
#        w10max
# 0   12.055099
# 1   11.664788
# 2   12.076045
# 3   11.888578
# 4   12.550705
# 5   12.083922
# 6   12.904962
# 7   12.650217
# 8   13.250352
# 9   13.007581
# 10  13.175367
# 11  14.137432
# 12  13.275363
# 13  13.511723
# 14  13.525671
# 15  12.950952
# 16  13.652727
# 17  13.646322
# 18  14.536643
# 19  16.357458
# 20  16.069832
# 21  15.783942
# 22  15.197276
# 23  14.846285
# 24  15.889249
# 25  17.598475
# 26  17.598507
# 27  19.337402
# 28  19.128256
# 29  18.455315
# 30  17.359365
# 31  15.830731
# 32  14.125549
# 33  14.234856
# 34  12.302150
# 35  13.596095
# 36  14.185441
# 37  13.296937
# 38  12.367274
# 39  11.381276
# 40  10.595592
# 41  10.759361
# 42  11.476065
# 43  11.670926
# 44  11.541632
# 45   9.210520
# 46   8.805575
# 47   7.341660
# 48   7.700410
# 49   8.404633
# 50   8.886277
# 51   9.780406
# 52   8.787664
# 53   7.375129
# 54   7.326790
# 55   7.266920
# 56   8.629134

# %%
df.to_csv(p1+'time_series/2011_w10max_nio_keila.csv')
