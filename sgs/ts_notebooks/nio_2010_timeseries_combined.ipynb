# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
# !ls -lrt ../create_ts/outputs/targets/*2010*
# Out:
# -rwxrwxrwx 1 saranya saranya 1273 Aug 16 14:12 ../create_ts/outputs/targets/2010_tot_ppt_max_nio_bandu.csv
# -rwxrwxrwx 1 saranya saranya 1194 Aug 16 14:12 ../create_ts/outputs/targets/2010_tot_ppt_int_nio_jal.csv
# -rwxrwxrwx 1 saranya saranya  765 Aug 16 14:12 ../create_ts/outputs/targets/2010_pmin_nio_jal.csv
# -rwxrwxrwx 1 saranya saranya 1225 Aug 16 14:13 ../create_ts/outputs/targets/2010_tot_ppt_max_nio_phet.csv
# -rwxrwxrwx 1 saranya saranya 1249 Aug 16 14:13 ../create_ts/outputs/targets/2010_tot_ppt_int_nio_bandu.csv
# -rwxrwxrwx 1 saranya saranya 1205 Aug 16 14:13 ../create_ts/outputs/targets/2010_tot_ppt_int_nio_phet.csv
# -rwxrwxrwx 1 saranya saranya 1206 Aug 16 14:13 ../create_ts/outputs/targets/2010_tot_ppt_max_nio_jal.csv
# -rwxrwxrwx 1 saranya saranya  814 Aug 16 14:13 ../create_ts/outputs/targets/2010_pmin_nio_bandu.csv
# -rwxrwxrwx 1 saranya saranya  744 Aug 16 14:13 ../create_ts/outputs/targets/2010_pmin_nio_phet.csv

# %%
# !ls /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/create_ts/outputs/*era5*bandu*
# Out:
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/create_ts/outputs/timeseries_era5_nio_bandu.csv

# %%
# !ls /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/*2010*
# Out:
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/2010_w10max_nio_bandu.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/2010_w10max_nio_jal.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/2010_w10max_nio_phet.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/inder_2010_nio_bandu.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/inder_2010_nio_jal.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/inder_2010_nio_phet.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/outder_2010_nio_bandu.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/outder_2010_nio_jal.csv
# /media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/outder_2010_nio_phet.csv

# %%
output="/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/time_series/"
rest="/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/create_ts/outputs/"
target="/media/saranya/DAEA17D6EA17ADAF/Data/Research_2022/jun22/create_ts/outputs/targets/"

# %%
#2010
wdf_12010=pd.read_csv(output+'2010_w10max_nio_phet.csv',delimiter=r",")
wdf_12010.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
wdf_12010=wdf_12010.drop('a', axis=1)

mdf_12010=pd.read_csv(target+'2010_pmin_nio_phet.csv',delimiter=r",")
mdf_12010.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
mdf_12010=mdf_12010.drop('a', axis=1)
mdf_12010=mdf_12010[:-1]

# %%
wdf_12010
# Out:
#        w10max
# 0   13.242209
# 1   14.061127
# 2   15.274748
# 3   13.716768
# 4   13.975719
# 5   17.300179
# 6   18.241474
# 7   18.400702
# 8   16.727667
# 9   18.555166
# 10  16.832348
# 11  15.720375
# 12  15.430286
# 13  17.323727
# 14  18.578655
# 15  19.784384
# 16  15.200377
# 17  15.601810
# 18  16.568388
# 19  16.572796
# 20  15.380006
# 21  17.485880
# 22  18.518286
# 23  20.027882
# 24  18.408569
# 25  17.470491
# 26  17.202511
# 27  18.123789
# 28  18.557810
# 29  21.295340
# 30  21.735962
# 31  22.570778
# 32  22.563053
# 33  22.553549
# 34  23.749649
# 35  24.931105
# 36  25.135933
# 37  25.271603
# 38  23.427956
# 39  21.760717
# 40  20.816755
# 41  18.974573
# 42  18.811260
# 43  17.836908
# 44  17.230509
# 45  16.585646
# 46  18.454863
# 47  19.243513
# 48  17.597097
# 49  17.851477
# 50  18.880049
# 51  19.476261
# 52  18.310926
# 53  19.023933
# 54  19.494619
# 55  19.817841

# %%
#derived
inder=pd.read_csv(output+'inder_2010_nio_phet.csv',delimiter=r",")
inder.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
inder=inder.drop('a', axis=1)
outder=pd.read_csv(output+'outder_2010_nio_phet.csv',delimiter=r",")
outder.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
outder=outder.drop('a', axis=1)

#df = pd.concat(list_of_dataframes)
ts_12010=pd.read_csv(rest+'timeseries_era5_nio_phet.csv',delimiter=r",")
ts_12010.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
ts_12010=ts_12010.drop('a', axis=1)
ts_12010=ts_12010[:-1] #drop the last  row
ts_inner=ts_12010.drop(list(ts_12010)[113:226], axis=1) #divide the columns in to inner and outer timeseries
ts_outer=ts_12010.drop(list(ts_12010)[0:113], axis=1)

# %%
ts_inner
# Out:
#       2mdewtmp       2mtmp  conv_ppt  tot_cld_ice  tot_cldwtr  tot_cld_rain  \
# 0   298.419617  300.875229  0.001898     0.502789    0.233804      0.565022
# 1   298.398743  301.219833  0.001248     0.411952    0.196015      0.523478
# 2   298.497154  301.165558  0.001266     0.408353    0.146683      0.397098
# 3   298.593147  300.751053  0.001006     0.304605    0.139012      0.286300
# 4   298.695526  301.007088  0.001765     0.321349    0.246240      0.619451
# 5   298.644104  301.014122  0.002197     0.416650    0.251933      0.968714
# 6   298.795166  301.078804  0.002284     0.604140    0.328243      1.251977
# 7   298.634468  301.078735  0.001410     0.712518    0.263946      1.122135
# 8   298.999817  301.455986  0.001325     0.520830    0.138417      0.622550
# 9   299.119164  301.425797  0.001581     0.559658    0.167627      0.335990
# 10  299.173790  301.379417  0.001442     0.548372    0.253096      0.527343
# ...

# %%
ts_outer
# Out:
#     out2mdewtmp    out2mtmp  outconv_ppt  outtot_cld_ice  outtot_cldwtr  \
# 0    297.880826  302.251579     0.000301        0.125289       0.071548
# 1    298.107499  301.965299     0.000250        0.113524       0.069020
# 2    298.267762  301.849402     0.000217        0.110092       0.067183
# 3    298.374320  301.561121     0.000292        0.115753       0.069085
# 4    298.394323  301.505966     0.000251        0.115910       0.065155
# 5    298.336570  301.765575     0.000225        0.105198       0.058853
# 6    298.102858  302.315473     0.000231        0.097249       0.061972
# 7    297.881664  302.668045     0.000190        0.082171       0.070690
# 8    297.855410  302.800720     0.000236        0.074249       0.067363
# 9    297.944750  302.633944     0.000232        0.066280       0.053434
# 10   298.195333  302.429288     0.000172        0.057354       0.054811
# 11   298.306250  302.170450     0.000153        0.064442       0.064053
# ...

# %%
df=pd.concat([mdf_12010,wdf_12010,inder,ts_inner,outder,ts_outer], axis=1, join='inner')

# %%
df=df.drop('ws10', axis=1)
df=df.drop('out_ws10', axis=1)
df
# Out:
#            Pmin     w10max    div100    div200    div250        div300  \
# 0   1003.345625  13.242209  0.000058  0.000040  0.000021  1.026462e-05
# 1   1004.481250  14.061127  0.000053  0.000041  0.000018  1.618795e-05
# 2   1004.759375  15.274748  0.000046  0.000032  0.000022  1.750867e-05
# 3   1001.894375  13.716768  0.000040  0.000023  0.000004  7.797114e-06
# 4   1000.238125  13.975719  0.000031  0.000043  0.000019  1.406788e-05
# 5   1000.558750  17.300179  0.000051  0.000056  0.000032  1.973534e-05
# 6   1000.528125  18.241474  0.000058  0.000066  0.000045  1.985543e-05
# 7    998.721250  18.400702  0.000070  0.000057  0.000036  5.151677e-06
# 8    998.595625  16.727667  0.000050  0.000022  0.000036  1.194702e-06
# 9    998.102500  18.555166  0.000065  0.000020  0.000026 -8.424098e-06
# 10   998.638750  16.832348  0.000070  0.000019  0.000008 -1.625986e-06
# 11   996.407500  15.720375  0.000063  0.000009  0.000013  1.980238e-05
# ...

# %%
df.to_csv(rest+'timeseries_all_nio_phet2010.csv')

# %%
v1=df.columns.values.tolist()
v1
# Out:
# ['Pmin',
#  'w10max',
#  'div100',
#  'div200',
#  'div250',
#  'div300',
#  'div400',
#  'div500',
#  'eqt1000',
#  'eqt200',
#  'eqt250',
#  'eqt300',
#  'eqt400',
#  'eqt500',
#  'eqt600',
#  'eqt700',
#  'eqt850',
#  'eqt925',
#  'sh850_200',
#  'sh850_250',
#  'sh925_200',
#  'sh925_250',
#  'ws10',
#  'wstrss10',
#  '2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'conv_rrate',
#  'ls_rrate',
#  'mn_conv_prate',
#  'mn_ls_prate',
#  'mn_tot_prate',
#  'sst',
#  'vort_10',
#  'vort_20',
#  'vort_30',
#  'vort_50',
# ...

# %%
var_names1=ts_12001.columns.values.tolist()

# %%
var_names1[0:113]
# Out:
# ['2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'conv_rrate',
#  'ls_rrate',
#  'mn_conv_prate',
#  'mn_ls_prate',
#  'mn_tot_prate',
#  'sst',
#  'vort_10',
#  'vort_20',
#  'vort_30',
#  'vort_50',
#  'vort_70',
#  'vort_100',
#  'vort_150',
#  'vort_200',
#  'vort_250',
#  'vort_300',
#  'vort_400',
#  'vort_500',
#  'vort_600',
#  'vort_700',
#  'vort_800',
#  'vort_850',
#  'vort_900',
#  'vort_925',
#  'vort_950',
#  'vort_975',
#  'vort_1000',
#  'rhum_10',
#  'rhum_20',
#  'rhum_30',
#  'rhum_50',
#  'rhum_70',
# ...
