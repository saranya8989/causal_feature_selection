# %%
import pandas as pd
import numpy as np
import xarray as xr

# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

from scipy.integrate import dblquad

# %%
datapath="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/Data/ECMWF/ERA5_25kmx3hr/"
target="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/create_ts/outputs/targets/"
p1="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/create_ts/"

# %%
dm1=xr.open_dataset(datapath+'/slev_vars/totprec_2011_2020.nc')

# %%
dm0=xr.open_dataset(datapath+'/slev_vars/svars_2020.nc')

# %%
dm1
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 29224, lon: 1440, lat: 721)
# Coordinates:
#   * time     (time) datetime64[ns] 2011-01-01 ... 2020-12-31T21:00:00
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
# Data variables:
#     var228   (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.10 (https://mpimet.mpg.d...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Thu Aug 11 13:56:13 2022: cdo -f nc copy totprec_2011_2020....
#     CDO:          Climate Data Operators version 1.9.10 (https://mpimet.mpg.d...

# %%
track=pd.read_csv(p1+'tracks_wp/nwp_20201025.csv',delimiter=r",")
lon1=track['lon'].to_numpy()
lat1=track['lat'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)
pos.shape
# Out:
# (97, 2)

# %% [markdown]
# # 2920 is one year timesteps

# %%
track['time'].info()

print(track['time'][0])
print(track['time'][96])

#amphan [[48:99] (may 14.00.00 to may 20.06.00)
#vongfong [2:83] (may 8 06.00 to may 18. 06.00) 
#chanhom oct 3.06.00 to oct 16.21.00 [2:112]
#saudel oct.16.12.00 to oct.26.06.00 [108:187]
#molave oct.21.18.00 to oct.29.00.00 [150:209] 
#goni oct.25.06.00.00 to nov.6.06.00 [178:275] 2386 : 2483
#atsani oct.29.12.00 to nov.07.15.00 [212:286] [2420:2494]
#vamco nov.8.00.00 to nov.16.06.00 [288:355]
#fani dm1.time[928:986]
#luban[2222:2291]
#gaja 2505:2559
#ockhi [2654:2709]
#vardah [2722:2772]
#kyant [2352:2419]
#roanu [1096:1137]
#ashoba[1258:1307]
#chapala [2396:2449]
#megh [2460:2508]
#nanauk [1266:1317]
#hudhud 2258:2309
#nilofar 2364:2437
#viyaru 1030:1083
#phailin [2236:2279]
#lehar [2582:2651]
#madi [2704:2765]
#keila 2410:2467
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 97 entries, 0 to 96
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 97 non-null     object
# dtypes: object(1)
# memory usage: 904.0+ bytes
# 2020-10-25:06.00.00
# 2020-11-06:06.00.00

# %%
dm1.time[28682:28779]
# Out:
# <xarray.DataArray 'time' (time: 97)>
# array(['2020-10-25T06:00:00.000000000', '2020-10-25T09:00:00.000000000',
#        '2020-10-25T12:00:00.000000000', '2020-10-25T15:00:00.000000000',
#        '2020-10-25T18:00:00.000000000', '2020-10-25T21:00:00.000000000',
#        '2020-10-26T00:00:00.000000000', '2020-10-26T03:00:00.000000000',
#        '2020-10-26T06:00:00.000000000', '2020-10-26T09:00:00.000000000',
#        '2020-10-26T12:00:00.000000000', '2020-10-26T15:00:00.000000000',
#        '2020-10-26T18:00:00.000000000', '2020-10-26T21:00:00.000000000',
#        '2020-10-27T00:00:00.000000000', '2020-10-27T03:00:00.000000000',
#        '2020-10-27T06:00:00.000000000', '2020-10-27T09:00:00.000000000',
#        '2020-10-27T12:00:00.000000000', '2020-10-27T15:00:00.000000000',
#        '2020-10-27T18:00:00.000000000', '2020-10-27T21:00:00.000000000',
#        '2020-10-28T00:00:00.000000000', '2020-10-28T03:00:00.000000000',
#        '2020-10-28T06:00:00.000000000', '2020-10-28T09:00:00.000000000',
#        '2020-10-28T12:00:00.000000000', '2020-10-28T15:00:00.000000000',
#        '2020-10-28T18:00:00.000000000', '2020-10-28T21:00:00.000000000',
#        '2020-10-29T00:00:00.000000000', '2020-10-29T03:00:00.000000000',
#        '2020-10-29T06:00:00.000000000', '2020-10-29T09:00:00.000000000',
#        '2020-10-29T12:00:00.000000000', '2020-10-29T15:00:00.000000000',
#        '2020-10-29T18:00:00.000000000', '2020-10-29T21:00:00.000000000',
#        '2020-10-30T00:00:00.000000000', '2020-10-30T03:00:00.000000000',
#        '2020-10-30T06:00:00.000000000', '2020-10-30T09:00:00.000000000',
#        '2020-10-30T12:00:00.000000000', '2020-10-30T15:00:00.000000000',
#        '2020-10-30T18:00:00.000000000', '2020-10-30T21:00:00.000000000',
#        '2020-10-31T00:00:00.000000000', '2020-10-31T03:00:00.000000000',
#        '2020-10-31T06:00:00.000000000', '2020-10-31T09:00:00.000000000',
#        '2020-10-31T12:00:00.000000000', '2020-10-31T15:00:00.000000000',
#        '2020-10-31T18:00:00.000000000', '2020-10-31T21:00:00.000000000',
#        '2020-11-01T00:00:00.000000000', '2020-11-01T03:00:00.000000000',
#        '2020-11-01T06:00:00.000000000', '2020-11-01T09:00:00.000000000',
#        '2020-11-01T12:00:00.000000000', '2020-11-01T15:00:00.000000000',
#        '2020-11-01T18:00:00.000000000', '2020-11-01T21:00:00.000000000',
#        '2020-11-02T00:00:00.000000000', '2020-11-02T03:00:00.000000000',
#        '2020-11-02T06:00:00.000000000', '2020-11-02T09:00:00.000000000',
#        '2020-11-02T12:00:00.000000000', '2020-11-02T15:00:00.000000000',
#        '2020-11-02T18:00:00.000000000', '2020-11-02T21:00:00.000000000',
#        '2020-11-03T00:00:00.000000000', '2020-11-03T03:00:00.000000000',
#        '2020-11-03T06:00:00.000000000', '2020-11-03T09:00:00.000000000',
#        '2020-11-03T12:00:00.000000000', '2020-11-03T15:00:00.000000000',
#        '2020-11-03T18:00:00.000000000', '2020-11-03T21:00:00.000000000',
#        '2020-11-04T00:00:00.000000000', '2020-11-04T03:00:00.000000000',
#        '2020-11-04T06:00:00.000000000', '2020-11-04T09:00:00.000000000',
#        '2020-11-04T12:00:00.000000000', '2020-11-04T15:00:00.000000000',
#        '2020-11-04T18:00:00.000000000', '2020-11-04T21:00:00.000000000',
#        '2020-11-05T00:00:00.000000000', '2020-11-05T03:00:00.000000000',
#        '2020-11-05T06:00:00.000000000', '2020-11-05T09:00:00.000000000',
#        '2020-11-05T12:00:00.000000000', '2020-11-05T15:00:00.000000000',
#        '2020-11-05T18:00:00.000000000', '2020-11-05T21:00:00.000000000',
#        '2020-11-06T00:00:00.000000000', '2020-11-06T03:00:00.000000000',
#        '2020-11-06T06:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2020-10-25T06:00:00 ... 2020-11-06T06:00:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %%
#2020  26296
#vongfong  1026:1107 
#chanhom  2210:2320
#saudel 2316:2395
#molave 2358:2417
#goni 2386:2483
#atsani
#vamco




#2019          23376
#neoguri  [2304:2421]
#bualoi  2314:2380
#halong 2436:2502
#nakri 2456:2515
#fengshen 2506:2570
#kalmaegi 2502:2605
#fungwong 2564:2617
#kammuri 2620:2717



#wp start from 2014    20456
#2018 jelawat 650:733
#maliksi 1230:1294
#kongrey 2156:2232
#yutu 2342:2451


#muifa 894:947   17536
#lan 2296:2360
#damrey 2424:2465
#haikul 2484:2541



#megi 2120:2183      14608
#sarika 2286:2347
#haima 2298:2367


#maysak 670:769     11688
#mujigae 2176:2219
#koppu 2272:2347
#infa 2558:2639

#tapah 924:971       8768
#nuri 2416:2478
#hagupit 2666:2765

#yagi 1254:1319   5848 addition
#fitow 2170:2235
#danas 2184:2248
#francisco 2300:2386
#krosa 2398:2463
#haiyan 2442:2517


#guchol 1288:1367
#gaemi 2176:2245
#maria 2286:2345
#sontinh 2356:2421
#bopha 2636:2747


#songda 1110:1186
#2011 haima 1330:1407
#nalgae 2148:2221
#washi 2758:2819

# %%
dm0.time[2386:2483]
# Out:
# <xarray.DataArray 'time' (time: 97)>
# array(['2020-10-25T06:00:00.000000000', '2020-10-25T09:00:00.000000000',
#        '2020-10-25T12:00:00.000000000', '2020-10-25T15:00:00.000000000',
#        '2020-10-25T18:00:00.000000000', '2020-10-25T21:00:00.000000000',
#        '2020-10-26T00:00:00.000000000', '2020-10-26T03:00:00.000000000',
#        '2020-10-26T06:00:00.000000000', '2020-10-26T09:00:00.000000000',
#        '2020-10-26T12:00:00.000000000', '2020-10-26T15:00:00.000000000',
#        '2020-10-26T18:00:00.000000000', '2020-10-26T21:00:00.000000000',
#        '2020-10-27T00:00:00.000000000', '2020-10-27T03:00:00.000000000',
#        '2020-10-27T06:00:00.000000000', '2020-10-27T09:00:00.000000000',
#        '2020-10-27T12:00:00.000000000', '2020-10-27T15:00:00.000000000',
#        '2020-10-27T18:00:00.000000000', '2020-10-27T21:00:00.000000000',
#        '2020-10-28T00:00:00.000000000', '2020-10-28T03:00:00.000000000',
#        '2020-10-28T06:00:00.000000000', '2020-10-28T09:00:00.000000000',
#        '2020-10-28T12:00:00.000000000', '2020-10-28T15:00:00.000000000',
#        '2020-10-28T18:00:00.000000000', '2020-10-28T21:00:00.000000000',
#        '2020-10-29T00:00:00.000000000', '2020-10-29T03:00:00.000000000',
#        '2020-10-29T06:00:00.000000000', '2020-10-29T09:00:00.000000000',
#        '2020-10-29T12:00:00.000000000', '2020-10-29T15:00:00.000000000',
#        '2020-10-29T18:00:00.000000000', '2020-10-29T21:00:00.000000000',
#        '2020-10-30T00:00:00.000000000', '2020-10-30T03:00:00.000000000',
#        '2020-10-30T06:00:00.000000000', '2020-10-30T09:00:00.000000000',
#        '2020-10-30T12:00:00.000000000', '2020-10-30T15:00:00.000000000',
#        '2020-10-30T18:00:00.000000000', '2020-10-30T21:00:00.000000000',
#        '2020-10-31T00:00:00.000000000', '2020-10-31T03:00:00.000000000',
#        '2020-10-31T06:00:00.000000000', '2020-10-31T09:00:00.000000000',
#        '2020-10-31T12:00:00.000000000', '2020-10-31T15:00:00.000000000',
#        '2020-10-31T18:00:00.000000000', '2020-10-31T21:00:00.000000000',
#        '2020-11-01T00:00:00.000000000', '2020-11-01T03:00:00.000000000',
#        '2020-11-01T06:00:00.000000000', '2020-11-01T09:00:00.000000000',
#        '2020-11-01T12:00:00.000000000', '2020-11-01T15:00:00.000000000',
#        '2020-11-01T18:00:00.000000000', '2020-11-01T21:00:00.000000000',
#        '2020-11-02T00:00:00.000000000', '2020-11-02T03:00:00.000000000',
#        '2020-11-02T06:00:00.000000000', '2020-11-02T09:00:00.000000000',
#        '2020-11-02T12:00:00.000000000', '2020-11-02T15:00:00.000000000',
#        '2020-11-02T18:00:00.000000000', '2020-11-02T21:00:00.000000000',
#        '2020-11-03T00:00:00.000000000', '2020-11-03T03:00:00.000000000',
#        '2020-11-03T06:00:00.000000000', '2020-11-03T09:00:00.000000000',
#        '2020-11-03T12:00:00.000000000', '2020-11-03T15:00:00.000000000',
#        '2020-11-03T18:00:00.000000000', '2020-11-03T21:00:00.000000000',
#        '2020-11-04T00:00:00.000000000', '2020-11-04T03:00:00.000000000',
#        '2020-11-04T06:00:00.000000000', '2020-11-04T09:00:00.000000000',
#        '2020-11-04T12:00:00.000000000', '2020-11-04T15:00:00.000000000',
#        '2020-11-04T18:00:00.000000000', '2020-11-04T21:00:00.000000000',
#        '2020-11-05T00:00:00.000000000', '2020-11-05T03:00:00.000000000',
#        '2020-11-05T06:00:00.000000000', '2020-11-05T09:00:00.000000000',
#        '2020-11-05T12:00:00.000000000', '2020-11-05T15:00:00.000000000',
#        '2020-11-05T18:00:00.000000000', '2020-11-05T21:00:00.000000000',
#        '2020-11-06T00:00:00.000000000', '2020-11-06T03:00:00.000000000',
#        '2020-11-06T06:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2020-10-25T06:00:00 ... 2020-11-06T06:00:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %% [markdown]
# ##### cld_ice=dm0.var79[1030:1083]
# cld_liq=dm0.var78[1030:1083]
# cloud=cld_ice+cld_liq

# %%
cld_ice=dm0.var79[2386:2483]
cld_liq=dm0.var78[2386:2483]
cloud=cld_ice+cld_liq

# %%
precip=dm1.var228[28682:28779]

# %%
precip_nan=precip.where(precip>0, other='nan')

# %%
tc_irad=np.empty((pos.shape[0],4))
tc_irad[:,0] = pos[:,0]-5
tc_irad[:,1] = pos[:,0]+5
tc_irad[:,2] = pos[:,1]-5
tc_irad[:,3] = pos[:,1]+5

# %%
tc_irad
# Out:
# array([[  5.6   ,  15.6   , 138.9   , 148.9   ],
#        [  6.0399,  16.0399, 138.793 , 148.793 ],
#        [  6.4   ,  16.4   , 138.6   , 148.6   ],
#        [  6.6426,  16.6426, 138.272 , 148.272 ],
#        [  6.9   ,  16.9   , 137.9   , 147.9   ],
#        [  7.3125,  17.3125, 137.585 , 147.585 ],
#        [  7.8   ,  17.8   , 137.3   , 147.3   ],
#        [  8.3225,  18.3225, 137.02  , 147.02  ],
#        [  8.8   ,  18.8   , 136.8   , 146.8   ],
#        [  9.13  ,  19.13  , 136.647 , 146.647 ],
#        [  9.34  ,  19.34  , 136.62  , 146.62  ],
#        [  9.5942,  19.5942, 136.703 , 146.703 ],
#        [  9.8286,  19.8286, 136.757 , 146.757 ],
#        [ 10.0288,  20.0288, 136.694 , 146.694 ],
#        [ 10.26  ,  20.26  , 136.6   , 146.6   ],
#        [ 10.5075,  20.5075, 136.547 , 146.547 ],
#        [ 10.76  ,  20.76  , 136.45  , 146.45  ],
#        [ 10.9476,  20.9476, 136.24  , 146.24  ],
#        [ 11.1   ,  21.1   , 136.    , 146.    ],
#        [ 11.2149,  21.2149, 135.829 , 145.829 ],
#        [ 11.3   ,  21.3   , 135.65  , 145.65  ],
#        [ 11.3862,  21.3862, 135.419 , 145.419 ],
#        [ 11.4   ,  21.4   , 135.189 , 145.189 ],
#        [ 11.4168,  21.4168, 134.973 , 144.973 ],
#        [ 11.4455,  21.4455, 134.673 , 144.673 ],
#        [ 11.4886,  21.4886, 134.203 , 144.203 ],
#        [ 11.5333,  21.5333, 133.667 , 143.667 ],
#        [ 11.5714,  21.5714, 133.25  , 143.25  ],
#        [ 11.6   ,  21.6   , 132.833 , 142.833 ],
#        [ 11.6166,  21.6166, 132.334 , 142.334 ],
#        [ 11.6333,  21.6333, 131.8   , 141.8   ],
#        [ 11.6715,  21.6715, 131.279 , 141.279 ],
#        [ 11.7   ,  21.7   , 130.733 , 140.733 ],
#        [ 11.7108,  21.7108, 130.138 , 140.138 ],
#        [ 11.6667,  21.6667, 129.533 , 139.533 ],
#        [ 11.5167,  21.5167, 128.929 , 138.929 ],
#        [ 11.3667,  21.3667, 128.4   , 138.4   ],
#        [ 11.3246,  21.3246, 128.05  , 138.05  ],
#        [ 11.3333,  21.3333, 127.7   , 137.7   ],
#        [ 11.3678,  21.3678, 127.134 , 137.134 ],
#        [ 11.3667,  21.3667, 126.567 , 136.567 ],
#        [ 11.253 ,  21.253 , 126.204 , 136.204 ],
#        [ 11.1   ,  21.1   , 125.867 , 135.867 ],
#        [ 11.0058,  21.0058, 125.414 , 135.414 ],
#        [ 10.8667,  20.8667, 124.9   , 134.9   ],
#        [ 10.6107,  20.6107, 124.367 , 134.367 ],
#        [ 10.3   ,  20.3   , 123.8   , 133.8   ],
#        [  9.9949,  19.9949, 123.203 , 133.203 ],
#        [  9.7   ,  19.7   , 122.6   , 132.6   ],
#        [  9.4422,  19.4422, 122.051 , 132.051 ],
#        [  9.2   ,  19.2   , 121.467 , 131.467 ],
#        [  8.9248,  18.9248, 120.771 , 130.771 ],
#        [  8.7   ,  18.7   , 120.033 , 130.033 ],
#        [  8.5673,  18.5673, 119.324 , 129.324 ],
#        [  8.51  ,  18.51  , 118.567 , 128.567 ],
#        [  8.546 ,  18.546 , 117.751 , 127.751 ],
#        [  8.6667,  18.6667, 117.033 , 127.033 ],
#        [  8.8419,  18.8419, 116.441 , 126.441 ],
#        [  9.0333,  19.0333, 116.    , 126.    ],
#        [  9.2488,  19.2488, 115.348 , 125.348 ],
#        [  9.4333,  19.4333, 114.567 , 124.567 ],
#        [  9.5781,  19.5781, 113.981 , 123.981 ],
#        [  9.7333,  19.7333, 113.5   , 123.5   ],
#        [  9.9815,  19.9815, 113.209 , 123.209 ],
#        [ 10.1667,  20.1667, 112.833 , 122.833 ],
#        [ 10.2034,  20.2034, 112.324 , 122.324 ],
#        [ 10.1333,  20.1333, 111.8   , 121.8   ],
#        [ 10.1408,  20.1408, 111.418 , 121.418 ],
#        [ 10.1   ,  20.1   , 111.033 , 121.033 ],
#        [ 10.0408,  20.0408, 110.62  , 120.62  ],
#        [  9.9   ,  19.9   , 110.4   , 120.4   ],
#        [  9.8066,  19.8066, 110.259 , 120.259 ],
#        [  9.7333,  19.7333, 110.133 , 120.133 ],
#        [  9.7308,  19.7308, 109.987 , 119.987 ],
#        [  9.7667,  19.7667, 109.767 , 119.767 ],
#        [  9.7433,  19.7433, 109.436 , 119.436 ],
#        [  9.7   ,  19.7   , 109.133 , 119.133 ],
#        [  9.5667,  19.5667, 108.766 , 118.766 ],
#        [  9.4333,  19.4333, 108.533 , 118.533 ],
#        [  9.2924,  19.2924, 108.383 , 118.383 ],
#        [  9.3333,  19.3333, 108.3   , 118.3   ],
#        [  9.3092,  19.3092, 107.967 , 117.967 ],
#        [  9.3   ,  19.3   , 107.667 , 117.667 ],
#        [  9.3142,  19.3142, 107.428 , 117.428 ],
#        [  9.3333,  19.3333, 107.233 , 117.233 ],
#        [  9.3558,  19.3558, 107.002 , 117.002 ],
#        [  9.3667,  19.3667, 106.667 , 116.667 ],
#        [  9.2025,  19.2025, 106.469 , 116.469 ],
#        [  9.1   ,  19.1   , 106.367 , 116.367 ],
#        [  8.9275,  18.9275, 106.223 , 116.223 ],
#        [  8.9333,  18.9333, 105.933 , 115.933 ],
#        [  8.94  ,  18.94  , 105.596 , 115.596 ],
#        [  8.9636,  18.9636, 105.218 , 115.218 ],
#        [  9.0016,  19.0016, 104.862 , 114.862 ],
#        [  9.1   ,  19.1   , 104.4   , 114.4   ],
#        [  9.2586,  19.2586, 103.746 , 113.746 ],
#        [  9.45  ,  19.45  , 102.95  , 112.95  ]])

# %%
ppr=np.zeros((pos.shape[0],40,40))
pp=np.zeros((tc_irad.shape[0],))
ppm=np.zeros((tc_irad.shape[0],))
ppmaskcloud = np.zeros((pos.shape[0],40,40))

# %%
for it in range(tc_irad.shape[0]):
    latn, lats, lone, lonw = tc_irad[it,:]
    ppr[it,:,:]=precip[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw))[0:40,0:40]
    ppmaskcloud[it,:,:]=cloud[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw))[0:40,0:40]
    ppm[it]=np.nanmax(ppr[it,:,:])

# %%
def preproc_integration(array_precip=None,array_cloud=None,cloudmaskvalue=None):
    pprm = array_precip.copy().flatten()
    pprm[array_cloud.copy().flatten()<cloudmaskvalue] = 0
    return pprm.reshape(array_precip.shape)

# %%
cloudmaskvalue = np.nanpercentile(ppmaskcloud[...].flatten(),10)
masked_precip = [preproc_integration(ppr[i,...],ppmaskcloud[i,...],cloudmaskvalue) for i in range(ppr.shape[0])]
p=(np.trapz(np.trapz(np.asarray(masked_precip),dx=25,axis=1),dx=25,axis=1))
plt.plot(np.trapz(np.trapz(np.asarray(masked_precip),dx=25,axis=1),dx=25,axis=1))
plt.show()

# %%
p
# Out:
# array([ 479.259938  ,  921.18278146,  696.11884654,  564.99689817,
#         443.32034886,  705.5606693 ,  613.87643218,  726.9641757 ,
#         716.27050638,  676.3958931 ,  544.52195764,  491.98560417,
#         511.74968481,  703.29912007,  704.09364998,  562.18996644,
#         556.74128234,  620.25673687,  575.01256466,  463.40085566,
#         470.06651759,  684.12974477,  582.0312351 ,  532.99978375,
#         412.32801974,  535.01188755,  486.53557897,  512.43722439,
#         775.69626272, 1058.28024447,  879.91148233,  713.64343166,
#         572.32432067,  629.9906224 ,  468.77741814,  679.17972803,
#         785.91749072,  603.79311442,  501.62002444,  627.63139606,
#         677.31149495,  652.93468535,  804.23250794,  818.94904375,
#         870.96706033,  745.87978423,  651.64059401,  784.9714905 ,
#         872.16332555,  781.4770937 ,  590.67711234,  742.38181114,
#         867.77418852, 1302.50945687, 1252.80931592, 1112.52181232,
#        1084.06625688, 1256.23367727,  959.50879157,  658.9359045 ,
#         495.05986273,  398.94938469,  462.37975359,  566.7745322 ,
#         666.01082683,  616.55566096,  584.16165411,  639.52699304,
#         614.91385102,  423.32708836,  550.01549423,  598.67419302,
#         669.33996975,  744.95770037,  645.52769065,  678.49777639,
#         612.23804951,  540.40409625,  593.87132525,  539.7374928 ,
#         557.44640529,  703.45625281,  667.30096936,  578.70864868,
#         546.32097483,  605.91548681,  679.08719182,  551.12324655,
#         500.69868565,  468.46486628,  462.85793185,  345.672369  ,
#         330.45656979,  254.34993207,  300.2306819 ,  326.70654356,
#         408.83041918])

# %%
ppm=ppm*1000 #to convert to mm/hr

# %%
plt.plot(ppm)
#plt.plot(testm)
plt.show()

# %%
p.shape
# Out:
# (97,)

# %%
df = pd.DataFrame(data=ppm, columns=["tot_Prec_max"])
df1 = pd.DataFrame(data=p, columns=["tot_Prec_Intg"])

# %%
df.to_csv(target+'2020_tot_ppt_max_nwp_goni.csv')
df1.to_csv(target+'2020_tot_ppt_int_nwp_goni.csv')

# %%
plt.pcolormesh(np.ma.masked_less(ppmaskcloud[15,...],0.05))
plt.colorbar()
plt.show()

# %%
plt.pcolormesh(np.ma.masked_where(ppmaskcloud[15,...]<0.062,ppr[15,...]))
plt.colorbar()
plt.show()

# %%
cloudmaskvalue = np.nanpercentile(ppmaskcloud[...].flatten(),10)
testm = [np.mean(ppr[i,...][~np.ma.masked_where(ppmaskcloud[i,...]<cloudmaskvalue,ppr[i,...]).mask]) for i in range(ppr.shape[0])]

# %%
plt.plot(np.trapz(np.trapz(ppr,dx=25,axis=1),dx=25,axis=1))
plt.plot(np.trapz(np.trapz(np.asarray(masked_precip),dx=25,axis=1),dx=25,axis=1))
plt.show()

# %%
pp=pp*86400 #to convert to mm/day

# %%
np.nanpercentile(cloud[15,280:360,240:500],10)

# %%
cloud[15,280:360,240:500].plot()

# %%
import matplotlib.pyplot as plt
plt.pcolormesh(np.ma.masked_less(precip[15,280:360,240:500],0))
plt.show()

# %%
plt.pcolormesh(np.ma.masked_less(cloud[15,280:360,240:500],0.006958),cmap='magma')
plt.colorbar()
plt.show()
