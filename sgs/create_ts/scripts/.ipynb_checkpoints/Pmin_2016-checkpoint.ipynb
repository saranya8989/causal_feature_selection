# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
datapath="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/Data/ECMWF/ERA5_25kmx3hr/"
target="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/outputs/2016/"
p1="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/"

# %%
dm1=xr.open_dataset(datapath+'/mslp/mslp_2016.nc')

# %%
# !ls /work/FAC/FGSE/IDYST/tbeucler/default/saranya/causal/create_ts/2016/
# Out:
# 20160809_nio.csv  dianmu_wp.csv   ivette_ep.csv    madeline_ep.csv
# 20160816_nio.csv  earl_na.csv	  javier_ep.csv    malou_wp.csv
# 20160822_wp.csv   fiona_na.csv	  kay_ep.csv	   mindulle_wp.csv
# 20160827_na.csv   gaston_na.csv   kompasu_wp.csv   namtheun_wp.csv
# chanthu_wp.csv	  hermine_na.csv  lester_ep.csv    newton_ep.csv
# conson_wp.csv	  howard_ep.csv   lionrock_wp.csv  omais_wp.csv

# %%
track=pd.read_csv(p1+'2016/malou_wp.csv',delimiter=r",")
lon1=track['lon'].to_numpy()
lat1=track['lat'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)
pos.shape
# Out:
# (19, 2)

# %%
#for North Atlantic
lonx=np.mod(lon1,360)
pos = arr = np.stack((lat1, lonx), axis=1)
pos.shape
# Out:
# (19, 2)

# %%
pos
# Out:
# array([[ 24.75  , 124.55  ],
#        [ 25.0099, 124.608 ],
#        [ 25.35  , 124.8   ],
#        [ 25.8201, 125.215 ],
#        [ 26.35  , 125.75  ],
#        [ 26.8496, 126.242 ],
#        [ 27.2778, 126.8   ],
#        [ 27.8149, 127.458 ],
#        [ 28.3364, 128.091 ],
#        [ 28.7478, 128.608 ],
#        [ 29.0333, 129.133 ],
#        [ 29.2041, 129.661 ],
#        [ 29.3818, 130.3   ],
#        [ 29.7457, 131.149 ],
#        [ 30.275 , 132.15  ],
#        [ 30.9726, 133.291 ],
#        [ 31.475 , 134.45  ],
#        [ 31.7874, 135.568 ],
#        [ 32.3   , 136.4   ]])

# %%
track['time'].info()

track['time'][0]
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 19 entries, 0 to 18
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 19 non-null     object
# dtypes: object(1)
# memory usage: 280.0+ bytes
# '2016-09-05:12.00.00'

# %%
track['time'][18]
# Out:
# '2016-09-07:18.00.00'

# %%
dm1.time[1988:2007]
# Out:
# <xarray.DataArray 'time' (time: 19)>
# array(['2016-09-05T12:00:00.000000000', '2016-09-05T15:00:00.000000000',
#        '2016-09-05T18:00:00.000000000', '2016-09-05T21:00:00.000000000',
#        '2016-09-06T00:00:00.000000000', '2016-09-06T03:00:00.000000000',
#        '2016-09-06T06:00:00.000000000', '2016-09-06T09:00:00.000000000',
#        '2016-09-06T12:00:00.000000000', '2016-09-06T15:00:00.000000000',
#        '2016-09-06T18:00:00.000000000', '2016-09-06T21:00:00.000000000',
#        '2016-09-07T00:00:00.000000000', '2016-09-07T03:00:00.000000000',
#        '2016-09-07T06:00:00.000000000', '2016-09-07T09:00:00.000000000',
#        '2016-09-07T12:00:00.000000000', '2016-09-07T15:00:00.000000000',
#        '2016-09-07T18:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2016-09-05T12:00:00 ... 2016-09-07T18:00:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %%
#howard 1700:1757
#ivette 1720:1785
#javier 1750:1781
#kay 1832:1907
#lester 1890:2009
#madeline
#newton 1978:2011

#hermine 1926:2015
#gaston 1868:1973
#fiona 1830:1891
#earl 1714:1749
#wp_822 1878:1893
#na_827 1912:1953
#chanthu 1792:1847
#conson 1756:1829
#dianmu 1818:1857
#kompasu 1844:1875
#lionrock 1828:1863
#malou
#mindulle
#namtheun
#omais

# %%
dm0=dm1.var151[1828:1863]

# %%
dm0
# Out:
# <xarray.DataArray 'var151' (time: 35, lat: 721, lon: 1440)>
# [36338400 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2016-08-16T12:00:00 ... 2016-08-20T18:00:00
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
# Attributes:
#     table:    128

# %%
tc_irad=np.empty((pos.shape[0],4))
tc_irad[:,0] = pos[:,0]-5
tc_irad[:,1] = pos[:,0]+5
tc_irad[:,2] = pos[:,1]-5
tc_irad[:,3] = pos[:,1]+5

# %%
tc_irad
# Out:
# array([[16.    , 26.    , 84.    , 94.    ],
#        [16.1   , 26.1   , 83.867 , 93.867 ],
#        [16.2   , 26.2   , 83.7   , 93.7   ],
#        [16.3   , 26.3   , 83.4989, 93.4989],
#        [16.4   , 26.4   , 83.4   , 93.4   ],
#        [16.5   , 26.5   , 83.5   , 93.5   ],
#        [16.5   , 26.5   , 83.5   , 93.5   ],
#        [16.6712, 26.6712, 83.4483, 93.4483],
#        [17.    , 27.    , 83.2   , 93.2   ],
#        [17.428 , 27.428 , 82.6181, 92.6181],
#        [17.9   , 27.9   , 81.9   , 91.9   ],
#        [18.3268, 28.3268, 81.3133, 91.3133],
#        [18.7   , 28.7   , 80.7   , 90.7   ],
#        [19.    , 29.    , 80.    , 90.    ],
#        [19.    , 29.    , 79.4   , 89.4   ],
#        [19.026 , 29.026 , 78.859 , 88.859 ],
#        [19.1   , 29.1   , 78.4   , 88.4   ],
#        [19.2348, 29.2348, 78.02  , 88.02  ],
#        [19.4   , 29.4   , 77.7   , 87.7   ],
#        [19.5194, 29.5194, 77.2911, 87.2911],
#        [19.7   , 29.7   , 77.1   , 87.1   ],
#        [20.    , 30.    , 77.3   , 87.3   ],
#        [19.8   , 29.8   , 75.6   , 85.6   ],
#        [19.7103, 29.7103, 74.5486, 84.5486],
#        [19.7   , 29.7   , 74.    , 84.    ],
#        [19.6917, 29.6917, 73.6251, 83.6251],
#        [19.7   , 29.7   , 73.4   , 83.4   ],
#        [19.6795, 29.6795, 73.0999, 83.0999],
#        [19.7   , 29.7   , 72.8   , 82.8   ],
#        [19.8   , 29.8   , 72.5   , 82.5   ],
#        [19.8   , 29.8   , 72.3   , 82.3   ],
#        [19.7862, 29.7862, 72.2601, 82.2601],
#        [19.8   , 29.8   , 72.2   , 82.2   ],
#        [19.8799, 29.8799, 71.9219, 81.9219],
#        [20.    , 30.    , 71.5   , 81.5   ]])

# %%
pmin=np.zeros((pos.shape[0],40,40))
slp=np.zeros((tc_irad.shape[0],))

# %%
slp.shape
# Out:
# (35,)

# %%
for it in range(tc_irad.shape[0]):
    latn, lats, lone, lonw = tc_irad[it,:]
    pmin[it,:,:]=dm0[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw))[0:40,0:40]
    slp[it]=np.min(pmin[it,:,:])

# %%
slp=slp/100

# %%
slp
# Out:
# array([991.444375, 993.3825  , 993.1325  , 990.833125, 989.73125 ,
#        990.0075  , 990.2025  , 988.68375 , 988.590625, 991.545   ,
#        991.673125, 990.631875, 990.3275  , 992.535   , 991.99625 ,
#        990.886875, 990.644375, 993.575625, 992.41125 , 991.33125 ,
#        991.541875, 992.9475  , 994.2775  , 993.023125, 991.97625 ,
#        994.199375, 994.621875, 993.853125, 994.615625, 996.41625 ,
#        997.17625 , 995.80125 , 994.961875, 996.963125, 997.7225  ])

# %%
plt.plot(slp)
plt.show()

# %%
df = pd.DataFrame(data=slp, columns=["Pmin"])

# %%
df.to_csv(target+'2016_pmin_wp_lionrock.csv')
