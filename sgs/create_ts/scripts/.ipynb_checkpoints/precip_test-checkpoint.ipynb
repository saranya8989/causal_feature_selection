# %%
import pandas as pd
import numpy as np
import xarray as xr

# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

from scipy.integrate import dblquad

# %%
datapath="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/Data/ECMWF/ERA5_25kmx3hr/"
target="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/create_ts/outputs/targets/"
p1="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/create_ts/"

# %%
dm0=xr.open_dataset(datapath+'/slev_vars/svars_2011.nc')
dm1=xr.open_dataset(datapath+'/prate/prates_2011.nc')

# %%
track=pd.read_csv(p1+'tracks_wp/nwp_20110616.csv',delimiter=r",")
lon1=track['lon'].to_numpy()
lat1=track['lat'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)
pos.shape
# Out:
# (77, 2)

# %%
track['time'].info()

track['time'][0]

#fani dm1.time[928:986]
#luban[2222:2291]
#gaja 2505:2559
#ockhi [2654:2709]
#vardah [2722:2772]
#kyant [2352:2419]
#roanu [1096:1137]
#ashoba[1258:1307]
#chapala [2396:2449]
#megh [2460:2508]
#nanauk [1266:1317]
#hudhud 2258:2309
#nilofar 2364:2437
#viyaru 1030:1083
#phailin [2236:2279]
#lehar [2582:2651]
#madi [2704:2765]
#keila 2410:2467
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 77 entries, 0 to 76
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 77 non-null     object
# dtypes: object(1)
# memory usage: 744.0+ bytes
# '2011-06-16:06.00.00'

# %%
track['time'][76]
# Out:
# '2011-06-25:18.00.00'

# %%
dm1.time[1330:1407]
# Out:
# <xarray.DataArray 'time' (time: 77)>
# array(['2011-06-16T06:00:00.000000000', '2011-06-16T09:00:00.000000000',
#        '2011-06-16T12:00:00.000000000', '2011-06-16T15:00:00.000000000',
#        '2011-06-16T18:00:00.000000000', '2011-06-16T21:00:00.000000000',
#        '2011-06-17T00:00:00.000000000', '2011-06-17T03:00:00.000000000',
#        '2011-06-17T06:00:00.000000000', '2011-06-17T09:00:00.000000000',
#        '2011-06-17T12:00:00.000000000', '2011-06-17T15:00:00.000000000',
#        '2011-06-17T18:00:00.000000000', '2011-06-17T21:00:00.000000000',
#        '2011-06-18T00:00:00.000000000', '2011-06-18T03:00:00.000000000',
#        '2011-06-18T06:00:00.000000000', '2011-06-18T09:00:00.000000000',
#        '2011-06-18T12:00:00.000000000', '2011-06-18T15:00:00.000000000',
#        '2011-06-18T18:00:00.000000000', '2011-06-18T21:00:00.000000000',
#        '2011-06-19T00:00:00.000000000', '2011-06-19T03:00:00.000000000',
#        '2011-06-19T06:00:00.000000000', '2011-06-19T09:00:00.000000000',
#        '2011-06-19T12:00:00.000000000', '2011-06-19T15:00:00.000000000',
#        '2011-06-19T18:00:00.000000000', '2011-06-19T21:00:00.000000000',
#        '2011-06-20T00:00:00.000000000', '2011-06-20T03:00:00.000000000',
#        '2011-06-20T06:00:00.000000000', '2011-06-20T09:00:00.000000000',
#        '2011-06-20T12:00:00.000000000', '2011-06-20T15:00:00.000000000',
#        '2011-06-20T18:00:00.000000000', '2011-06-20T21:00:00.000000000',
#        '2011-06-21T00:00:00.000000000', '2011-06-21T03:00:00.000000000',
#        '2011-06-21T06:00:00.000000000', '2011-06-21T09:00:00.000000000',
#        '2011-06-21T12:00:00.000000000', '2011-06-21T15:00:00.000000000',
#        '2011-06-21T18:00:00.000000000', '2011-06-21T21:00:00.000000000',
#        '2011-06-22T00:00:00.000000000', '2011-06-22T03:00:00.000000000',
#        '2011-06-22T06:00:00.000000000', '2011-06-22T09:00:00.000000000',
#        '2011-06-22T12:00:00.000000000', '2011-06-22T15:00:00.000000000',
#        '2011-06-22T18:00:00.000000000', '2011-06-22T21:00:00.000000000',
#        '2011-06-23T00:00:00.000000000', '2011-06-23T03:00:00.000000000',
#        '2011-06-23T06:00:00.000000000', '2011-06-23T09:00:00.000000000',
#        '2011-06-23T12:00:00.000000000', '2011-06-23T15:00:00.000000000',
#        '2011-06-23T18:00:00.000000000', '2011-06-23T21:00:00.000000000',
#        '2011-06-24T00:00:00.000000000', '2011-06-24T03:00:00.000000000',
#        '2011-06-24T06:00:00.000000000', '2011-06-24T09:00:00.000000000',
#        '2011-06-24T12:00:00.000000000', '2011-06-24T15:00:00.000000000',
#        '2011-06-24T18:00:00.000000000', '2011-06-24T21:00:00.000000000',
#        '2011-06-25T00:00:00.000000000', '2011-06-25T03:00:00.000000000',
#        '2011-06-25T06:00:00.000000000', '2011-06-25T09:00:00.000000000',
#        '2011-06-25T12:00:00.000000000', '2011-06-25T15:00:00.000000000',
#        '2011-06-25T18:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2011-06-16T06:00:00 ... 2011-06-25T18:00:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %% [markdown]
# ##### cld_ice=dm0.var79[1030:1083]
# cld_liq=dm0.var78[1030:1083]
# cloud=cld_ice+cld_liq

# %%
cld_ice=dm0.var79[1330:1407]
cld_liq=dm0.var78[1330:1407]
cloud=cld_ice+cld_liq

# %%
convrr=dm1.var218[1330:1407]
lsrr=dm1.var219[1330:1407]
precip=convrr+lsrr

# %%
precip_nan=precip.where(precip>0, other='nan')

# %%
tc_irad=np.empty((pos.shape[0],4))
tc_irad[:,0] = pos[:,0]-5
tc_irad[:,1] = pos[:,0]+5
tc_irad[:,2] = pos[:,1]-5
tc_irad[:,3] = pos[:,1]+5

# %%
tc_irad
# Out:
# array([[  2.9    ,  12.9    , 124.     , 134.     ],
#        [  3.27999,  13.27999, 124.13   , 134.13   ],
#        [  3.6    ,  13.6    , 124.3    , 134.3    ],
#        [  3.835  ,  13.835  , 124.51   , 134.51   ],
#        [  4.13333,  14.13333, 124.483  , 134.483  ],
#        [ 15.3162 ,  25.3162 , 108.227  , 118.227  ],
#        [ 15.5    ,  25.5    , 108.125  , 118.125  ],
#        [ 15.7056 ,  25.7056 , 107.881  , 117.881  ],
#        [ 15.9    ,  25.9    , 107.55   , 117.55   ],
#        [ 16.0725 ,  26.0725 , 107.179  , 117.179  ],
#        [ 16.2    ,  26.2    , 106.775  , 116.775  ],
#        [ 16.2817 ,  26.2817 , 106.394  , 116.394  ],
#        [ 16.3    ,  26.3    , 105.975  , 115.975  ],
#        [ 16.2638 ,  26.2638 , 105.47   , 115.47   ],
#        [ 16.175  ,  26.175  , 104.95   , 114.95   ],
#        [ 16.0537 ,  26.0537 , 104.479  , 114.479  ],
#        [ 15.925  ,  25.925  , 104.05   , 114.05   ],
#        [ 15.8429 ,  25.8429 , 103.677  , 113.677  ],
#        [ 15.75   ,  25.75   , 103.3    , 113.3    ],
#        [ 15.5874 ,  25.5874 , 102.858  , 112.858  ],
#        [ 15.425  ,  25.425  , 102.375  , 112.375  ],
#        [ 15.3223 ,  25.3223 , 101.881  , 111.881  ],
#        [ 15.25   ,  25.25   , 101.35   , 111.35   ],
#        [ 15.1951 ,  25.1951 , 100.751  , 110.751  ],
#        [ 15.125  ,  25.125  , 100.175  , 110.175  ],
#        [ 15.0005 ,  25.0005 ,  99.692  , 109.692  ],
#        [ 14.84   ,  24.84   ,  99.3    , 109.3    ],
#        [ 14.7009 ,  24.7009 ,  98.994  , 108.994  ],
#        [ 14.5545 ,  24.5545 ,  98.709  , 108.709  ],
#        [ 14.3862 ,  24.3862 ,  98.399  , 108.399  ],
#        [ 14.2    ,  24.2    ,  98.04   , 108.04   ],
#        [ 14.0506 ,  24.0506 ,  97.405  , 107.405  ],
#        [ 13.9    ,  23.9    ,  96.8    , 106.8    ]])

# %%
ppr=np.zeros((pos.shape[0],40,40))
pp=np.zeros((tc_irad.shape[0],))
ppm=np.zeros((tc_irad.shape[0],))
ppmaskcloud = np.zeros((pos.shape[0],40,40))

# %%
for it in range(tc_irad.shape[0]):
    latn, lats, lone, lonw = tc_irad[it,:]
    ppr[it,:,:]=precip[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw))[0:40,0:40]
    ppmaskcloud[it,:,:]=cloud[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw))[0:40,0:40]
    ppm[it]=np.nanmax(ppr[it,:,:])

# %%
def preproc_integration(array_precip=None,array_cloud=None,cloudmaskvalue=None):
    pprm = array_precip.copy().flatten()
    pprm[array_cloud.copy().flatten()<cloudmaskvalue] = 0
    return pprm.reshape(array_precip.shape)

# %%
cloudmaskvalue = np.nanpercentile(ppmaskcloud[...].flatten(),10)
masked_precip = [preproc_integration(ppr[i,...],ppmaskcloud[i,...],cloudmaskvalue) for i in range(ppr.shape[0])]
p=(np.trapz(np.trapz(np.asarray(masked_precip),dx=25,axis=1),dx=25,axis=1))
plt.plot(np.trapz(np.trapz(np.asarray(masked_precip),dx=25,axis=1),dx=25,axis=1))
plt.show()

# %%
p
# Out:
# array([383.64622742, 272.26235718, 294.2009829 , 262.83059269,
#        229.23771292, 248.36027995, 234.85004902, 243.60492826,
#        261.95704937, 303.56798321, 264.88155127, 288.11106458,
#        271.69084176, 275.99193156, 225.83249956, 206.53033629,
#        170.40977255, 217.17214957, 281.90391138, 269.7824873 ,
#        197.86156714, 201.13255829, 141.00668952, 187.88922578,
#        205.45125008, 258.65240023, 264.96132836, 244.50968951,
#        195.19774243, 274.58250523, 246.18469179, 251.45500898,
#        282.51333162, 276.53440833, 227.22359747, 220.42263299,
#        247.44993076, 346.23835236, 373.27704951, 335.62479541,
#        299.70599338, 304.45260927, 206.60221577, 186.52699888,
#        249.21741337, 332.48554915, 338.26615661, 317.36737117,
#        296.07363045, 268.73199269, 184.67836082, 217.41479635,
#        219.50619295, 276.40042827, 242.83772334, 261.366833  ,
#        263.18242773, 207.72481337, 260.9610185 , 283.17194432,
#        321.20157033, 352.12190822, 328.53003591, 295.8753705 ,
#        357.37894475, 309.45291743, 282.60106221, 325.79708844,
#        327.6103735 , 350.94654188, 332.72689208, 337.36141399,
#        367.51259118, 287.66775504, 269.20972392, 264.5527944 ,
#        264.30385187])

# %%
ppm=ppm*3600 #to convert to mm/hr

# %%
plt.plot(ppm)
#plt.plot(testm)
plt.show()

# %%
df = pd.DataFrame(data=ppm, columns=["Prec_max"])
df1 = pd.DataFrame(data=p, columns=["Prec_Intg"])

# %%
df.to_csv(target+'2011_pratemax_nwp_haima.csv')
df1.to_csv(target+'2011_integrated_prate_nwp_haima.csv')

# %%
plt.pcolormesh(np.ma.masked_less(ppmaskcloud[15,...],0.05))
plt.colorbar()
plt.show()

# %%
plt.pcolormesh(np.ma.masked_where(ppmaskcloud[15,...]<0.062,ppr[15,...]))
plt.colorbar()
plt.show()

# %%
cloudmaskvalue = np.nanpercentile(ppmaskcloud[...].flatten(),10)
testm = [np.mean(ppr[i,...][~np.ma.masked_where(ppmaskcloud[i,...]<cloudmaskvalue,ppr[i,...]).mask]) for i in range(ppr.shape[0])]

# %%
plt.plot(np.trapz(np.trapz(ppr,dx=25,axis=1),dx=25,axis=1))
plt.plot(np.trapz(np.trapz(np.asarray(masked_precip),dx=25,axis=1),dx=25,axis=1))
plt.show()

# %%
pp=pp*86400 #to convert to mm/day

# %%
np.nanpercentile(cloud[15,280:360,240:500],10)

# %%
cloud[15,280:360,240:500].plot()

# %%
import matplotlib.pyplot as plt
plt.pcolormesh(np.ma.masked_less(precip[15,280:360,240:500],0))
plt.show()

# %%
plt.pcolormesh(np.ma.masked_less(cloud[15,280:360,240:500],0.006958),cmap='magma')
plt.colorbar()
plt.show()
