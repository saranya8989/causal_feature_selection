# %%
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nf
from netCDF4 import Dataset
# %matplotlib inline

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
datapath="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/Data/ECMWF/ERA5_25kmx3hr/"
target="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/create_ts/outputs/targets/"
p1="/work/FAC/FGSE/IDYST/tbeucler/default/saranya/create_ts/"

# %%
dm1=xr.open_dataset(datapath+'/mslp/mslp_2012.nc')

# %%
track=pd.read_csv(p1+'tracks_wp/nwp_20121012.csv',delimiter=r",")
lon1=track['lon'].to_numpy()
lat1=track['lat'].to_numpy()
pos = arr = np.stack((lat1, lon1), axis=1)
pos.shape
# Out:
# (59, 2)

# %%
#wp start from 2014
#2018 jelawat 650:733
#maliksi 1230:1294
#kongrey 2156:2232
#yutu 2342:2451


#muifa 894:947
#lan 2296:2360
#damrey 2424:2465
#haikul 2484:2541



#megi 2120:2183
#sarika 2286:2347
#haima 2298:2367


#maysak 670:769
#mujigae 2176:2219
#koppu 2272:2347
#infa 2558:2639

#tapah 924:971
#nuri 2416:2478
#hagupit 2666:2765

#yagi 1254:1319
#fitow 2170:2235
#danas 2184:2248
#francisco 2300:2386
#krosa 2398:2463
#haiyan 2444:2519


#guchol 1288:1367
#gaemi 2176:2245
#maria
#sontinh
#bopha


#songda
#2011 haima
#nalgae
#washi

# %%
track['time'].info()

track['time'][0]
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 69 entries, 0 to 68
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 69 non-null     object
# dtypes: object(1)
# memory usage: 680.0+ bytes
# '2012-09-29:00.00.00'

# %%
track['time'][68]
# Out:
# '2012-10-07:12.00.00'

# %%
dm1.time[2176:2245]
# Out:
# <xarray.DataArray 'time' (time: 69)>
# array(['2012-09-29T00:00:00.000000000', '2012-09-29T03:00:00.000000000',
#        '2012-09-29T06:00:00.000000000', '2012-09-29T09:00:00.000000000',
#        '2012-09-29T12:00:00.000000000', '2012-09-29T15:00:00.000000000',
#        '2012-09-29T18:00:00.000000000', '2012-09-29T21:00:00.000000000',
#        '2012-09-30T00:00:00.000000000', '2012-09-30T03:00:00.000000000',
#        '2012-09-30T06:00:00.000000000', '2012-09-30T09:00:00.000000000',
#        '2012-09-30T12:00:00.000000000', '2012-09-30T15:00:00.000000000',
#        '2012-09-30T18:00:00.000000000', '2012-09-30T21:00:00.000000000',
#        '2012-10-01T00:00:00.000000000', '2012-10-01T03:00:00.000000000',
#        '2012-10-01T06:00:00.000000000', '2012-10-01T09:00:00.000000000',
#        '2012-10-01T12:00:00.000000000', '2012-10-01T15:00:00.000000000',
#        '2012-10-01T18:00:00.000000000', '2012-10-01T21:00:00.000000000',
#        '2012-10-02T00:00:00.000000000', '2012-10-02T03:00:00.000000000',
#        '2012-10-02T06:00:00.000000000', '2012-10-02T09:00:00.000000000',
#        '2012-10-02T12:00:00.000000000', '2012-10-02T15:00:00.000000000',
#        '2012-10-02T18:00:00.000000000', '2012-10-02T21:00:00.000000000',
#        '2012-10-03T00:00:00.000000000', '2012-10-03T03:00:00.000000000',
#        '2012-10-03T06:00:00.000000000', '2012-10-03T09:00:00.000000000',
#        '2012-10-03T12:00:00.000000000', '2012-10-03T15:00:00.000000000',
#        '2012-10-03T18:00:00.000000000', '2012-10-03T21:00:00.000000000',
#        '2012-10-04T00:00:00.000000000', '2012-10-04T03:00:00.000000000',
#        '2012-10-04T06:00:00.000000000', '2012-10-04T09:00:00.000000000',
#        '2012-10-04T12:00:00.000000000', '2012-10-04T15:00:00.000000000',
#        '2012-10-04T18:00:00.000000000', '2012-10-04T21:00:00.000000000',
#        '2012-10-05T00:00:00.000000000', '2012-10-05T03:00:00.000000000',
#        '2012-10-05T06:00:00.000000000', '2012-10-05T09:00:00.000000000',
#        '2012-10-05T12:00:00.000000000', '2012-10-05T15:00:00.000000000',
#        '2012-10-05T18:00:00.000000000', '2012-10-05T21:00:00.000000000',
#        '2012-10-06T00:00:00.000000000', '2012-10-06T03:00:00.000000000',
#        '2012-10-06T06:00:00.000000000', '2012-10-06T09:00:00.000000000',
#        '2012-10-06T12:00:00.000000000', '2012-10-06T15:00:00.000000000',
#        '2012-10-06T18:00:00.000000000', '2012-10-06T21:00:00.000000000',
#        '2012-10-07T00:00:00.000000000', '2012-10-07T03:00:00.000000000',
#        '2012-10-07T06:00:00.000000000', '2012-10-07T09:00:00.000000000',
#        '2012-10-07T12:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2012-09-29 ... 2012-10-07T12:00:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %%
#amphan [[48:99] (may 14.00.00 to may 20.06.00)
#vongfong [2:83] (may 8 06.00 to may 18. 06.00) 
#chanhom oct 3.06.00 to oct 16.21.00 [2:112]
#saudel oct.16.12.00 to oct.26.06.00 [108:187]
#molave oct.21.18.00 to oct.29.00.00 [150:209] 
#goni oct.25.06.00.00 to nov.6.06.00 [178:275] 2386 : 2483
#atsani oct.29.12.00 to nov.07.15.00 [212:286] [2420:2494]
#vamco nov.8.00.00 to nov.16.06.00 [288:355]

# %%
dm0=dm1.var151[2176:2245]

# %%
tc_irad=np.empty((pos.shape[0],4))
tc_irad[:,0] = pos[:,0]-5
tc_irad[:,1] = pos[:,0]+5
tc_irad[:,2] = pos[:,1]-5
tc_irad[:,3] = pos[:,1]+5

# %%
pmin=np.zeros((pos.shape[0],40,40))
slp=np.zeros((tc_irad.shape[0],))

# %%
slp.shape
# Out:
# (69,)

# %%
for it in range(tc_irad.shape[0]):
    latn, lats, lone, lonw = tc_irad[it,:]
    #test.append(dm.slp[it,:,:].sel(lat=slice(latn,lats),lon=slice(lone,lonw)))
    pmin[it,:,:]=dm0[it,:,:].sel(lat=slice(lats,latn),lon=slice(lone,lonw))[0:40,0:40]
    slp[it]=np.min(pmin[it,:,:])

# %%
slp=slp/100

# %%
slp
# Out:
# array([1007.2625  , 1008.311875, 1006.141875, 1005.035625, 1006.63    ,
#        1008.118125, 1006.6425  , 1005.6375  , 1007.515   , 1007.885625,
#        1005.984375, 1005.605625, 1007.214375, 1008.269375, 1006.9025  ,
#        1006.693125, 1008.71125 , 1008.66875 , 1006.499375, 1006.23375 ,
#        1007.389375, 1008.19375 , 1006.63875 , 1006.288125, 1007.28625 ,
#        1006.645625, 1003.548125, 1002.569375, 1002.416875, 1001.69625 ,
#         999.78625 ,  998.82625 , 1000.023125,  999.304375,  996.790625,
#         996.0775  ,  998.3875  ,  998.496875,  997.398125,  996.665   ,
#         998.876875,  998.86875 ,  996.65625 ,  996.251875,  998.33375 ,
#         999.18    ,  998.06875 ,  997.093125,  999.944375, 1001.49    ,
#        1000.020625,  999.779375, 1001.770625, 1002.706875, 1001.960625,
#        1001.045625, 1004.209375, 1005.22625 , 1004.105   , 1003.13375 ,
#        1005.95125 , 1008.180625, 1006.33125 , 1004.72875 , 1007.161875,
#        1008.40125 , 1006.7825  , 1005.518125, 1006.87125 ])

# %%
plt.plot(slp)
plt.show()

# %%
df = pd.DataFrame(data=slp, columns=["Pmin"])

# %%
df.to_csv(target+'2012_pmin_nwp_gaemi.csv')
