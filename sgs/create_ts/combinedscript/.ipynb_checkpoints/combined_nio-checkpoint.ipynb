# %%
# Imports
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline     
## use `%matplotlib notebook` for interactive figures
# plt.style.use('ggplot')


import tigramite
from tigramite import data_processing as pp
from tigramite.toymodels import structural_causal_processes as toys

from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests import ParCorr, GPDC, CMIknn, CMIsymb

import pandas as pd
import numpy as np

from tigramite.models import Models, Prediction

import math
#import sklearn
#from sklearn.linear_model import LinearRegression
# Out:
# /home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/plotting.py:26: UserWarning: [Errno 2] No such file or directory: '/home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/../versions.py'
#   warnings.warn(str(e))
# /home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/independence_tests/gpdc.py:27: UserWarning: [Errno 2] No such file or directory: '/home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/independence_tests/../../versions.py'
#   warnings.warn(str(e))
# /home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/independence_tests/gpdc_torch.py:33: UserWarning: No module named 'torch'
#   warnings.warn(str(e))
# /home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/models.py:29: UserWarning: [Errno 2] No such file or directory: '/home/saranya/anaconda3/envs/bmap/lib/python3.8/site-packages/tigramite/../versions.py'
#   warnings.warn(str(e))

# %%
def select_links(tau_min, tau_max, parents, children):
    """
    This function selects the causal links that will be tested by
    PCMCI. The links are selected such that per each variable in
    `children` all `parents` are stablished as causes, and no other
    causal relationships exist.
    
    Assumes `parents` and `children` are disjoint sets, and that all
    variables are included in the union of both sets.
    
    Parameters
    ----------
    tau_min : int
        Minimum time lag to test. Note that zero-lags are undirected.
    tau_max : int
        Maximum time lag. Must be larger or equal to tau_min.
    parents : set of int
        List of variables that will be assigned as a parent link.
        Assumed to be disjoint with children
    children : set of int
        List of variables that will be assigned a link from a parent.
        Assumed to be disjoint with parents
    Returns
    -------
    selected_links: dict
        Dictionary of selected links for Tigramite
        
    """

    parents = set(parents)
    children = set(children)

    selected_links = dict()
    # Set the default as all combinations of the selected variables
    for var in [*children, *parents]:
        if var in children:
            # Children can be caused only by parents and by themselves
            selected_links[var] = [
                (parent, -lag)
                for parent in parents
                for lag in range(tau_min, tau_max + 1)
            ]
        else:
            selected_links[var] = []

    return selected_links

# %%
p1="../../tigramite_timeseries/"
p2="../../targets/"

# %%
df1 = pd.read_csv(p1+"timeseries_all_nio_vayu.csv",sep=',')
df1.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df1=df1.drop('a', axis=1)
df1=df1.drop('conv_rrate', axis=1)
df1=df1.drop('ls_rrate', axis=1)
df1=df1.drop('mn_conv_prate', axis=1)
df1=df1.drop('mn_ls_prate', axis=1)
df1=df1.drop('mn_tot_prate', axis=1)
df1=df1.drop('outconv_rrate', axis=1)
df1=df1.drop('outls_rrate', axis=1)
df1=df1.drop('outmn_conv_prate', axis=1)
df1=df1.drop('outmn_ls_prate', axis=1)
df1=df1.drop('outmn_tot_prate', axis=1)
d1=pd.read_csv(p2+'2019_integrated_prate_nio_vayu.csv')
d1.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d1=d1.drop('a', axis=1)
dt1=pd.concat([d1,df1],axis=1, join='inner')

# %%
df2 = pd.read_csv(p1+"timeseries_all_nio_fani.csv",sep=',')
df2.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df2=df2.drop('a', axis=1)
df2=df2.drop('conv_rrate', axis=1)
df2=df2.drop('ls_rrate', axis=1)
df2=df2.drop('mn_conv_prate', axis=1)
df2=df2.drop('mn_ls_prate', axis=1)
df2=df2.drop('mn_tot_prate', axis=1)
df2=df2.drop('outconv_rrate', axis=1)
df2=df2.drop('outls_rrate', axis=1)
df2=df2.drop('outmn_conv_prate', axis=1)
df2=df2.drop('outmn_ls_prate', axis=1)
df2=df2.drop('outmn_tot_prate', axis=1)
d2=pd.read_csv(p2+'2019_integrated_prate_nio_fani.csv')
d2.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d2=d2.drop('a', axis=1)
dt2=pd.concat([d2,df2],axis=1, join='inner')

# %%
df3 = pd.read_csv(p1+"timeseries_all_amphan.csv",sep=',')
df3.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df3=df3.drop('a', axis=1)
df3=df3.drop('conv_rrate', axis=1)
df3=df3.drop('ls_rrate', axis=1)
df3=df3.drop('mn_conv_prate', axis=1)
df3=df3.drop('mn_ls_prate', axis=1)
df3=df3.drop('mn_tot_prate', axis=1)
df3=df3.drop('outconv_rrate', axis=1)
df3=df3.drop('outls_rrate', axis=1)
df3=df3.drop('outmn_conv_prate', axis=1)
df3=df3.drop('outmn_ls_prate', axis=1)
df3=df3.drop('outmn_tot_prate', axis=1)
d3=pd.read_csv(p2+'2020_integrated_prate_nio_amphan.csv')
d3.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d3=d3.drop('a', axis=1)
dt3=pd.concat([d3,df3],axis=1, join='inner')

# %%
df4 = pd.read_csv(p1+"timeseries_all_nio_kyaar.csv",sep=',')
df4.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df4=df4.drop('a', axis=1)
df4=df4.drop('conv_rrate', axis=1)
df4=df4.drop('ls_rrate', axis=1)
df4=df4.drop('mn_conv_prate', axis=1)
df4=df4.drop('mn_ls_prate', axis=1)
df4=df4.drop('mn_tot_prate', axis=1)
df4=df4.drop('outconv_rrate', axis=1)
df4=df4.drop('outls_rrate', axis=1)
df4=df4.drop('outmn_conv_prate', axis=1)
df4=df4.drop('outmn_ls_prate', axis=1)
df4=df4.drop('outmn_tot_prate', axis=1)
d4=pd.read_csv(p2+'2019_integrated_prate_nio_kyaar.csv')
d4.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d4=d4.drop('a', axis=1)
dt4=pd.concat([d4,df4],axis=1, join='inner')

# %%
df5 = pd.read_csv(p1+"timeseries_all_nio_pawan.csv",sep=',')
df5.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df5=df5.drop('a', axis=1)
df5=df5.drop('conv_rrate', axis=1)
df5=df5.drop('ls_rrate', axis=1)
df5=df5.drop('mn_conv_prate', axis=1)
df5=df5.drop('mn_ls_prate', axis=1)
df5=df5.drop('mn_tot_prate', axis=1)
df5=df5.drop('outconv_rrate', axis=1)
df5=df5.drop('outls_rrate', axis=1)
df5=df5.drop('outmn_conv_prate', axis=1)
df5=df5.drop('outmn_ls_prate', axis=1)
df5=df5.drop('outmn_tot_prate', axis=1)
d5=pd.read_csv(p2+'2019_integrated_prate_nio_pawan.csv')
d5.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d5=d5.drop('a', axis=1)
dt5=pd.concat([d5,df5],axis=1, join='inner')

# %%
df6 = pd.read_csv(p1+"timeseries_all_nio_maha.csv",sep=',')
df6.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df6=df6.drop('a', axis=1)
df6=df6.drop('conv_rrate', axis=1)
df6=df6.drop('ls_rrate', axis=1)
df6=df6.drop('mn_conv_prate', axis=1)
df6=df6.drop('mn_ls_prate', axis=1)
df6=df6.drop('mn_tot_prate', axis=1)
df6=df6.drop('outconv_rrate', axis=1)
df6=df6.drop('outls_rrate', axis=1)
df6=df6.drop('outmn_conv_prate', axis=1)
df6=df6.drop('outmn_ls_prate', axis=1)
df6=df6.drop('outmn_tot_prate', axis=1)
d6=pd.read_csv(p2+'2019_integrated_prate_nio_maha.csv')
d6.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d6=d6.drop('a', axis=1)
dt6=pd.concat([d6,df6],axis=1, join='inner')

# %%
df7 = pd.read_csv(p1+"timeseries_all_nio_bulbul.csv",sep=',')
df7.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
df7=df7.drop('a', axis=1)
df7=df7.drop('conv_rrate', axis=1)
df7=df7.drop('ls_rrate', axis=1)
df7=df7.drop('mn_conv_prate', axis=1)
df7=df7.drop('mn_ls_prate', axis=1)
df7=df7.drop('mn_tot_prate', axis=1)
df7=df7.drop('outconv_rrate', axis=1)
df7=df7.drop('outls_rrate', axis=1)
df7=df7.drop('outmn_conv_prate', axis=1)
df7=df7.drop('outmn_ls_prate', axis=1)
df7=df7.drop('outmn_tot_prate', axis=1)
d7=pd.read_csv(p2+'2019_integrated_prate_nio_bulbul.csv')
d7.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
d7=d7.drop('a', axis=1)
dt7=pd.concat([d7,df7],axis=1, join='inner')

# %%
 
 dt1
# Out:
#      Prec_Intg         Pmin     w10max    div100        div200    div250  \
# 0   275.592338  1004.161250  13.432127  0.000037  3.033961e-05  0.000022
# 1   283.111781  1003.260625  14.378722  0.000057  5.648138e-05  0.000029
# 2   334.341414  1005.521875  15.848115  0.000053  5.462169e-05  0.000026
# 3   404.590424  1006.959375  16.375698  0.000064  3.901983e-05  0.000005
# 4   326.595865  1005.797500  14.064686  0.000055  4.183283e-05  0.000012
# ..         ...          ...        ...       ...           ...       ...
# 70   13.637841   970.562500  11.845954  0.000002  2.820352e-06  0.000003
# 71   22.771712   972.964375  12.091147 -0.000002  9.092987e-07  0.000004
# 72   32.252427   972.267500  11.416389 -0.000010 -4.606551e-06  0.000005
# 73   33.768211   970.848750  11.119370 -0.000007 -6.297744e-06  0.000003
# 74   31.341277   973.754375  11.000634 -0.000003 -5.406963e-06 -0.000003
#
#       div300        div400        div500     eqt1000  ...  outvvel_250  \
# 0   0.000021  1.033537e-05 -9.683152e-06  336.310120  ...    -0.043412
# 1   0.000017 -4.290808e-06 -1.818451e-05  333.951965  ...    -0.034768
# 2   0.000002 -1.273937e-05 -1.564485e-05  337.823547  ...    -0.065810
# 3  -0.000020 -2.690667e-05 -9.921511e-06  339.066284  ...    -0.087828
# 4  -0.000021 -2.480903e-05  7.740191e-07  338.007965  ...    -0.106979
# ..       ...           ...           ...         ...  ...          ...
# 70 -0.000004 -4.722464e-06  1.586464e-06  316.065125  ...    -0.017351
# 71 -0.000005 -2.378558e-06  6.535027e-06  314.548340  ...    -0.014452
# 72 -0.000003 -1.952885e-06  3.420026e-06  312.680145  ...     0.002120
# 73  0.000001  9.115012e-07  2.443341e-06  310.716858  ...     0.005610
# 74 -0.000001  4.362543e-06  7.814393e-07  313.004944  ...    -0.011253
#
#     outvvel_300  outvvel_400  outvvel_500  outvvel_600  outvvel_700  \
# 0     -0.067069    -0.076733    -0.066272    -0.053405    -0.034822
# 1     -0.059238    -0.074319    -0.076056    -0.067077    -0.040135
# 2     -0.096040    -0.105373    -0.100904    -0.100390    -0.085076
# 3     -0.120525    -0.128605    -0.127290    -0.127369    -0.118495
# 4     -0.144795    -0.137654    -0.117769    -0.087772    -0.068126
# ..          ...          ...          ...          ...          ...
# 70    -0.012753    -0.012093     0.011836     0.017975    -0.012602
# 71    -0.012703    -0.021371    -0.013175    -0.015176    -0.036555
# 72     0.009569     0.011590    -0.006808    -0.018637    -0.026843
# 73     0.018501     0.026826     0.010215    -0.019253    -0.027152
# 74     0.006266     0.011546    -0.011443    -0.041076    -0.053272
#
#     outvvel_850  outvvel_925  outvvel_975  outvvel_1000
# 0     -0.017927    -0.009423     0.003136      0.011556
# 1     -0.011975    -0.002022     0.009977      0.016728
# 2     -0.044960    -0.033494    -0.022801     -0.015852
# 3     -0.077594    -0.057291    -0.039402     -0.029692
# 4     -0.034696    -0.021807    -0.009824     -0.001791
# ..          ...          ...          ...           ...
# 70    -0.050000    -0.042123    -0.024152     -0.016818
# 71    -0.052451    -0.034581    -0.014828     -0.007202
# 72    -0.026415    -0.008793     0.009232      0.017048
# 73    -0.035206    -0.021277    -0.004050      0.005725
# 74    -0.066658    -0.053765    -0.037086     -0.027874
#
# [75 rows x 261 columns]

# %%
var_names
# Out:
# ['Prec_Intg',
#  'Pmin',
#  'w10max',
#  'div100',
#  'div200',
#  'div250',
#  'div300',
#  'div400',
#  'div500',
#  'eqt1000',
#  'eqt200',
#  'eqt250',
#  'eqt300',
#  'eqt400',
#  'eqt500',
#  'eqt600',
#  'eqt700',
#  'eqt850',
#  'eqt925',
#  'sh850_200',
#  'sh850_250',
#  'sh925_200',
#  'sh925_250',
#  'wstrss10',
#  '2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'sst',
#  'vort_10',
#  'vort_20',
#  'vort_30',
#  'vort_50',
#  'vort_70',
#  'vort_100',
#  'vort_150',
#  'vort_200',
#  'vort_250',
#  'vort_300',
#  'vort_400',
#  'vort_500',
#  'vort_600',
#  'vort_700',
#  'vort_800',
#  'vort_850',
#  'vort_900',
#  'vort_925',
#  'vort_950',
#  'vort_975',
#  'vort_1000',
#  'rhum_10',
#  'rhum_20',
#  'rhum_30',
#  'rhum_50',
#  'rhum_70',
#  'rhum_100',
#  'rhum_150',
#  'rhum_200',
#  'rhum_250',
#  'rhum_300',
#  'rhum_400',
#  'rhum_500',
#  'rhum_600',
#  'rhum_700',
#  'rhum_800',
#  'rhum_850',
#  'rhum_900',
#  'rhum_925',
#  'rhum_950',
#  'rhum_975',
#  'rhum_1000',
#  'gpot_10',
#  'gpot_20',
#  'gpot_30',
#  'gpot_50',
#  'gpot_70',
#  'gpot_100',
#  'gpot_150',
#  'gpot_200',
#  'gpot_250',
#  'gpot_300',
#  'gpot_400',
#  'gpot_500',
#  'gpot_600',
#  'gpot_700',
#  'gpot_800',
#  'gpot_850',
#  'gpot_900',
#  'gpot_925',
#  'gpot_950',
#  'gpot_975',
#  'gpot_1000',
#  'vvel_10',
#  'vvel_20',
#  'vvel_30',
#  'vvel_50',
#  'vvel_70',
#  'vvel_100',
#  'vvel_150',
#  'vvel_200',
#  'vvel_250',
#  'vvel_300',
#  'vvel_400',
#  'vvel_500',
#  'vvel_600',
#  'vvel_700',
#  'vvel_850',
#  'vvel_925',
#  'vvel_975',
#  'vvel_1000',
#  'out_div100',
#  'out_div200',
#  'out_div250',
#  'out_div300',
#  'out_div400',
#  'out_div500',
#  'out_eqt1000',
#  'out_eqt200',
#  'out_eqt250',
#  'out_eqt300',
#  'out_eqt400',
#  'out_eqt500',
#  'out_eqt600',
#  'out_eqt700',
#  'out_eqt850',
#  'out_eqt925',
#  'out_sh850_200',
#  'out_sh850_250',
#  'out_sh925_200',
#  'out_sh925_250',
#  'out_wstrss10',
#  'out2mdewtmp',
#  'out2mtmp',
#  'outconv_ppt',
#  'outtot_cld_ice',
#  'outtot_cldwtr',
#  'outtot_cld_rain',
#  'outvi_div_cld_froz_wtr',
#  'outvi_div_cld_liq_wtr',
#  'outvi_div_mass_flux',
#  'outvi_div_moisture_flux',
#  'outvi_div_tot_enrgy_flux',
#  'outvi_pe_inte',
#  'outvi_pe_ie_latentenrgy',
#  'outvi_olr',
#  'outvi_tot_enrgy',
#  'outvi_moisture_div',
#  'outcape',
#  'outinst_moisture_flux',
#  'outinst_ssh_flux',
#  'outsurfmean_lhf',
#  'outsurfmean_shf',
#  'outvimean_moisture_div',
#  'outsurf_lhf',
#  'outsurf_shf',
#  'outtot_suprcool_liqwtr',
#  'outtot_wtr_vpr',
#  'outsst',
#  'outvort_10',
#  'outvort_20',
#  'outvort_30',
#  'outvort_50',
#  'outvort_70',
#  'outvort_100',
#  'outvort_150',
#  'outvort_200',
#  'outvort_250',
#  'outvort_300',
#  'outvort_400',
#  'outvort_500',
#  'outvort_600',
#  'outvort_700',
#  'outvort_800',
#  'outvort_850',
#  'outvort_900',
#  'outvort_925',
#  'outvort_950',
#  'outvort_975',
#  'outvort_1000',
#  'outrhum_10',
#  'outrhum_20',
#  'outrhum_30',
#  'outrhum_50',
#  'outrhum_70',
#  'outrhum_100',
#  'outrhum_150',
#  'outrhum_200',
#  'outrhum_250',
#  'outrhum_300',
#  'outrhum_400',
#  'outrhum_500',
#  'outrhum_600',
#  'outrhum_700',
#  'outrhum_800',
#  'outrhum_850',
#  'outrhum_900',
#  'outrhum_925',
#  'outrhum_950',
#  'outrhum_975',
#  'outrhum_1000',
#  'outgpot_10',
#  'outgpot_20',
#  'outgpot_30',
#  'outgpot_50',
#  'outgpot_70',
#  'outgpot_100',
#  'outgpot_150',
#  'outgpot_200',
#  'outgpot_250',
#  'outgpot_300',
#  'outgpot_400',
#  'outgpot_500',
#  'outgpot_600',
#  'outgpot_700',
#  'outgpot_800',
#  'outgpot_850',
#  'outgpot_900',
#  'outgpot_925',
#  'outgpot_950',
#  'outgpot_975',
#  'outgpot_1000',
#  'outvvel_10',
#  'outvvel_20',
#  'outvvel_30',
#  'outvvel_50',
#  'outvvel_70',
#  'outvvel_100',
#  'outvvel_150',
#  'outvvel_200',
#  'outvvel_250',
#  'outvvel_300',
#  'outvvel_400',
#  'outvvel_500',
#  'outvvel_600',
#  'outvvel_700',
#  'outvvel_850',
#  'outvvel_925',
#  'outvvel_975',
#  'outvvel_1000']

# %%
tc1=dt1.values
tc2=dt2.values
tc3=dt3.values
tc4=dt4.values
tc5=dt5.values
tc6=dt6.values
tc7=dt7.values

# %%
print(tc1.shape)
print(tc2.shape)
print(tc3.shape)
print(tc4.shape)
print(tc5.shape)
print(tc6.shape)
print(tc7.shape)
# Out:
# (75, 261)
# (58, 261)
# (51, 261)
# (93, 261)
# (54, 261)
# (111, 261)
# (55, 261)

# %%
var_names=dt1.columns.values.tolist()

# %%
T=[75,58]
N = 261
M= 2
tc=[tc1,tc2]

# %%
dd={'cyclone1':tc1,'cyclone2':tc2,'cyclone3':tc3,'cyclone4':tc4,'cyclone5':tc5,'cyclone6':tc6,'cyclone7':tc7}

# %%
var_names
# Out:
# ['Prec_Intg',
#  'Pmin',
#  'w10max',
#  'div100',
#  'div200',
#  'div250',
#  'div300',
#  'div400',
#  'div500',
#  'eqt1000',
#  'eqt200',
#  'eqt250',
#  'eqt300',
#  'eqt400',
#  'eqt500',
#  'eqt600',
#  'eqt700',
#  'eqt850',
#  'eqt925',
#  'sh850_200',
#  'sh850_250',
#  'sh925_200',
#  'sh925_250',
#  'wstrss10',
#  '2mdewtmp',
#  '2mtmp',
#  'conv_ppt',
#  'tot_cld_ice',
#  'tot_cldwtr',
#  'tot_cld_rain',
#  'vi_div_cld_froz_wtr',
#  'vi_div_cld_liq_wtr',
#  'vi_div_mass_flux',
#  'vi_div_moisture_flux',
#  'vi_div_tot_enrgy_flux',
#  'vi_pe_inte',
#  'vi_pe_ie_latentenrgy',
#  'vi_olr',
#  'vi_tot_enrgy',
#  'vi_moisture_div',
#  'cape',
#  'inst_moisture_flux',
#  'inst_ssh_flux',
#  'surfmean_lhf',
#  'surfmean_shf',
#  'vimean_moisture_div',
#  'surf_lhf',
#  'surf_shf',
#  'tot_suprcool_liqwtr',
#  'tot_wtr_vpr',
#  'sst',
#  'vort_10',
#  'vort_20',
#  'vort_30',
#  'vort_50',
#  'vort_70',
#  'vort_100',
#  'vort_150',
#  'vort_200',
#  'vort_250',
#  'vort_300',
#  'vort_400',
#  'vort_500',
#  'vort_600',
#  'vort_700',
#  'vort_800',
#  'vort_850',
#  'vort_900',
#  'vort_925',
#  'vort_950',
#  'vort_975',
#  'vort_1000',
#  'rhum_10',
#  'rhum_20',
#  'rhum_30',
#  'rhum_50',
#  'rhum_70',
#  'rhum_100',
#  'rhum_150',
#  'rhum_200',
#  'rhum_250',
#  'rhum_300',
#  'rhum_400',
#  'rhum_500',
#  'rhum_600',
#  'rhum_700',
#  'rhum_800',
#  'rhum_850',
#  'rhum_900',
#  'rhum_925',
#  'rhum_950',
#  'rhum_975',
#  'rhum_1000',
#  'gpot_10',
#  'gpot_20',
#  'gpot_30',
#  'gpot_50',
#  'gpot_70',
#  'gpot_100',
#  'gpot_150',
#  'gpot_200',
#  'gpot_250',
#  'gpot_300',
#  'gpot_400',
#  'gpot_500',
#  'gpot_600',
#  'gpot_700',
#  'gpot_800',
#  'gpot_850',
#  'gpot_900',
#  'gpot_925',
#  'gpot_950',
#  'gpot_975',
#  'gpot_1000',
#  'vvel_10',
#  'vvel_20',
#  'vvel_30',
#  'vvel_50',
#  'vvel_70',
#  'vvel_100',
#  'vvel_150',
#  'vvel_200',
#  'vvel_250',
#  'vvel_300',
#  'vvel_400',
#  'vvel_500',
#  'vvel_600',
#  'vvel_700',
#  'vvel_850',
#  'vvel_925',
#  'vvel_975',
#  'vvel_1000',
#  'out_div100',
#  'out_div200',
#  'out_div250',
#  'out_div300',
#  'out_div400',
#  'out_div500',
#  'out_eqt1000',
#  'out_eqt200',
#  'out_eqt250',
#  'out_eqt300',
#  'out_eqt400',
#  'out_eqt500',
#  'out_eqt600',
#  'out_eqt700',
#  'out_eqt850',
#  'out_eqt925',
#  'out_sh850_200',
#  'out_sh850_250',
#  'out_sh925_200',
#  'out_sh925_250',
#  'out_wstrss10',
#  'out2mdewtmp',
#  'out2mtmp',
#  'outconv_ppt',
#  'outtot_cld_ice',
#  'outtot_cldwtr',
#  'outtot_cld_rain',
#  'outvi_div_cld_froz_wtr',
#  'outvi_div_cld_liq_wtr',
#  'outvi_div_mass_flux',
#  'outvi_div_moisture_flux',
#  'outvi_div_tot_enrgy_flux',
#  'outvi_pe_inte',
#  'outvi_pe_ie_latentenrgy',
#  'outvi_olr',
#  'outvi_tot_enrgy',
#  'outvi_moisture_div',
#  'outcape',
#  'outinst_moisture_flux',
#  'outinst_ssh_flux',
#  'outsurfmean_lhf',
#  'outsurfmean_shf',
#  'outvimean_moisture_div',
#  'outsurf_lhf',
#  'outsurf_shf',
#  'outtot_suprcool_liqwtr',
#  'outtot_wtr_vpr',
#  'outsst',
#  'outvort_10',
#  'outvort_20',
#  'outvort_30',
#  'outvort_50',
#  'outvort_70',
#  'outvort_100',
#  'outvort_150',
#  'outvort_200',
#  'outvort_250',
#  'outvort_300',
#  'outvort_400',
#  'outvort_500',
#  'outvort_600',
#  'outvort_700',
#  'outvort_800',
#  'outvort_850',
#  'outvort_900',
#  'outvort_925',
#  'outvort_950',
#  'outvort_975',
#  'outvort_1000',
#  'outrhum_10',
#  'outrhum_20',
#  'outrhum_30',
#  'outrhum_50',
#  'outrhum_70',
#  'outrhum_100',
#  'outrhum_150',
#  'outrhum_200',
#  'outrhum_250',
#  'outrhum_300',
#  'outrhum_400',
#  'outrhum_500',
#  'outrhum_600',
#  'outrhum_700',
#  'outrhum_800',
#  'outrhum_850',
#  'outrhum_900',
#  'outrhum_925',
#  'outrhum_950',
#  'outrhum_975',
#  'outrhum_1000',
#  'outgpot_10',
#  'outgpot_20',
#  'outgpot_30',
#  'outgpot_50',
#  'outgpot_70',
#  'outgpot_100',
#  'outgpot_150',
#  'outgpot_200',
#  'outgpot_250',
#  'outgpot_300',
#  'outgpot_400',
#  'outgpot_500',
#  'outgpot_600',
#  'outgpot_700',
#  'outgpot_800',
#  'outgpot_850',
#  'outgpot_900',
#  'outgpot_925',
#  'outgpot_950',
#  'outgpot_975',
#  'outgpot_1000',
#  'outvvel_10',
#  'outvvel_20',
#  'outvvel_30',
#  'outvvel_50',
#  'outvvel_70',
#  'outvvel_100',
#  'outvvel_150',
#  'outvvel_200',
#  'outvvel_250',
#  'outvvel_300',
#  'outvvel_400',
#  'outvvel_500',
#  'outvvel_600',
#  'outvvel_700',
#  'outvvel_850',
#  'outvvel_925',
#  'outvvel_975',
#  'outvvel_1000']

# %%
data=dd
dataframe = pp.DataFrame(data,analysis_mode ='multiple', var_names=var_names)
tau_max0 = 16
tau_min0 = 1

# %%
for member in dataframe.values.keys():
    children = [0,1,2]
    parents = np.arange(3,261)
    sel_links = select_links(tau_min0, tau_max0, parents, children)

# %%
results = pcmci.run_pc_stable(selected_links = sel_links, tau_max=tau_max0, tau_min=tau_min0, pc_alpha=0.05)
#pcmci.verbosity = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_759747/183858957.py in <module>
# ----> 1 results = pcmci.run_pc_stable(selected_links = sel_links, tau_max=tau_max0, tau_min=tau_min0, pc_alpha=0.05)
#       2 #pcmci.verbosity = 1
#
# NameError: name 'pcmci' is not defined

# %%
pc_alpha = 0.05
pcmci = PCMCI(dataframe = dataframe, cond_ind_test = ParCorr())
results = pcmci.run_pcmciplus(selected_links = sel_links, tau_min = tau_min0, tau_max = tau_max0,  pc_alpha = pc_alpha)
pcmci.verbosity = 2

# %%
fig=plt.rcParams["figure.figsize"] = (20,25)
tp.plot_graph(graph=results['graph'], val_matrix=results['val_matrix'], var_names=var_names)
plt.show()

# %%
pcmci.print_significant_links(p_matrix=results['p_matrix'],
        val_matrix = results['val_matrix'],
        alpha_level = 0.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_759747/1210590913.py in <module>
# ----> 1 pcmci.print_significant_links(p_matrix=results['p_matrix'],
#       2         val_matrix = results['val_matrix'],
#       3         alpha_level = 0.05)
#
# NameError: name 'pcmci' is not defined

# %%
pcmci.verbosity = 1
results = pcmci.run_pc_stable(selected_links = sel_links, tau_max=tau_max0, tau_min=tau_min0, pc_alpha=0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_759747/424529737.py in <module>
# ----> 1 pcmci.verbosity = 1
#       2 results = pcmci.run_pc_stable(selected_links = sel_links, tau_max=tau_max0, tau_min=tau_min0, pc_alpha=0.01)
#
# NameError: name 'pcmci' is not defined

# %%
pcmci.verbosity = 1
pc_alpha = 0.05
pcmci = PCMCI(dataframe = dataframe, cond_ind_test = ParCorr())
results = pcmci.run_pcmci(selected_links = sel_links, tau_min = tau_min0, tau_max = tau_max0,  pc_alpha = pc_alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_759747/2425435802.py in <module>
# ----> 1 pcmci.verbosity = 1
#       2 pc_alpha = 0.05
#       3 pcmci = PCMCI(dataframe = dataframe, cond_ind_test = ParCorr())
#       4 results = pcmci.run_pcmci(selected_links = sel_links, tau_min = tau_min0, tau_max = tau_max0,  pc_alpha = pc_alpha)
#
# NameError: name 'pcmci' is not defined

# %%
q_matrix = pcmci.get_corrected_pvalues(p_matrix=results['p_matrix'],selected_links = sel_links, tau_min=tau_min0,tau_max=tau_max0, fdr_method='fdr_bh')
pcmci.print_significant_links(
        p_matrix = q_matrix,
        val_matrix = results['val_matrix'],
        alpha_level = 0.05)
graph = pcmci.get_graph_from_pmatrix(p_matrix=q_matrix, alpha_level=0.05,
                                     tau_min=tau_min0,tau_max=tau_max0, selected_links=sel_links)
results['graph'] = graph
# Out:
# ## Significant links at alpha = 0.05:
#
#     Variable Prec_Intg has 282 link(s):
#         (vvel_150 -1): pval = 0.00000 | val = -0.721
#         (vi_moisture_div -1): pval = 0.00000 | val = -0.446
#         (vimean_moisture_div -1): pval = 0.00000 | val = -0.446
#         (vi_div_moisture_flux -1): pval = 0.00000 | val = -0.375
#         (outrhum_500 -1): pval = 0.00001 | val =  0.323
#         (tot_suprcool_liqwtr -1): pval = 0.00002 | val =  0.317
#         (vvel_500 -1): pval = 0.00003 | val = -0.313
#         (vvel_600 -1): pval = 0.00006 | val = -0.304
#         (outrhum_1000 -14): pval = 0.00008 | val = -0.300
#         (vvel_700 -1): pval = 0.00013 | val = -0.292
#         (tot_cldwtr -1): pval = 0.00022 | val =  0.283
#         (outtot_cld_rain -6): pval = 0.00022 | val =  0.283
#         (tot_cld_rain -1): pval = 0.00027 | val =  0.280
#         (outrhum_975 -14): pval = 0.00030 | val = -0.278
#         (outrhum_950 -14): pval = 0.00033 | val = -0.277
#         (vvel_850 -1): pval = 0.00039 | val = -0.274
#         (outrhum_950 -13): pval = 0.00041 | val = -0.273
#         (outrhum_1000 -13): pval = 0.00066 | val = -0.265
#         (outrhum_975 -13): pval = 0.00092 | val = -0.259
#         (vvel_400 -1): pval = 0.00101 | val = -0.257
#         (outrhum_1000 -15): pval = 0.00105 | val = -0.256
#         (vvel_925 -1): pval = 0.00184 | val = -0.246
#         (outrhum_1000 -6): pval = 0.00200 | val = -0.244
#         (outrhum_950 -5): pval = 0.00202 | val = -0.244
#         (outrhum_950 -6): pval = 0.00232 | val = -0.242
#         (outrhum_925 -14): pval = 0.00234 | val = -0.242
#         (outvvel_100 -15): pval = 0.00239 | val =  0.241
#         (outrhum_975 -5): pval = 0.00266 | val = -0.239
#         (outrhum_975 -6): pval = 0.00286 | val = -0.238
#         (outrhum_1000 -5): pval = 0.00316 | val = -0.235
#         (outrhum_975 -15): pval = 0.00316 | val = -0.235
#         (outrhum_925 -13): pval = 0.00316 | val = -0.235
#         (div400 -5): pval = 0.00321 | val = -0.235
#         (div400 -10): pval = 0.00323 | val =  0.235
#         (outvvel_300 -11): pval = 0.00336 | val =  0.234
#         (outvvel_400 -11): pval = 0.00338 | val =  0.234
#         (outrhum_30 -2): pval = 0.00338 | val = -0.234
#         (div200 -1): pval = 0.00346 | val =  0.233
#         (outvvel_200 -7): pval = 0.00365 | val =  0.232
#         (cape -13): pval = 0.00391 | val =  0.230
#         (div250 -1): pval = 0.00476 | val =  0.226
#         (outrhum_950 -12): pval = 0.00488 | val = -0.225
#         (rhum_800 -2): pval = 0.00500 | val =  0.225
#         (gpot_600 -4): pval = 0.00507 | val = -0.224
#         (outgpot_700 -12): pval = 0.00527 | val = -0.224
#         (vi_div_moisture_flux -2): pval = 0.00567 | val = -0.222
#         (vi_div_cld_liq_wtr -5): pval = 0.00584 | val = -0.221
#         (gpot_500 -4): pval = 0.00600 | val = -0.221
#         (outgpot_600 -12): pval = 0.00603 | val = -0.221
#         (gpot_700 -4): pval = 0.00605 | val = -0.220
#         (outrhum_30 -3): pval = 0.00642 | val = -0.219
#         (out_div100 -3): pval = 0.00729 | val = -0.217
#         (outvvel_50 -3): pval = 0.00746 | val =  0.216
#         (outrhum_950 -15): pval = 0.00752 | val = -0.216
#         (outvvel_500 -11): pval = 0.00774 | val =  0.215
#         (out_div100 -7): pval = 0.00774 | val = -0.215
#         (vvel_300 -1): pval = 0.00774 | val = -0.215
#         (outvvel_400 -10): pval = 0.00781 | val =  0.215
#         (outvort_50 -3): pval = 0.00814 | val = -0.214
#         (outvvel_300 -10): pval = 0.00814 | val =  0.214
#         (rhum_800 -7): pval = 0.00814 | val =  0.214
#         (rhum_850 -2): pval = 0.00819 | val =  0.214
#         (outgpot_700 -4): pval = 0.00846 | val = -0.213
#         (out_div400 -11): pval = 0.00862 | val = -0.212
#         (outvort_50 -2): pval = 0.00886 | val = -0.212
#         (outrhum_925 -12): pval = 0.00947 | val = -0.211
#         (gpot_400 -16): pval = 0.00987 | val = -0.210
#         (outvort_850 -16): pval = 0.00994 | val =  0.209
#         (rhum_800 -1): pval = 0.01023 | val =  0.209
#         (gpot_800 -4): pval = 0.01140 | val = -0.206
#         (outvort_30 -8): pval = 0.01140 | val = -0.206
#         (gpot_700 -3): pval = 0.01148 | val = -0.206
#         (outrhum_925 -15): pval = 0.01164 | val = -0.205
#         (eqt500 -1): pval = 0.01189 | val =  0.205
#         (outrhum_30 -1): pval = 0.01198 | val = -0.205
#         (outvvel_250 -10): pval = 0.01310 | val =  0.203
#         (out2mtmp -14): pval = 0.01371 | val =  0.202
#         (outvort_30 -6): pval = 0.01379 | val = -0.201
#         (outvvel_50 -2): pval = 0.01391 | val =  0.201
#         (outvort_30 -5): pval = 0.01391 | val = -0.201
#         (div400 -4): pval = 0.01394 | val = -0.201
#         (tot_cldwtr -10): pval = 0.01420 | val =  0.201
#         (outvort_30 -7): pval = 0.01433 | val = -0.201
#         (gpot_850 -4): pval = 0.01448 | val = -0.200
#         (vvel_250 -1): pval = 0.01465 | val = -0.200
#         (rhum_800 -8): pval = 0.01473 | val =  0.200
#         (rhum_800 -3): pval = 0.01480 | val =  0.200
#         (outvvel_250 -11): pval = 0.01508 | val =  0.199
#         (outvvel_1000 -5): pval = 0.01552 | val = -0.198
#         (outvort_30 -9): pval = 0.01578 | val = -0.198
#         (gpot_600 -3): pval = 0.01584 | val = -0.198
#         (outvort_800 -16): pval = 0.01589 | val =  0.198
#         (rhum_20 -16): pval = 0.01656 | val = -0.197
#         (gpot_900 -4): pval = 0.01659 | val = -0.197
#         (outvvel_30 -11): pval = 0.01660 | val =  0.197
#         (outvvel_600 -11): pval = 0.01726 | val =  0.196
#         (outrhum_975 -7): pval = 0.01726 | val = -0.196
#         (gpot_925 -4): pval = 0.01730 | val = -0.196
#         (out_div100 -6): pval = 0.01750 | val = -0.195
#         (outgpot_800 -12): pval = 0.01751 | val = -0.195
#         (gpot_800 -3): pval = 0.01765 | val = -0.195
#         (outvort_30 -4): pval = 0.01782 | val = -0.195
#         (outrhum_900 -14): pval = 0.01787 | val = -0.195
#         (gpot_950 -4): pval = 0.01793 | val = -0.195
#         (outgpot_800 -4): pval = 0.01825 | val = -0.194
#         (cape -14): pval = 0.01859 | val =  0.194
#         (gpot_975 -4): pval = 0.01859 | val = -0.194
#         (outgpot_600 -4): pval = 0.01875 | val = -0.193
#         (rhum_200 -5): pval = 0.01888 | val =  0.193
#         (outrhum_1000 -7): pval = 0.01888 | val = -0.193
#         (outrhum_20 -3): pval = 0.01943 | val = -0.192
#         (gpot_400 -4): pval = 0.01945 | val = -0.192
#         (outgpot_500 -12): pval = 0.01957 | val = -0.192
#         (tot_cldwtr -9): pval = 0.01963 | val =  0.192
#         (outvvel_100 -16): pval = 0.01979 | val =  0.192
#         (outvort_850 -15): pval = 0.01987 | val =  0.192
#         (gpot_400 -8): pval = 0.01996 | val = -0.192
#         (outvvel_70 -5): pval = 0.01996 | val = -0.191
#         (outgpot_600 -16): pval = 0.01996 | val = -0.191
#         (gpot_1000 -4): pval = 0.01998 | val = -0.191
#         (outrhum_950 -7): pval = 0.02011 | val = -0.191
#         (rhum_850 -8): pval = 0.02065 | val =  0.190
#         (outsurfmean_lhf -14): pval = 0.02068 | val = -0.190
#         (outsurf_lhf -14): pval = 0.02068 | val = -0.190
#         (outvort_100 -7): pval = 0.02068 | val = -0.190
#         (outvvel_50 -6): pval = 0.02068 | val = -0.190
#         (outvort_100 -3): pval = 0.02112 | val = -0.190
#         (rhum_200 -6): pval = 0.02112 | val =  0.190
#         (gpot_850 -3): pval = 0.02121 | val = -0.189
#         (outvort_100 -6): pval = 0.02131 | val = -0.189
#         (outrhum_925 -6): pval = 0.02137 | val = -0.189
#         (outvvel_975 -5): pval = 0.02178 | val = -0.189
#         (outvvel_1000 -11): pval = 0.02178 | val =  0.189
#         (outvort_100 -1): pval = 0.02178 | val = -0.189
#         (outgpot_600 -8): pval = 0.02206 | val = -0.188
#         (outrhum_950 -4): pval = 0.02246 | val = -0.188
#         (gpot_500 -16): pval = 0.02305 | val = -0.187
#         (outvvel_1000 -10): pval = 0.02307 | val =  0.187
#         (outrhum_925 -5): pval = 0.02311 | val = -0.187
#         (vort_250 -4): pval = 0.02343 | val =  0.186
#         (outrhum_975 -12): pval = 0.02359 | val = -0.186
#         (outrhum_900 -13): pval = 0.02361 | val = -0.186
#         (vort_300 -4): pval = 0.02361 | val =  0.186
#         (gpot_900 -3): pval = 0.02382 | val = -0.186
#         (vort_250 -3): pval = 0.02386 | val =  0.186
#         (vvel_975 -1): pval = 0.02424 | val = -0.186
#         (outconv_ppt -12): pval = 0.02429 | val = -0.185
#         (outinst_ssh_flux -3): pval = 0.02458 | val =  0.185
#         (vi_pe_inte -4): pval = 0.02461 | val = -0.185
#         (vi_pe_inte -8): pval = 0.02470 | val = -0.185
#         (gpot_925 -3): pval = 0.02489 | val = -0.185
#         (vort_400 -1): pval = 0.02502 | val =  0.184
#         (outvvel_150 -7): pval = 0.02533 | val =  0.184
#         (vimean_moisture_div -16): pval = 0.02533 | val = -0.184
#         (vi_moisture_div -16): pval = 0.02533 | val = -0.184
#         (vi_moisture_div -8): pval = 0.02533 | val = -0.184
#         (vimean_moisture_div -8): pval = 0.02533 | val = -0.184
#         (outvort_30 -15): pval = 0.02536 | val = -0.184
#         (outvort_900 -16): pval = 0.02552 | val =  0.184
#         (rhum_850 -3): pval = 0.02606 | val =  0.183
#         (gpot_500 -8): pval = 0.02606 | val = -0.183
#         (gpot_950 -3): pval = 0.02606 | val = -0.183
#         (outtot_cld_rain -10): pval = 0.02606 | val = -0.183
#         (outvvel_10 -7): pval = 0.02668 | val = -0.183
#         (outvort_100 -2): pval = 0.02669 | val = -0.183
#         (outvort_100 -5): pval = 0.02670 | val = -0.183
#         (outvort_925 -15): pval = 0.02692 | val =  0.182
#         (outgpot_850 -12): pval = 0.02696 | val = -0.182
#         (gpot_975 -3): pval = 0.02729 | val = -0.182
#         (rhum_250 -5): pval = 0.02759 | val =  0.182
#         (outsurf_shf -3): pval = 0.02765 | val =  0.182
#         (outsurfmean_shf -3): pval = 0.02765 | val =  0.182
#         (outvvel_50 -11): pval = 0.02795 | val =  0.181
#         (outgpot_850 -4): pval = 0.02803 | val = -0.181
#         (outgpot_700 -8): pval = 0.02825 | val = -0.181
#         (out2mtmp -13): pval = 0.02840 | val =  0.181
#         (outvort_50 -1): pval = 0.02872 | val = -0.180
#         (outgpot_700 -16): pval = 0.02921 | val = -0.180
#         (gpot_500 -12): pval = 0.02926 | val = -0.180
#         (gpot_1000 -3): pval = 0.02958 | val = -0.179
#         (vort_250 -2): pval = 0.02962 | val =  0.179
#         (outvvel_200 -10): pval = 0.02994 | val =  0.179
#         (outvvel_200 -6): pval = 0.03002 | val =  0.179
#         (outvvel_200 -8): pval = 0.03004 | val =  0.179
#         (eqt1000 -6): pval = 0.03014 | val =  0.179
#         (outvort_900 -15): pval = 0.03028 | val =  0.179
#         (outrhum_20 -4): pval = 0.03043 | val = -0.179
#         (gpot_400 -12): pval = 0.03068 | val = -0.178
#         (outsurfmean_lhf -15): pval = 0.03068 | val = -0.178
#         (outsurf_lhf -15): pval = 0.03068 | val = -0.178
#         (outgpot_500 -16): pval = 0.03075 | val = -0.178
#         (rhum_850 -1): pval = 0.03088 | val =  0.178
#         (rhum_800 -4): pval = 0.03109 | val =  0.178
#         (outvort_925 -16): pval = 0.03128 | val =  0.178
#         (vort_20 -11): pval = 0.03174 | val = -0.177
#         (vort_20 -9): pval = 0.03180 | val = -0.177
#         (out_div100 -2): pval = 0.03180 | val = -0.177
#         (vi_olr -4): pval = 0.03210 | val = -0.177
#         (outinst_moisture_flux -14): pval = 0.03210 | val = -0.177
#         (vi_olr -8): pval = 0.03212 | val = -0.177
#         (outrhum_900 -15): pval = 0.03212 | val = -0.177
#         (out_div100 -4): pval = 0.03212 | val = -0.177
#         (tot_wtr_vpr -1): pval = 0.03217 | val =  0.177
#         (outvvel_1000 -2): pval = 0.03234 | val =  0.177
#         (out_div200 -11): pval = 0.03249 | val = -0.177
#         (outvort_1000 -13): pval = 0.03265 | val =  0.176
#         (rhum_850 -7): pval = 0.03277 | val =  0.176
#         (outvvel_250 -7): pval = 0.03300 | val =  0.176
#         (rhum_250 -4): pval = 0.03315 | val =  0.176
#         (outvort_100 -4): pval = 0.03346 | val = -0.176
#         (gpot_500 -3): pval = 0.03350 | val = -0.176
#         (vort_400 -2): pval = 0.03413 | val =  0.175
#         (cape -12): pval = 0.03416 | val =  0.175
#         (eqt500 -2): pval = 0.03433 | val =  0.175
#         (outvvel_10 -6): pval = 0.03506 | val = -0.174
#         (outvvel_1000 -13): pval = 0.03527 | val = -0.174
#         (outvort_50 -4): pval = 0.03534 | val = -0.174
#         (outgpot_900 -12): pval = 0.03537 | val = -0.174
#         (rhum_20 -3): pval = 0.03563 | val = -0.174
#         (outvort_1000 -14): pval = 0.03620 | val =  0.174
#         (outvvel_10 -11): pval = 0.03678 | val =  0.173
#         (rhum_20 -15): pval = 0.03678 | val = -0.173
#         (vi_div_cld_froz_wtr -5): pval = 0.03689 | val = -0.173
#         (outgpot_500 -8): pval = 0.03702 | val = -0.173
#         (gpot_600 -8): pval = 0.03718 | val = -0.173
#         (vort_70 -8): pval = 0.03724 | val = -0.173
#         (vort_300 -3): pval = 0.03725 | val =  0.173
#         (outvort_30 -3): pval = 0.03732 | val = -0.173
#         (outconv_ppt -13): pval = 0.03732 | val = -0.173
#         (outgpot_925 -12): pval = 0.03732 | val = -0.173
#         (outvort_30 -10): pval = 0.03740 | val = -0.172
#         (vvel_70 -5): pval = 0.03748 | val = -0.172
#         (rhum_10 -11): pval = 0.03767 | val =  0.172
#         (outgpot_950 -12): pval = 0.03798 | val = -0.172
#         (outgpot_900 -4): pval = 0.03804 | val = -0.172
#         (outrhum_925 -11): pval = 0.03820 | val = -0.172
#         (outsurfmean_shf -14): pval = 0.03853 | val = -0.172
#         (outsurf_shf -14): pval = 0.03853 | val = -0.172
#         (outrhum_30 -4): pval = 0.03879 | val = -0.171
#         (gpot_600 -12): pval = 0.03879 | val = -0.171
#         (rhum_200 -4): pval = 0.03892 | val =  0.171
#         (outvvel_20 -14): pval = 0.03931 | val = -0.171
#         (outgpot_975 -12): pval = 0.03975 | val = -0.171
#         (outsurf_shf -15): pval = 0.03975 | val = -0.171
#         (outsurfmean_shf -15): pval = 0.03975 | val = -0.171
#         (outgpot_925 -4): pval = 0.04044 | val = -0.170
#         (outgpot_950 -4): pval = 0.04102 | val = -0.170
#         (outgpot_975 -4): pval = 0.04118 | val = -0.169
#         (outvort_10 -5): pval = 0.04126 | val =  0.169
#         (outgpot_1000 -4): pval = 0.04126 | val = -0.169
#         (outvort_950 -15): pval = 0.04134 | val =  0.169
#         (outrhum_975 -4): pval = 0.04177 | val = -0.169
#         (outvvel_975 -11): pval = 0.04183 | val =  0.169
#         (gpot_700 -1): pval = 0.04219 | val = -0.169
#         (outgpot_1000 -12): pval = 0.04234 | val = -0.169
#         (eqt300 -1): pval = 0.04240 | val =  0.169
#         (outgpot_700 -11): pval = 0.04240 | val = -0.169
#         (outvort_800 -15): pval = 0.04262 | val =  0.169
#         (tot_cld_rain -7): pval = 0.04320 | val =  0.168
#         (outvort_30 -16): pval = 0.04380 | val = -0.168
#         (outvvel_50 -5): pval = 0.04388 | val = -0.168
#         (div400 -11): pval = 0.04406 | val =  0.168
#         (out_div250 -7): pval = 0.04414 | val =  0.168
#         (outvvel_30 -10): pval = 0.04423 | val =  0.167
#         (outtot_cld_ice -10): pval = 0.04469 | val = -0.167
#         (vort_300 -5): pval = 0.04480 | val =  0.167
#         (outvort_850 -14): pval = 0.04503 | val =  0.167
#         (vort_20 -10): pval = 0.04552 | val = -0.167
#         (outvvel_925 -5): pval = 0.04593 | val = -0.166
#         (outgpot_600 -11): pval = 0.04600 | val = -0.166
#         (outrhum_900 -12): pval = 0.04601 | val = -0.166
#         (rhum_30 -16): pval = 0.04588 | val =  0.166
#         (outinst_moisture_flux -15): pval = 0.04648 | val = -0.166
#         (vort_200 -3): pval = 0.04692 | val =  0.166
#         (div400 -9): pval = 0.04757 | val =  0.165
#         (outvort_100 -8): pval = 0.04813 | val = -0.165
#         (gpot_700 -8): pval = 0.04829 | val = -0.165
#         (vvel_10 -2): pval = 0.04884 | val =  0.165
#         (outgpot_10 -6): pval = 0.04917 | val =  0.164
#         (gpot_500 -5): pval = 0.04936 | val = -0.164
#         (out_div200 -10): pval = 0.04961 | val = -0.164
#         (out_div100 -8): pval = 0.04964 | val = -0.164
#
#     Variable Pmin has 1103 link(s):
#         (gpot_1000 -3): pval = 0.00000 | val =  0.461
#         (out_wstrss10 -4): pval = 0.00000 | val = -0.448
#         (out_wstrss10 -3): pval = 0.00000 | val = -0.438
#         (out_wstrss10 -5): pval = 0.00000 | val = -0.433
#         (out_wstrss10 -6): pval = 0.00000 | val = -0.421
#         (out_wstrss10 -7): pval = 0.00000 | val = -0.407
#         (out_wstrss10 -2): pval = 0.00000 | val = -0.406
#         (conv_ppt -16): pval = 0.00000 | val =  0.402
#         (rhum_200 -5): pval = 0.00000 | val =  0.396
#         (rhum_200 -7): pval = 0.00000 | val =  0.394
#         (rhum_200 -6): pval = 0.00000 | val =  0.393
#         (rhum_200 -4): pval = 0.00000 | val =  0.391
#         (conv_ppt -15): pval = 0.00000 | val =  0.388
#         (out_wstrss10 -1): pval = 0.00000 | val = -0.386
#         (eqt1000 -7): pval = 0.00000 | val =  0.386
#         (rhum_200 -8): pval = 0.00000 | val =  0.384
#         (rhum_150 -7): pval = 0.00000 | val =  0.384
#         (rhum_150 -6): pval = 0.00000 | val =  0.383
#         (outrhum_500 -14): pval = 0.00000 | val =  0.382
#         (eqt1000 -6): pval = 0.00000 | val =  0.381
#         (outrhum_500 -13): pval = 0.00000 | val =  0.381
#         (out_wstrss10 -8): pval = 0.00000 | val = -0.380
#         (outrhum_500 -12): pval = 0.00000 | val =  0.380
#         (rhum_200 -3): pval = 0.00000 | val =  0.380
#         (outrhum_500 -15): pval = 0.00000 | val =  0.377
#         (rhum_150 -5): pval = 0.00000 | val =  0.377
#         (rhum_200 -9): pval = 0.00000 | val =  0.377
#         (outrhum_700 -12): pval = 0.00000 | val =  0.372
#         (outrhum_500 -11): pval = 0.00000 | val =  0.372
#         (outrhum_700 -14): pval = 0.00000 | val =  0.372
#         (outrhum_700 -15): pval = 0.00000 | val =  0.371
#         (outrhum_700 -11): pval = 0.00000 | val =  0.370
#         (eqt1000 -5): pval = 0.00000 | val =  0.368
#         (rhum_150 -8): pval = 0.00000 | val =  0.368
#         (outrhum_700 -13): pval = 0.00000 | val =  0.368
#         (eqt1000 -8): pval = 0.00000 | val =  0.366
#         (rhum_200 -2): pval = 0.00000 | val =  0.366
#         (outrhum_500 -16): pval = 0.00000 | val =  0.366
#         (rhum_150 -4): pval = 0.00000 | val =  0.362
#         (rhum_200 -10): pval = 0.00000 | val =  0.362
#         (outvvel_100 -10): pval = 0.00000 | val =  0.359
#         (outrhum_700 -10): pval = 0.00000 | val =  0.356
#         (outrhum_700 -16): pval = 0.00000 | val =  0.356
#         (surf_shf -16): pval = 0.00000 | val = -0.355
#         (surfmean_shf -16): pval = 0.00000 | val = -0.355
#         (rhum_150 -9): pval = 0.00000 | val =  0.354
#         (outrhum_500 -10): pval = 0.00000 | val =  0.353
#         (rhum_200 -1): pval = 0.00000 | val =  0.350
#         (eqt1000 -4): pval = 0.00000 | val =  0.350
#         (rhum_200 -11): pval = 0.00000 | val =  0.349
#         (outrhum_700 -8): pval = 0.00000 | val =  0.348
#         (rhum_150 -3): pval = 0.00000 | val =  0.348
#         (eqt1000 -9): pval = 0.00000 | val =  0.347
#         (outrhum_700 -9): pval = 0.00000 | val =  0.347
#         (outrhum_700 -7): pval = 0.00000 | val =  0.344
#         (out_wstrss10 -9): pval = 0.00000 | val = -0.344
#         (conv_ppt -14): pval = 0.00000 | val =  0.341
#         (rhum_200 -12): pval = 0.00000 | val =  0.339
#         (rhum_150 -10): pval = 0.00000 | val =  0.336
#         (rhum_150 -2): pval = 0.00000 | val =  0.335
#         (outrhum_700 -6): pval = 0.00000 | val =  0.333
#         (outvvel_100 -14): pval = 0.00000 | val =  0.333
#         (outrhum_500 -9): pval = 0.00001 | val =  0.332
#         (vvel_925 -8): pval = 0.00001 | val = -0.331
#         (vvel_925 -9): pval = 0.00001 | val = -0.331
#         (eqt1000 -3): pval = 0.00001 | val =  0.327
#         (rhum_150 -1): pval = 0.00001 | val =  0.327
#         (eqt1000 -10): pval = 0.00001 | val =  0.327
#         (tot_cld_rain -6): pval = 0.00001 | val =  0.326
#         (rhum_200 -13): pval = 0.00001 | val =  0.326
#         (2mdewtmp -1): pval = 0.00001 | val = -0.325
#         (outrhum_700 -5): pval = 0.00001 | val =  0.325
#         (outvvel_100 -11): pval = 0.00001 | val =  0.324
#         (outrhum_700 -4): pval = 0.00001 | val =  0.323
#         (outvort_800 -1): pval = 0.00001 | val = -0.322
#         (2mdewtmp -2): pval = 0.00002 | val = -0.319
#         (rhum_250 -2): pval = 0.00002 | val =  0.318
#         (gpot_850 -3): pval = 0.00002 | val = -0.318
#         (inst_ssh_flux -16): pval = 0.00002 | val = -0.316
#         (rhum_250 -3): pval = 0.00002 | val =  0.316
#         (gpot_800 -3): pval = 0.00002 | val = -0.314
#         (out_wstrss10 -10): pval = 0.00002 | val = -0.314
#         (gpot_700 -7): pval = 0.00002 | val = -0.314
#         (outrhum_700 -3): pval = 0.00002 | val =  0.314
#         (outrhum_500 -8): pval = 0.00002 | val =  0.314
#         (rhum_150 -11): pval = 0.00002 | val =  0.313
#         (cape -2): pval = 0.00003 | val = -0.311
#         (cape -1): pval = 0.00003 | val = -0.311
#         (gpot_600 -7): pval = 0.00003 | val = -0.310
#         (vvel_925 -5): pval = 0.00003 | val = -0.310
#         (rhum_250 -1): pval = 0.00004 | val =  0.308
#         (outvort_850 -1): pval = 0.00004 | val = -0.306
#         (rhum_200 -14): pval = 0.00005 | val =  0.305
#         (gpot_900 -3): pval = 0.00005 | val = -0.304
#         (vvel_975 -12): pval = 0.00005 | val = -0.304
#         (vvel_975 -8): pval = 0.00005 | val = -0.303
#         (eqt1000 -2): pval = 0.00006 | val =  0.302
#         (2mdewtmp -3): pval = 0.00006 | val = -0.302
#         (vort_100 -13): pval = 0.00006 | val =  0.301
#         (rhum_250 -4): pval = 0.00006 | val =  0.301
#         (tot_cld_rain -7): pval = 0.00006 | val =  0.301
#         (vvel_975 -9): pval = 0.00007 | val = -0.300
#         (vi_moisture_div -15): pval = 0.00008 | val = -0.298
#         (vimean_moisture_div -15): pval = 0.00008 | val = -0.298
#         (outrhum_400 -16): pval = 0.00008 | val =  0.297
#         (gpot_500 -7): pval = 0.00008 | val = -0.297
#         (vvel_700 -16): pval = 0.00009 | val = -0.296
#         (vi_moisture_div -12): pval = 0.00010 | val = -0.295
#         (vimean_moisture_div -12): pval = 0.00010 | val = -0.295
#         (surf_shf -15): pval = 0.00010 | val = -0.294
#         (surfmean_shf -15): pval = 0.00010 | val = -0.294
#         (out_wstrss10 -11): pval = 0.00010 | val = -0.294
#         (outvvel_100 -13): pval = 0.00011 | val =  0.293
#         (conv_ppt -13): pval = 0.00011 | val =  0.293
#         (rhum_150 -12): pval = 0.00011 | val =  0.293
#         (eqt1000 -11): pval = 0.00012 | val =  0.292
#         (out_div400 -4): pval = 0.00012 | val =  0.292
#         (vort_100 -14): pval = 0.00012 | val =  0.291
#         (outrhum_500 -7): pval = 0.00012 | val =  0.291
#         (tot_cldwtr -3): pval = 0.00013 | val =  0.291
#         (vvel_925 -7): pval = 0.00013 | val = -0.290
#         (vvel_925 -12): pval = 0.00013 | val = -0.290
#         (outrhum_700 -2): pval = 0.00013 | val =  0.290
#         (outrhum_400 -15): pval = 0.00013 | val =  0.290
#         (outrhum_600 -15): pval = 0.00014 | val =  0.289
#         (outvort_850 -2): pval = 0.00014 | val = -0.289
#         (gpot_925 -3): pval = 0.00014 | val = -0.289
#         (outrhum_600 -14): pval = 0.00015 | val =  0.288
#         (outvort_800 -2): pval = 0.00015 | val = -0.288
#         (vvel_925 -6): pval = 0.00016 | val = -0.287
#         (rhum_800 -1): pval = 0.00016 | val =  0.287
#         (gpot_950 -3): pval = 0.00016 | val = -0.287
#         (rhum_250 -5): pval = 0.00016 | val =  0.287
#         (eqt1000 -1): pval = 0.00017 | val =  0.286
#         (outrhum_400 -14): pval = 0.00017 | val =  0.286
#         (outvvel_100 -9): pval = 0.00017 | val =  0.286
#         (outrhum_600 -13): pval = 0.00017 | val =  0.286
#         (vi_moisture_div -16): pval = 0.00017 | val = -0.285
#         (vimean_moisture_div -16): pval = 0.00017 | val = -0.285
#         (tot_cld_rain -5): pval = 0.00017 | val =  0.285
#         (vi_moisture_div -7): pval = 0.00017 | val = -0.285
#         (vimean_moisture_div -7): pval = 0.00017 | val = -0.285
#         (outrhum_600 -16): pval = 0.00018 | val =  0.285
#         (outrhum_600 -12): pval = 0.00018 | val =  0.284
#         (sh850_200 -15): pval = 0.00019 | val = -0.284
#         (vi_moisture_div -8): pval = 0.00019 | val = -0.284
#         (vimean_moisture_div -8): pval = 0.00019 | val = -0.284
#         (tot_cldwtr -4): pval = 0.00020 | val =  0.283
#         (vvel_975 -16): pval = 0.00020 | val = -0.283
#         (gpot_400 -11): pval = 0.00020 | val = -0.283
#         (outvort_1000 -1): pval = 0.00022 | val = -0.281
#         (vi_moisture_div -14): pval = 0.00022 | val = -0.281
#         (vimean_moisture_div -14): pval = 0.00022 | val = -0.281
#         (sh850_200 -16): pval = 0.00023 | val = -0.281
#         (sh850_250 -16): pval = 0.00024 | val = -0.280
#         (rhum_800 -2): pval = 0.00025 | val =  0.280
#         (tot_cldwtr -6): pval = 0.00025 | val =  0.279
#         (tot_cldwtr -5): pval = 0.00025 | val =  0.279
#         (cape -3): pval = 0.00026 | val = -0.279
#         (sh850_250 -15): pval = 0.00029 | val = -0.277
#         (vi_div_moisture_flux -14): pval = 0.00029 | val = -0.277
#         (outrhum_600 -11): pval = 0.00030 | val =  0.277
#         (outrhum_400 -13): pval = 0.00031 | val =  0.276
#         (vvel_975 -13): pval = 0.00032 | val = -0.276
#         (outvvel_100 -15): pval = 0.00032 | val =  0.275
#         (vi_moisture_div -11): pval = 0.00033 | val = -0.275
#         (vimean_moisture_div -11): pval = 0.00033 | val = -0.275
#         (vvel_1000 -1): pval = 0.00033 | val =  0.275
#         (gpot_400 -7): pval = 0.00034 | val = -0.274
#         (tot_cld_rain -3): pval = 0.00036 | val =  0.273
#         (out_div400 -3): pval = 0.00037 | val =  0.273
#         (gpot_500 -11): pval = 0.00037 | val = -0.273
#         (rhum_250 -6): pval = 0.00037 | val =  0.273
#         (vi_div_moisture_flux -15): pval = 0.00037 | val = -0.273
#         (gpot_800 -7): pval = 0.00038 | val = -0.273
#         (2mdewtmp -4): pval = 0.00039 | val = -0.272
#         (outgpot_600 -11): pval = 0.00040 | val = -0.272
#         (vi_moisture_div -13): pval = 0.00040 | val = -0.272
#         (vimean_moisture_div -13): pval = 0.00040 | val = -0.272
#         (vvel_925 -10): pval = 0.00041 | val = -0.271
#         (gpot_50 -16): pval = 0.00041 | val = -0.271
#         (outgpot_50 -16): pval = 0.00041 | val = -0.271
#         (sh925_200 -16): pval = 0.00041 | val = -0.271
#         (rhum_800 -3): pval = 0.00041 | val =  0.271
#         (sh925_200 -15): pval = 0.00045 | val = -0.270
#         (vvel_600 -16): pval = 0.00048 | val = -0.269
#         (outrhum_500 -6): pval = 0.00050 | val =  0.268
#         (vvel_925 -13): pval = 0.00050 | val = -0.268
#         (outvort_850 -3): pval = 0.00050 | val = -0.268
#         (conv_ppt -12): pval = 0.00050 | val =  0.268
#         (eqt250 -16): pval = 0.00050 | val = -0.268
#         (eqt250 -7): pval = 0.00052 | val =  0.267
#         (rhum_250 -7): pval = 0.00052 | val =  0.267
#         (outgpot_100 -16): pval = 0.00055 | val = -0.266
#         (out_div400 -5): pval = 0.00056 | val =  0.266
#         (vvel_700 -14): pval = 0.00056 | val = -0.266
#         (vort_100 -12): pval = 0.00056 | val =  0.266
#         (outgpot_150 -16): pval = 0.00056 | val = -0.266
#         (tot_cldwtr -7): pval = 0.00057 | val =  0.266
#         (vvel_700 -15): pval = 0.00058 | val = -0.265
#         (outvvel_100 -12): pval = 0.00059 | val =  0.265
#         (div100 -6): pval = 0.00059 | val =  0.265
#         (outrhum_700 -1): pval = 0.00059 | val =  0.265
#         (outrhum_400 -12): pval = 0.00059 | val =  0.265
#         (rhum_200 -15): pval = 0.00061 | val =  0.265
#         (vort_100 -15): pval = 0.00061 | val =  0.264
#         (vvel_600 -15): pval = 0.00066 | val = -0.263
#         (eqt250 -8): pval = 0.00070 | val =  0.263
#         (rhum_850 -12): pval = 0.00073 | val =  0.262
#         (vi_moisture_div -9): pval = 0.00075 | val = -0.261
#         (vimean_moisture_div -9): pval = 0.00075 | val = -0.261
#         (outrhum_600 -10): pval = 0.00075 | val =  0.261
#         (vi_div_moisture_flux -16): pval = 0.00076 | val = -0.261
#         (outvort_800 -3): pval = 0.00077 | val = -0.261
#         (rhum_250 -12): pval = 0.00077 | val =  0.261
#         (vvel_850 -9): pval = 0.00078 | val = -0.261
#         (rhum_250 -9): pval = 0.00079 | val =  0.260
#         (inst_ssh_flux -15): pval = 0.00081 | val = -0.260
#         (outgpot_150 -15): pval = 0.00081 | val = -0.260
#         (gpot_70 -16): pval = 0.00081 | val = -0.260
#         (rhum_700 -1): pval = 0.00081 | val =  0.260
#         (gpot_700 -3): pval = 0.00082 | val = -0.260
#         (eqt250 -9): pval = 0.00083 | val =  0.260
#         (rhum_700 -2): pval = 0.00085 | val =  0.259
#         (sh925_250 -16): pval = 0.00085 | val = -0.259
#         (out_div400 -1): pval = 0.00088 | val =  0.258
#         (outgpot_50 -15): pval = 0.00090 | val = -0.258
#         (outgpot_100 -15): pval = 0.00092 | val = -0.258
#         (vvel_600 -14): pval = 0.00092 | val = -0.257
#         (out_wstrss10 -12): pval = 0.00094 | val = -0.257
#         (outvort_1000 -2): pval = 0.00095 | val = -0.257
#         (outgpot_400 -15): pval = 0.00095 | val = -0.257
#         (rhum_850 -13): pval = 0.00096 | val =  0.257
#         (gpot_50 -15): pval = 0.00096 | val = -0.257
#         (gpot_70 -15): pval = 0.00096 | val = -0.257
#         (outgpot_400 -11): pval = 0.00097 | val = -0.256
#         (eqt250 -6): pval = 0.00098 | val =  0.256
#         (tot_cldwtr -2): pval = 0.00099 | val =  0.256
#         (sh850_200 -14): pval = 0.00099 | val = -0.256
#         (tot_cld_rain -8): pval = 0.00100 | val =  0.256
#         (div100 -7): pval = 0.00101 | val =  0.256
#         (vort_20 -12): pval = 0.00103 | val = -0.255
#         (vvel_925 -14): pval = 0.00104 | val = -0.255
#         (vort_20 -11): pval = 0.00105 | val = -0.255
#         (vvel_925 -11): pval = 0.00105 | val = -0.255
#         (outvort_900 -1): pval = 0.00107 | val = -0.254
#         (out_div400 -8): pval = 0.00107 | val =  0.254
#         (outgpot_20 -16): pval = 0.00108 | val = -0.254
#         (out_div400 -2): pval = 0.00110 | val =  0.254
#         (outgpot_700 -11): pval = 0.00112 | val = -0.254
#         (rhum_250 -13): pval = 0.00112 | val =  0.254
#         (rhum_800 -12): pval = 0.00112 | val =  0.253
#         (rhum_250 -8): pval = 0.00113 | val =  0.253
#         (outgpot_70 -16): pval = 0.00113 | val = -0.253
#         (sh925_250 -15): pval = 0.00113 | val = -0.253
#         (rhum_850 -15): pval = 0.00114 | val =  0.253
#         (rhum_800 -4): pval = 0.00115 | val =  0.253
#         (rhum_800 -13): pval = 0.00121 | val =  0.252
#         (outgpot_600 -7): pval = 0.00121 | val = -0.252
#         (rhum_850 -14): pval = 0.00125 | val =  0.252
#         (tot_cld_rain -4): pval = 0.00126 | val =  0.251
#         (rhum_250 -10): pval = 0.00126 | val =  0.251
#         (out_div400 -9): pval = 0.00128 | val =  0.251
#         (rhum_700 -3): pval = 0.00130 | val =  0.251
#         (rhum_150 -13): pval = 0.00130 | val =  0.251
#         (outgpot_500 -11): pval = 0.00131 | val = -0.251
#         (gpot_150 -16): pval = 0.00132 | val = -0.251
#         (vvel_850 -8): pval = 0.00134 | val = -0.250
#         (2mtmp -16): pval = 0.00135 | val = -0.250
#         (outrhum_400 -11): pval = 0.00135 | val =  0.250
#         (rhum_250 -11): pval = 0.00135 | val =  0.250
#         (eqt250 -10): pval = 0.00136 | val =  0.250
#         (gpot_400 -8): pval = 0.00139 | val = -0.250
#         (vi_moisture_div -10): pval = 0.00139 | val = -0.249
#         (vimean_moisture_div -10): pval = 0.00139 | val = -0.249
#         (gpot_100 -16): pval = 0.00144 | val = -0.249
#         (tot_cld_rain -2): pval = 0.00145 | val =  0.249
#         (eqt250 -3): pval = 0.00145 | val =  0.249
#         (outrhum_600 -9): pval = 0.00145 | val =  0.249
#         (outgpot_700 -7): pval = 0.00162 | val = -0.247
#         (outgpot_70 -15): pval = 0.00163 | val = -0.247
#         (eqt1000 -12): pval = 0.00166 | val =  0.247
#         (vvel_700 -13): pval = 0.00169 | val = -0.246
#         (outgpot_10 -16): pval = 0.00170 | val = -0.246
#         (vvel_850 -5): pval = 0.00170 | val = -0.246
#         (vort_100 -11): pval = 0.00172 | val =  0.246
#         (rhum_700 -15): pval = 0.00174 | val =  0.246
#         (gpot_850 -7): pval = 0.00174 | val = -0.246
#         (rhum_800 -14): pval = 0.00187 | val =  0.245
#         (gpot_150 -15): pval = 0.00187 | val = -0.245
#         (rhum_800 -15): pval = 0.00189 | val =  0.244
#         (outrhum_500 -5): pval = 0.00189 | val =  0.244
#         (eqt250 -2): pval = 0.00190 | val =  0.244
#         (vvel_850 -16): pval = 0.00190 | val = -0.244
#         (outrhum_600 -8): pval = 0.00193 | val =  0.244
#         (rhum_900 -12): pval = 0.00196 | val =  0.244
#         (2mdewtmp -5): pval = 0.00199 | val = -0.243
#         (outvort_900 -12): pval = 0.00199 | val = -0.243
#         (outvort_900 -2): pval = 0.00200 | val = -0.243
#         (gpot_400 -12): pval = 0.00200 | val = -0.243
#         (gpot_100 -15): pval = 0.00204 | val = -0.243
#         (gpot_300 -11): pval = 0.00219 | val = -0.242
#         (vort_500 -12): pval = 0.00216 | val = -0.241
#         (gpot_600 -11): pval = 0.00226 | val = -0.241
#         (eqt250 -5): pval = 0.00226 | val =  0.241
#         (outgpot_150 -12): pval = 0.00231 | val = -0.241
#         (outvort_900 -8): pval = 0.00232 | val = -0.241
#         (vvel_975 -5): pval = 0.00240 | val = -0.240
#         (sh925_200 -14): pval = 0.00240 | val = -0.240
#         (rhum_800 -11): pval = 0.00243 | val =  0.240
#         (outgpot_150 -14): pval = 0.00244 | val = -0.239
#         (eqt250 -4): pval = 0.00245 | val =  0.239
#         (outgpot_100 -12): pval = 0.00252 | val = -0.239
#         (vi_div_moisture_flux -13): pval = 0.00255 | val = -0.239
#         (sh850_250 -14): pval = 0.00255 | val = -0.239
#         (outgpot_100 -14): pval = 0.00258 | val = -0.238
#         (outrhum_600 -7): pval = 0.00259 | val =  0.238
#         (gpot_20 -16): pval = 0.00262 | val = -0.238
#         (vi_moisture_div -4): pval = 0.00262 | val = -0.238
#         (vimean_moisture_div -4): pval = 0.00262 | val = -0.238
#         (gpot_500 -8): pval = 0.00264 | val = -0.238
#         (rhum_900 -13): pval = 0.00264 | val =  0.238
#         (tot_cld_rain -9): pval = 0.00264 | val =  0.238
#         (gpot_10 -16): pval = 0.00268 | val = -0.237
#         (vort_20 -2): pval = 0.00273 | val = -0.237
#         (outvort_900 -9): pval = 0.00276 | val = -0.237
#         (rhum_300 -1): pval = 0.00277 | val =  0.237
#         (vvel_700 -12): pval = 0.00279 | val = -0.237
#         (outvort_900 -11): pval = 0.00283 | val = -0.236
#         (vvel_925 -16): pval = 0.00288 | val = -0.236
#         (rhum_700 -4): pval = 0.00293 | val =  0.236
#         (2mtmp -15): pval = 0.00293 | val = -0.236
#         (outvort_900 -10): pval = 0.00294 | val = -0.236
#         (2mtmp -4): pval = 0.00294 | val = -0.236
#         (vi_moisture_div -6): pval = 0.00294 | val = -0.236
#         (vimean_moisture_div -6): pval = 0.00294 | val = -0.236
#         (outvort_900 -7): pval = 0.00295 | val = -0.235
#         (rhum_250 -14): pval = 0.00297 | val =  0.235
#         (out_div400 -6): pval = 0.00297 | val =  0.235
#         (out_div400 -7): pval = 0.00297 | val =  0.235
#         (outvort_850 -4): pval = 0.00298 | val = -0.235
#         (gpot_400 -15): pval = 0.00300 | val = -0.235
#         (gpot_200 -15): pval = 0.00306 | val = -0.235
#         (outgpot_150 -11): pval = 0.00314 | val = -0.234
#         (out_sh925_200 -16): pval = 0.00316 | val = -0.234
#         (outgpot_200 -16): pval = 0.00316 | val = -0.234
#         (div100 -5): pval = 0.00316 | val =  0.234
#         (outgpot_200 -15): pval = 0.00316 | val = -0.234
#         (outrhum_600 -6): pval = 0.00316 | val =  0.234
#         (rhum_850 -11): pval = 0.00326 | val =  0.233
#         (gpot_200 -16): pval = 0.00328 | val = -0.233
#         (gpot_70 -14): pval = 0.00332 | val = -0.233
#         (outvort_900 -13): pval = 0.00338 | val = -0.232
#         (outvort_800 -4): pval = 0.00338 | val = -0.232
#         (vvel_975 -15): pval = 0.00338 | val = -0.232
#         (outvort_925 -12): pval = 0.00354 | val = -0.232
#         (gpot_150 -12): pval = 0.00360 | val = -0.231
#         (vort_100 -16): pval = 0.00360 | val =  0.231
#         (rhum_500 -1): pval = 0.00363 | val =  0.231
#         (vvel_850 -7): pval = 0.00364 | val = -0.231
#         (outvvel_100 -16): pval = 0.00372 | val =  0.230
#         (outgpot_400 -12): pval = 0.00372 | val = -0.230
#         (rhum_700 -16): pval = 0.00372 | val =  0.230
#         (rhum_800 -10): pval = 0.00372 | val =  0.230
#         (gpot_100 -12): pval = 0.00372 | val = -0.230
#         (gpot_250 -15): pval = 0.00377 | val = -0.230
#         (outgpot_500 -15): pval = 0.00378 | val = -0.230
#         (div100 -8): pval = 0.00378 | val =  0.230
#         (outgpot_20 -15): pval = 0.00385 | val = -0.230
#         (gpot_400 -10): pval = 0.00386 | val = -0.229
#         (outgpot_100 -11): pval = 0.00386 | val = -0.229
#         (vvel_975 -14): pval = 0.00386 | val = -0.229
#         (2mtmp -5): pval = 0.00391 | val = -0.229
#         (rhum_800 -9): pval = 0.00391 | val =  0.229
#         (gpot_300 -15): pval = 0.00391 | val = -0.229
#         (outgpot_300 -15): pval = 0.00391 | val = -0.229
#         (tot_cld_rain -10): pval = 0.00391 | val =  0.229
#         (outgpot_30 -16): pval = 0.00391 | val = -0.229
#         (vvel_850 -6): pval = 0.00394 | val = -0.229
#         (vvel_600 -13): pval = 0.00395 | val = -0.229
#         (rhum_850 -16): pval = 0.00399 | val =  0.228
#         (div200 -14): pval = 0.00400 | val =  0.228
#         (vort_20 -1): pval = 0.00400 | val = -0.228
#         (outrhum_500 -4): pval = 0.00403 | val =  0.228
#         (outgpot_300 -11): pval = 0.00406 | val = -0.228
#         (vvel_850 -14): pval = 0.00416 | val = -0.228
#         (vort_150 -14): pval = 0.00420 | val =  0.227
#         (rhum_900 -14): pval = 0.00421 | val =  0.227
#         (vort_20 -3): pval = 0.00422 | val = -0.227
#         (rhum_700 -14): pval = 0.00423 | val =  0.227
#         (vort_20 -10): pval = 0.00424 | val = -0.227
#         (gpot_70 -12): pval = 0.00425 | val = -0.227
#         (outvort_900 -3): pval = 0.00428 | val = -0.227
#         (gpot_250 -11): pval = 0.00428 | val = -0.227
#         (outgpot_100 -13): pval = 0.00428 | val = -0.227
#         (outrhum_600 -5): pval = 0.00430 | val =  0.227
#         (gpot_30 -16): pval = 0.00431 | val = -0.227
#         (outvort_1000 -3): pval = 0.00434 | val = -0.227
#         (gpot_300 -12): pval = 0.00434 | val = -0.227
#         (rhum_500 -2): pval = 0.00445 | val =  0.226
#         (vort_150 -13): pval = 0.00447 | val =  0.226
#         (outgpot_150 -13): pval = 0.00447 | val = -0.226
#         (vvel_925 -4): pval = 0.00447 | val = -0.226
#         (outgpot_600 -15): pval = 0.00448 | val = -0.226
#         (rhum_975 -16): pval = 0.00452 | val =  0.226
#         (outgpot_70 -12): pval = 0.00453 | val = -0.226
#         (vvel_850 -12): pval = 0.00453 | val = -0.226
#         (outrhum_400 -10): pval = 0.00454 | val =  0.226
#         (gpot_900 -7): pval = 0.00463 | val = -0.225
#         (rhum_900 -15): pval = 0.00465 | val =  0.225
#         (gpot_150 -11): pval = 0.00473 | val = -0.225
#         (gpot_100 -14): pval = 0.00476 | val = -0.225
#         (out_sh925_200 -15): pval = 0.00478 | val = -0.225
#         (outvort_925 -13): pval = 0.00478 | val = -0.225
#         (vi_moisture_div -5): pval = 0.00479 | val = -0.224
#         (vimean_moisture_div -5): pval = 0.00479 | val = -0.224
#         (outsurfmean_lhf -5): pval = 0.00479 | val =  0.224
#         (outsurf_lhf -5): pval = 0.00479 | val =  0.224
#         (vvel_925 -15): pval = 0.00479 | val = -0.224
#         (outrhum_800 -15): pval = 0.00479 | val =  0.224
#         (vvel_700 -8): pval = 0.00487 | val = -0.224
#         (outvort_50 -7): pval = 0.00488 | val = -0.224
#         (outrhum_600 -4): pval = 0.00491 | val =  0.224
#         (cape -4): pval = 0.00501 | val = -0.223
#         (outvvel_150 -2): pval = 0.00502 | val =  0.223
#         (rhum_700 -5): pval = 0.00507 | val =  0.223
#         (outrhum_800 -16): pval = 0.00507 | val =  0.223
#         (out_wstrss10 -13): pval = 0.00510 | val = -0.223
#         (outgpot_400 -16): pval = 0.00510 | val = -0.223
#         (rhum_500 -3): pval = 0.00512 | val =  0.223
#         (eqt200 -7): pval = 0.00518 | val =  0.223
#         (outvort_850 -5): pval = 0.00519 | val = -0.223
#         (outgpot_70 -14): pval = 0.00519 | val = -0.223
#         (gpot_150 -14): pval = 0.00524 | val = -0.222
#         (eqt250 -11): pval = 0.00527 | val =  0.222
#         (outgpot_250 -15): pval = 0.00527 | val = -0.222
#         (outgpot_50 -14): pval = 0.00530 | val = -0.222
#         (gpot_200 -12): pval = 0.00532 | val = -0.222
#         (2mtmp -3): pval = 0.00532 | val = -0.222
#         (2mtmp -6): pval = 0.00539 | val = -0.222
#         (outvort_900 -14): pval = 0.00539 | val = -0.222
#         (vvel_700 -9): pval = 0.00542 | val = -0.222
#         (vvel_850 -10): pval = 0.00547 | val = -0.222
#         (gpot_250 -12): pval = 0.00548 | val = -0.221
#         (rhum_500 -4): pval = 0.00566 | val =  0.221
#         (gpot_200 -11): pval = 0.00567 | val = -0.221
#         (gpot_50 -14): pval = 0.00569 | val = -0.221
#         (eqt200 -8): pval = 0.00569 | val =  0.221
#         (outvort_925 -1): pval = 0.00573 | val = -0.221
#         (rhum_500 -6): pval = 0.00573 | val =  0.221
#         (rhum_500 -7): pval = 0.00574 | val =  0.221
#         (outinst_moisture_flux -5): pval = 0.00574 | val =  0.221
#         (rhum_500 -5): pval = 0.00579 | val =  0.220
#         (gpot_70 -11): pval = 0.00579 | val = -0.220
#         (gpot_20 -15): pval = 0.00579 | val = -0.220
#         (outvort_975 -1): pval = 0.00584 | val = -0.220
#         (out_eqt200 -16): pval = 0.00584 | val = -0.220
#         (gpot_100 -11): pval = 0.00584 | val = -0.220
#         (outsurfmean_lhf -6): pval = 0.00584 | val =  0.220
#         (outsurf_lhf -6): pval = 0.00584 | val =  0.220
#         (rhum_300 -2): pval = 0.00596 | val =  0.220
#         (vvel_850 -13): pval = 0.00600 | val = -0.219
#         (outgpot_200 -11): pval = 0.00600 | val = -0.219
#         (outrhum_800 -14): pval = 0.00600 | val =  0.219
#         (rhum_800 -8): pval = 0.00600 | val =  0.219
#         (gpot_250 -16): pval = 0.00613 | val = -0.219
#         (vort_100 -10): pval = 0.00616 | val =  0.219
#         (outvort_50 -6): pval = 0.00623 | val = -0.219
#         (outinst_moisture_flux -3): pval = 0.00623 | val =  0.219
#         (vort_100 -9): pval = 0.00628 | val =  0.218
#         (outinst_moisture_flux -6): pval = 0.00634 | val =  0.218
#         (outgpot_200 -12): pval = 0.00640 | val = -0.218
#         (outgpot_250 -11): pval = 0.00651 | val = -0.218
#         (vvel_700 -11): pval = 0.00655 | val = -0.218
#         (outvort_900 -15): pval = 0.00663 | val = -0.217
#         (gpot_50 -12): pval = 0.00677 | val = -0.217
#         (outgpot_70 -11): pval = 0.00681 | val = -0.217
#         (vort_20 -6): pval = 0.00681 | val = -0.217
#         (vort_20 -13): pval = 0.00681 | val = -0.217
#         (outinst_moisture_flux -4): pval = 0.00681 | val =  0.217
#         (tot_cld_ice -14): pval = 0.00683 | val =  0.217
#         (gpot_100 -13): pval = 0.00690 | val = -0.217
#         (vort_20 -5): pval = 0.00690 | val = -0.217
#         (gpot_925 -7): pval = 0.00696 | val = -0.216
#         (outgpot_10 -15): pval = 0.00696 | val = -0.216
#         (outgpot_50 -12): pval = 0.00696 | val = -0.216
#         (outrhum_600 -3): pval = 0.00696 | val =  0.216
#         (sh925_250 -14): pval = 0.00709 | val = -0.216
#         (vvel_975 -11): pval = 0.00721 | val = -0.216
#         (gpot_1000 -1): pval = 0.00726 | val =  0.216
#         (vvel_600 -12): pval = 0.00726 | val = -0.215
#         (2mtmp -14): pval = 0.00736 | val = -0.215
#         (outgpot_300 -12): pval = 0.00737 | val = -0.215
#         (outgpot_250 -16): pval = 0.00747 | val = -0.215
#         (inst_ssh_flux -12): pval = 0.00750 | val = -0.215
#         (outgpot_30 -15): pval = 0.00750 | val = -0.215
#         (surf_shf -12): pval = 0.00754 | val = -0.215
#         (surfmean_shf -12): pval = 0.00754 | val = -0.215
#         (outvvel_100 -8): pval = 0.00758 | val =  0.215
#         (outrhum_800 -12): pval = 0.00759 | val =  0.214
#         (outvort_925 -11): pval = 0.00761 | val = -0.214
#         (outgpot_400 -14): pval = 0.00763 | val = -0.214
#         (outgpot_300 -16): pval = 0.00768 | val = -0.214
#         (vvel_975 -7): pval = 0.00773 | val = -0.214
#         (2mdewtmp -6): pval = 0.00774 | val = -0.214
#         (outrhum_500 -3): pval = 0.00777 | val =  0.214
#         (outvvel_150 -1): pval = 0.00790 | val =  0.213
#         (vvel_700 -7): pval = 0.00805 | val = -0.213
#         (vvel_850 -15): pval = 0.00805 | val = -0.213
#         (rhum_800 -5): pval = 0.00806 | val =  0.213
#         (outgpot_500 -7): pval = 0.00806 | val = -0.213
#         (outvort_800 -5): pval = 0.00814 | val = -0.213
#         (outvvel_100 -7): pval = 0.00814 | val =  0.213
#         (rhum_1000 -16): pval = 0.00814 | val =  0.213
#         (rhum_800 -16): pval = 0.00818 | val =  0.213
#         (gpot_300 -7): pval = 0.00818 | val = -0.213
#         (2mtmp -11): pval = 0.00819 | val = -0.213
#         (outrhum_800 -3): pval = 0.00819 | val =  0.213
#         (rhum_200 -16): pval = 0.00819 | val =  0.212
#         (outrhum_800 -4): pval = 0.00819 | val =  0.212
#         (rhum_850 -10): pval = 0.00836 | val =  0.212
#         (gpot_150 -13): pval = 0.00836 | val = -0.212
#         (vi_div_moisture_flux -10): pval = 0.00838 | val = -0.212
#         (rhum_700 -6): pval = 0.00845 | val =  0.212
#         (vort_20 -4): pval = 0.00845 | val = -0.212
#         (gpot_30 -15): pval = 0.00864 | val = -0.211
#         (outvort_50 -8): pval = 0.00866 | val = -0.211
#         (2mtmp -12): pval = 0.00869 | val = -0.211
#         (outrhum_800 -13): pval = 0.00876 | val =  0.211
#         (div100 -9): pval = 0.00876 | val =  0.211
#         (vvel_500 -15): pval = 0.00876 | val = -0.211
#         (vort_20 -9): pval = 0.00876 | val = -0.211
#         (eqt200 -6): pval = 0.00891 | val =  0.211
#         (outgpot_200 -14): pval = 0.00896 | val = -0.211
#         (gpot_70 -13): pval = 0.00896 | val = -0.211
#         (rhum_500 -8): pval = 0.00899 | val =  0.210
#         (outvvel_150 -3): pval = 0.00906 | val =  0.210
#         (vi_div_moisture_flux -12): pval = 0.00908 | val = -0.210
#         (out_eqt500 -11): pval = 0.00910 | val =  0.210
#         (outgpot_250 -12): pval = 0.00920 | val = -0.210
#         (outvort_50 -5): pval = 0.00924 | val = -0.210
#         (outvort_850 -7): pval = 0.00926 | val = -0.210
#         (outvort_900 -6): pval = 0.00928 | val = -0.210
#         (gpot_200 -14): pval = 0.00928 | val = -0.210
#         (out_sh925_200 -14): pval = 0.00952 | val = -0.209
#         (vvel_700 -10): pval = 0.00952 | val = -0.209
#         (tot_cld_ice -6): pval = 0.00953 | val =  0.209
#         (outvi_pe_inte -11): pval = 0.00953 | val = -0.209
#         (rhum_250 -15): pval = 0.00954 | val =  0.209
#         (outvort_850 -6): pval = 0.00959 | val = -0.209
#         (out_eqt500 -14): pval = 0.00968 | val =  0.209
#         (div400 -9): pval = 0.00977 | val =  0.209
#         (outvort_925 -14): pval = 0.00986 | val = -0.208
#         (rhum_900 -16): pval = 0.00987 | val =  0.208
#         (vi_div_moisture_flux -9): pval = 0.00987 | val = -0.208
#         (outsurfmean_lhf -4): pval = 0.00993 | val =  0.208
#         (outsurf_lhf -4): pval = 0.00993 | val =  0.208
#         (div300 -6): pval = 0.00999 | val = -0.208
#         (gpot_300 -16): pval = 0.01022 | val = -0.208
#         (vort_20 -7): pval = 0.01031 | val = -0.208
#         (tot_cld_ice -15): pval = 0.01031 | val =  0.207
#         (gpot_500 -10): pval = 0.01041 | val = -0.207
#         (outgpot_400 -7): pval = 0.01042 | val = -0.207
#         (outgpot_70 -13): pval = 0.01053 | val = -0.207
#         (vort_20 -8): pval = 0.01053 | val = -0.207
#         (gpot_950 -7): pval = 0.01061 | val = -0.207
#         (out_eqt500 -13): pval = 0.01071 | val =  0.207
#         (vvel_500 -16): pval = 0.01077 | val = -0.206
#         (rhum_700 -10): pval = 0.01081 | val =  0.206
#         (outvi_div_cld_liq_wtr -16): pval = 0.01093 | val = -0.206
#         (gpot_600 -8): pval = 0.01102 | val = -0.206
#         (gpot_300 -8): pval = 0.01105 | val = -0.206
#         (rhum_800 -7): pval = 0.01108 | val =  0.206
#         (outvort_30 -7): pval = 0.01109 | val = -0.206
#         (eqt250 -1): pval = 0.01113 | val =  0.206
#         (outvort_1000 -4): pval = 0.01113 | val = -0.206
#         (rhum_700 -11): pval = 0.01113 | val =  0.206
#         (div200 -13): pval = 0.01113 | val =  0.206
#         (gpot_10 -15): pval = 0.01113 | val = -0.206
#         (out_eqt500 -12): pval = 0.01113 | val =  0.206
#         (sh850_200 -13): pval = 0.01123 | val = -0.205
#         (out_eqt500 -10): pval = 0.01130 | val =  0.205
#         (outrhum_800 -2): pval = 0.01130 | val =  0.205
# ...
#         (surfmean_lhf -3): pval = 0.03506 | val =  0.174
#         (vvel_1000 -8): pval = 0.03506 | val = -0.174
#         (out_div500 -8): pval = 0.03534 | val =  0.174
#         (gpot_20 -5): pval = 0.03537 | val =  0.174
#         (outgpot_200 -6): pval = 0.03553 | val =  0.174
#         (outvvel_150 -12): pval = 0.03559 | val = -0.174
#         (outvvel_70 -10): pval = 0.03577 | val =  0.174
#         (outvvel_700 -15): pval = 0.03596 | val = -0.173
#         (outvi_moisture_div -3): pval = 0.03596 | val =  0.173
#         (outvimean_moisture_div -3): pval = 0.03596 | val =  0.173
#         (2mtmp -13): pval = 0.03596 | val =  0.173
#         (vort_975 -2): pval = 0.03620 | val = -0.173
#         (outrhum_975 -10): pval = 0.03638 | val =  0.173
#         (gpot_150 -15): pval = 0.03665 | val =  0.173
#         (outrhum_950 -13): pval = 0.03668 | val = -0.173
#         (eqt700 -5): pval = 0.03678 | val =  0.173
#         (vort_900 -16): pval = 0.03694 | val =  0.173
#         (vi_div_cld_froz_wtr -4): pval = 0.03699 | val = -0.173
#         (gpot_70 -5): pval = 0.03702 | val =  0.173
#         (div100 -10): pval = 0.03720 | val = -0.172
#         (outgpot_600 -5): pval = 0.03725 | val =  0.172
#         (rhum_100 -5): pval = 0.03737 | val =  0.172
#         (outvvel_70 -16): pval = 0.03740 | val = -0.172
#         (2mtmp -14): pval = 0.03795 | val =  0.172
#         (eqt300 -16): pval = 0.03795 | val =  0.172
#         (outvvel_30 -12): pval = 0.03807 | val =  0.172
#         (outgpot_400 -12): pval = 0.03810 | val =  0.172
#         (vvel_300 -12): pval = 0.03820 | val =  0.172
#         (tot_cld_ice -1): pval = 0.03820 | val =  0.171
#         (eqt850 -8): pval = 0.03858 | val =  0.171
#         (outvvel_850 -10): pval = 0.03916 | val =  0.171
#         (outvvel_20 -7): pval = 0.03916 | val = -0.171
#         (surfmean_lhf -5): pval = 0.03921 | val =  0.171
#         (surf_lhf -5): pval = 0.03921 | val =  0.171
#         (outvvel_700 -10): pval = 0.03952 | val =  0.170
#         (tot_suprcool_liqwtr -7): pval = 0.03972 | val = -0.170
#         (gpot_200 -16): pval = 0.03988 | val =  0.170
#         (out_div300 -4): pval = 0.04001 | val = -0.170
#         (eqt600 -14): pval = 0.04022 | val =  0.170
#         (eqt300 -1): pval = 0.04045 | val =  0.170
#         (vi_div_tot_enrgy_flux -10): pval = 0.04046 | val = -0.170
#         (outrhum_850 -4): pval = 0.04051 | val = -0.170
#         (outrhum_925 -6): pval = 0.04059 | val = -0.170
#         (outrhum_200 -4): pval = 0.04072 | val = -0.170
#         (div100 -13): pval = 0.04099 | val = -0.169
#         (outrhum_250 -16): pval = 0.04100 | val = -0.169
#         (conv_ppt -12): pval = 0.04109 | val = -0.169
#         (outrhum_975 -6): pval = 0.04109 | val = -0.169
#         (vvel_500 -2): pval = 0.04133 | val = -0.169
#         (gpot_150 -9): pval = 0.04134 | val =  0.169
#         (outgpot_150 -6): pval = 0.04171 | val =  0.169
#         (vort_925 -2): pval = 0.04184 | val = -0.169
#         (outgpot_30 -13): pval = 0.04223 | val =  0.169
#         (eqt300 -3): pval = 0.04225 | val =  0.168
#         (outvvel_20 -13): pval = 0.04227 | val =  0.168
#         (eqt600 -10): pval = 0.04240 | val =  0.168
#         (outgpot_250 -6): pval = 0.04240 | val =  0.168
#         (gpot_150 -16): pval = 0.04240 | val =  0.168
#         (outconv_ppt -11): pval = 0.04320 | val = -0.168
#         (outvvel_700 -3): pval = 0.04342 | val =  0.168
#         (vi_pe_inte -15): pval = 0.04375 | val =  0.168
#         (vi_div_cld_froz_wtr -8): pval = 0.04379 | val = -0.168
#         (outgpot_30 -5): pval = 0.04406 | val =  0.167
#         (outrhum_975 -5): pval = 0.04449 | val = -0.167
#         (outvort_10 -13): pval = 0.04457 | val =  0.167
#         (vvel_250 -11): pval = 0.04462 | val =  0.167
#         (outrhum_1000 -14): pval = 0.04469 | val = -0.167
#         (vvel_975 -16): pval = 0.04477 | val = -0.167
#         (gpot_100 -6): pval = 0.04483 | val =  0.167
#         (vort_20 -16): pval = 0.04495 | val =  0.167
#         (vort_600 -15): pval = 0.04516 | val =  0.167
#         (out_sh850_250 -12): pval = 0.04536 | val = -0.166
#         (vvel_200 -6): pval = 0.04536 | val =  0.166
#         (sh925_250 -10): pval = 0.04569 | val = -0.166
#         (out_div300 -5): pval = 0.04572 | val = -0.166
#         (vort_250 -12): pval = 0.04627 | val =  0.166
#         (outvvel_50 -8): pval = 0.04632 | val = -0.166
#         (out_div100 -4): pval = 0.04644 | val = -0.166
#         (outinst_ssh_flux -10): pval = 0.04669 | val =  0.166
#         (outrhum_900 -4): pval = 0.04692 | val = -0.165
#         (outtot_cld_ice -5): pval = 0.04719 | val = -0.165
#         (outgpot_200 -16): pval = 0.04719 | val =  0.165
#         (gpot_30 -13): pval = 0.04757 | val =  0.165
#         (vort_975 -16): pval = 0.04757 | val =  0.165
#         (outgpot_150 -15): pval = 0.04758 | val =  0.165
#         (gpot_150 -6): pval = 0.04758 | val =  0.165
#         (rhum_700 -8): pval = 0.04770 | val =  0.165
#         (gpot_50 -12): pval = 0.04771 | val =  0.165
#         (outrhum_950 -14): pval = 0.04779 | val = -0.165
#         (vort_500 -15): pval = 0.04798 | val =  0.165
#         (vort_400 -13): pval = 0.04813 | val =  0.165
#         (eqt850 -6): pval = 0.04813 | val =  0.165
#         (eqt600 -15): pval = 0.04813 | val =  0.165
#         (vort_500 -11): pval = 0.04814 | val =  0.165
#         (outgpot_250 -16): pval = 0.04828 | val =  0.165
#         (conv_ppt -3): pval = 0.04844 | val = -0.164
#         (div100 -9): pval = 0.04844 | val = -0.164
#         (vvel_700 -12): pval = 0.04851 | val =  0.164
#         (vvel_600 -1): pval = 0.04910 | val = -0.164
#         (outgpot_100 -6): pval = 0.04912 | val =  0.164
#         (gpot_200 -15): pval = 0.04926 | val =  0.164
#
#     Variable div100 has 0 link(s):
#
#     Variable div200 has 0 link(s):
#
#     Variable div250 has 0 link(s):
#
#     Variable div300 has 0 link(s):
#
#     Variable div400 has 0 link(s):
#
#     Variable div500 has 0 link(s):
#
#     Variable eqt1000 has 0 link(s):
#
#     Variable eqt200 has 0 link(s):
#
#     Variable eqt250 has 0 link(s):
#
#     Variable eqt300 has 0 link(s):
#
#     Variable eqt400 has 0 link(s):
#
#     Variable eqt500 has 0 link(s):
#
#     Variable eqt600 has 0 link(s):
#
#     Variable eqt700 has 0 link(s):
#
#     Variable eqt850 has 0 link(s):
#
#     Variable eqt925 has 0 link(s):
#
#     Variable sh850_200 has 0 link(s):
#
#     Variable sh850_250 has 0 link(s):
#
#     Variable sh925_200 has 0 link(s):
#
#     Variable sh925_250 has 0 link(s):
#
#     Variable wstrss10 has 0 link(s):
#
#     Variable 2mdewtmp has 0 link(s):
#
#     Variable 2mtmp has 0 link(s):
#
#     Variable conv_ppt has 0 link(s):
#
#     Variable tot_cld_ice has 0 link(s):
#
#     Variable tot_cldwtr has 0 link(s):
#
#     Variable tot_cld_rain has 0 link(s):
#
#     Variable vi_div_cld_froz_wtr has 0 link(s):
#
#     Variable vi_div_cld_liq_wtr has 0 link(s):
#
#     Variable vi_div_mass_flux has 0 link(s):
#
#     Variable vi_div_moisture_flux has 0 link(s):
#
#     Variable vi_div_tot_enrgy_flux has 0 link(s):
#
#     Variable vi_pe_inte has 0 link(s):
#
#     Variable vi_pe_ie_latentenrgy has 0 link(s):
#
#     Variable vi_olr has 0 link(s):
#
#     Variable vi_tot_enrgy has 0 link(s):
#
#     Variable vi_moisture_div has 0 link(s):
#
#     Variable cape has 0 link(s):
#
#     Variable inst_moisture_flux has 0 link(s):
#
#     Variable inst_ssh_flux has 0 link(s):
#
#     Variable surfmean_lhf has 0 link(s):
#
#     Variable surfmean_shf has 0 link(s):
#
#     Variable vimean_moisture_div has 0 link(s):
#
#     Variable surf_lhf has 0 link(s):
#
#     Variable surf_shf has 0 link(s):
#
#     Variable tot_suprcool_liqwtr has 0 link(s):
#
#     Variable tot_wtr_vpr has 0 link(s):
#
#     Variable sst has 0 link(s):
#
#     Variable vort_10 has 0 link(s):
#
#     Variable vort_20 has 0 link(s):
#
#     Variable vort_30 has 0 link(s):
#
#     Variable vort_50 has 0 link(s):
#
#     Variable vort_70 has 0 link(s):
#
#     Variable vort_100 has 0 link(s):
#
#     Variable vort_150 has 0 link(s):
#
#     Variable vort_200 has 0 link(s):
#
#     Variable vort_250 has 0 link(s):
#
#     Variable vort_300 has 0 link(s):
#
#     Variable vort_400 has 0 link(s):
#
#     Variable vort_500 has 0 link(s):
#
#     Variable vort_600 has 0 link(s):
#
#     Variable vort_700 has 0 link(s):
#
#     Variable vort_800 has 0 link(s):
#
#     Variable vort_850 has 0 link(s):
#
#     Variable vort_900 has 0 link(s):
#
#     Variable vort_925 has 0 link(s):
#
#     Variable vort_950 has 0 link(s):
#
#     Variable vort_975 has 0 link(s):
#
#     Variable vort_1000 has 0 link(s):
#
#     Variable rhum_10 has 0 link(s):
#
#     Variable rhum_20 has 0 link(s):
#
#     Variable rhum_30 has 0 link(s):
#
#     Variable rhum_50 has 0 link(s):
#
#     Variable rhum_70 has 0 link(s):
#
#     Variable rhum_100 has 0 link(s):
#
#     Variable rhum_150 has 0 link(s):
#
#     Variable rhum_200 has 0 link(s):
#
#     Variable rhum_250 has 0 link(s):
#
#     Variable rhum_300 has 0 link(s):
#
#     Variable rhum_400 has 0 link(s):
#
#     Variable rhum_500 has 0 link(s):
#
#     Variable rhum_600 has 0 link(s):
#
#     Variable rhum_700 has 0 link(s):
#
#     Variable rhum_800 has 0 link(s):
#
#     Variable rhum_850 has 0 link(s):
#
#     Variable rhum_900 has 0 link(s):
#
#     Variable rhum_925 has 0 link(s):
#
#     Variable rhum_950 has 0 link(s):
#
#     Variable rhum_975 has 0 link(s):
#
#     Variable rhum_1000 has 0 link(s):
#
#     Variable gpot_10 has 0 link(s):
#
#     Variable gpot_20 has 0 link(s):
#
#     Variable gpot_30 has 0 link(s):
#
#     Variable gpot_50 has 0 link(s):
#
#     Variable gpot_70 has 0 link(s):
#
#     Variable gpot_100 has 0 link(s):
#
#     Variable gpot_150 has 0 link(s):
#
#     Variable gpot_200 has 0 link(s):
#
#     Variable gpot_250 has 0 link(s):
#
#     Variable gpot_300 has 0 link(s):
#
#     Variable gpot_400 has 0 link(s):
#
#     Variable gpot_500 has 0 link(s):
#
#     Variable gpot_600 has 0 link(s):
#
#     Variable gpot_700 has 0 link(s):
#
#     Variable gpot_800 has 0 link(s):
#
#     Variable gpot_850 has 0 link(s):
#
#     Variable gpot_900 has 0 link(s):
#
#     Variable gpot_925 has 0 link(s):
#
#     Variable gpot_950 has 0 link(s):
#
#     Variable gpot_975 has 0 link(s):
#
#     Variable gpot_1000 has 0 link(s):
#
#     Variable vvel_10 has 0 link(s):
#
#     Variable vvel_20 has 0 link(s):
#
#     Variable vvel_30 has 0 link(s):
#
#     Variable vvel_50 has 0 link(s):
#
#     Variable vvel_70 has 0 link(s):
#
#     Variable vvel_100 has 0 link(s):
#
#     Variable vvel_150 has 0 link(s):
#
#     Variable vvel_200 has 0 link(s):
#
#     Variable vvel_250 has 0 link(s):
#
#     Variable vvel_300 has 0 link(s):
#
#     Variable vvel_400 has 0 link(s):
#
#     Variable vvel_500 has 0 link(s):
#
#     Variable vvel_600 has 0 link(s):
#
#     Variable vvel_700 has 0 link(s):
#
#     Variable vvel_850 has 0 link(s):
#
#     Variable vvel_925 has 0 link(s):
#
#     Variable vvel_975 has 0 link(s):
#
#     Variable vvel_1000 has 0 link(s):
#
#     Variable out_div100 has 0 link(s):
#
#     Variable out_div200 has 0 link(s):
#
#     Variable out_div250 has 0 link(s):
#
#     Variable out_div300 has 0 link(s):
#
#     Variable out_div400 has 0 link(s):
#
#     Variable out_div500 has 0 link(s):
#
#     Variable out_eqt1000 has 0 link(s):
#
#     Variable out_eqt200 has 0 link(s):
#
#     Variable out_eqt250 has 0 link(s):
#
#     Variable out_eqt300 has 0 link(s):
#
#     Variable out_eqt400 has 0 link(s):
#
#     Variable out_eqt500 has 0 link(s):
#
#     Variable out_eqt600 has 0 link(s):
#
#     Variable out_eqt700 has 0 link(s):
#
#     Variable out_eqt850 has 0 link(s):
#
#     Variable out_eqt925 has 0 link(s):
#
#     Variable out_sh850_200 has 0 link(s):
#
#     Variable out_sh850_250 has 0 link(s):
#
#     Variable out_sh925_200 has 0 link(s):
#
#     Variable out_sh925_250 has 0 link(s):
#
#     Variable out_wstrss10 has 0 link(s):
#
#     Variable out2mdewtmp has 0 link(s):
#
#     Variable out2mtmp has 0 link(s):
#
#     Variable outconv_ppt has 0 link(s):
#
#     Variable outtot_cld_ice has 0 link(s):
#
#     Variable outtot_cldwtr has 0 link(s):
#
#     Variable outtot_cld_rain has 0 link(s):
#
#     Variable outvi_div_cld_froz_wtr has 0 link(s):
#
#     Variable outvi_div_cld_liq_wtr has 0 link(s):
#
#     Variable outvi_div_mass_flux has 0 link(s):
#
#     Variable outvi_div_moisture_flux has 0 link(s):
#
#     Variable outvi_div_tot_enrgy_flux has 0 link(s):
#
#     Variable outvi_pe_inte has 0 link(s):
#
#     Variable outvi_pe_ie_latentenrgy has 0 link(s):
#
#     Variable outvi_olr has 0 link(s):
#
#     Variable outvi_tot_enrgy has 0 link(s):
#
#     Variable outvi_moisture_div has 0 link(s):
#
#     Variable outcape has 0 link(s):
#
#     Variable outinst_moisture_flux has 0 link(s):
#
#     Variable outinst_ssh_flux has 0 link(s):
#
#     Variable outsurfmean_lhf has 0 link(s):
#
#     Variable outsurfmean_shf has 0 link(s):
#
#     Variable outvimean_moisture_div has 0 link(s):
#
#     Variable outsurf_lhf has 0 link(s):
#
#     Variable outsurf_shf has 0 link(s):
#
#     Variable outtot_suprcool_liqwtr has 0 link(s):
#
#     Variable outtot_wtr_vpr has 0 link(s):
#
#     Variable outsst has 0 link(s):
#
#     Variable outvort_10 has 0 link(s):
#
#     Variable outvort_20 has 0 link(s):
#
#     Variable outvort_30 has 0 link(s):
#
#     Variable outvort_50 has 0 link(s):
#
#     Variable outvort_70 has 0 link(s):
#
#     Variable outvort_100 has 0 link(s):
#
#     Variable outvort_150 has 0 link(s):
#
#     Variable outvort_200 has 0 link(s):
#
#     Variable outvort_250 has 0 link(s):
#
#     Variable outvort_300 has 0 link(s):
#
#     Variable outvort_400 has 0 link(s):
#
#     Variable outvort_500 has 0 link(s):
#
#     Variable outvort_600 has 0 link(s):
#
#     Variable outvort_700 has 0 link(s):
#
#     Variable outvort_800 has 0 link(s):
#
#     Variable outvort_850 has 0 link(s):
#
#     Variable outvort_900 has 0 link(s):
#
#     Variable outvort_925 has 0 link(s):
#
#     Variable outvort_950 has 0 link(s):
#
#     Variable outvort_975 has 0 link(s):
#
#     Variable outvort_1000 has 0 link(s):
#
#     Variable outrhum_10 has 0 link(s):
#
#     Variable outrhum_20 has 0 link(s):
#
#     Variable outrhum_30 has 0 link(s):
#
#     Variable outrhum_50 has 0 link(s):
#
#     Variable outrhum_70 has 0 link(s):
#
#     Variable outrhum_100 has 0 link(s):
#
#     Variable outrhum_150 has 0 link(s):
#
#     Variable outrhum_200 has 0 link(s):
#
#     Variable outrhum_250 has 0 link(s):
#
#     Variable outrhum_300 has 0 link(s):
#
#     Variable outrhum_400 has 0 link(s):
#
#     Variable outrhum_500 has 0 link(s):
#
#     Variable outrhum_600 has 0 link(s):
#
#     Variable outrhum_700 has 0 link(s):
#
#     Variable outrhum_800 has 0 link(s):
#
#     Variable outrhum_850 has 0 link(s):
#
#     Variable outrhum_900 has 0 link(s):
#
#     Variable outrhum_925 has 0 link(s):
#
#     Variable outrhum_950 has 0 link(s):
#
#     Variable outrhum_975 has 0 link(s):
#
#     Variable outrhum_1000 has 0 link(s):
#
#     Variable outgpot_10 has 0 link(s):
#
#     Variable outgpot_20 has 0 link(s):
#
#     Variable outgpot_30 has 0 link(s):
#
#     Variable outgpot_50 has 0 link(s):
#
#     Variable outgpot_70 has 0 link(s):
#
#     Variable outgpot_100 has 0 link(s):
#
#     Variable outgpot_150 has 0 link(s):
#
#     Variable outgpot_200 has 0 link(s):
#
#     Variable outgpot_250 has 0 link(s):
#
#     Variable outgpot_300 has 0 link(s):
#
#     Variable outgpot_400 has 0 link(s):
#
#     Variable outgpot_500 has 0 link(s):
#
#     Variable outgpot_600 has 0 link(s):
#
#     Variable outgpot_700 has 0 link(s):
#
#     Variable outgpot_800 has 0 link(s):
#
#     Variable outgpot_850 has 0 link(s):
#
#     Variable outgpot_900 has 0 link(s):
#
#     Variable outgpot_925 has 0 link(s):
#
#     Variable outgpot_950 has 0 link(s):
#
#     Variable outgpot_975 has 0 link(s):
#
#     Variable outgpot_1000 has 0 link(s):
#
#     Variable outvvel_10 has 0 link(s):
#
#     Variable outvvel_20 has 0 link(s):
#
#     Variable outvvel_30 has 0 link(s):
#
#     Variable outvvel_50 has 0 link(s):
#
#     Variable outvvel_70 has 0 link(s):
#
#     Variable outvvel_100 has 0 link(s):
#
#     Variable outvvel_150 has 0 link(s):
#
#     Variable outvvel_200 has 0 link(s):
#
#     Variable outvvel_250 has 0 link(s):
#
#     Variable outvvel_300 has 0 link(s):
#
#     Variable outvvel_400 has 0 link(s):
#
#     Variable outvvel_500 has 0 link(s):
#
#     Variable outvvel_600 has 0 link(s):
#
#     Variable outvvel_700 has 0 link(s):
#
#     Variable outvvel_850 has 0 link(s):
#
#     Variable outvvel_925 has 0 link(s):
#
#     Variable outvvel_975 has 0 link(s):
#
#     Variable outvvel_1000 has 0 link(s):

# %%
fig=plt.rcParams["figure.figsize"] = (20,25)
tp.plot_graph(graph=results['graph'], val_matrix=results['val_matrix'], var_names=var_names)
plt.show()

# %%
data_long, nonstationarity_indicator = toys.structural_causal_process(
    links=links, T=100000, noises=noises, seed=seed)
parcorr = ParCorr(significance='analytic')
pcmci_long = PCMCI(
    dataframe=pp.DataFrame(data_long, var_names=var_names), 
    cond_ind_test=parcorr,
    verbosity=1)
tau_max = 3
pcmci_long.verbosity = 0

results = pcmci_long.run_pcalg(tau_min=0, tau_max=tau_max, pc_alpha=0.001)
tp.plot_time_series_graph(    
    figsize=(8, 8),
    node_size=0.05,
    val_matrix=results['val_matrix'],
    graph=results['graph'],
    link_attribute=link_attribute,
    var_names=var_names,
    link_colorbar_label='PC')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [150], in <cell line: 1>()
#       1 tp.plot_time_series_graph(
#       2     figsize=(8, 8),
#       3     node_size=0.05,
#       4     val_matrix=results['val_matrix'],
#       5     graph=results['graph'],
# ----> 6     link_attribute=link_attribute,
#       7     var_names=var_names,
#       8     link_colorbar_label='PC')
#       9 plt.show()
#
# NameError: name 'link_attribute' is not defined
